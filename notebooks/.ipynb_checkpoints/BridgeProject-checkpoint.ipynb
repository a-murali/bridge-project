# %%
#import requests
#from bs4 import BeautifulSoup

# %%
# #load composite material bridges
# url = "https://structurae.net/en/structures/bridges/composite-bridges/list"
# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')
# table_composite = soup.find('table', {id: 'structureListResults'})

# #headers = [header.text.strip() for header in table_composite.find_all('th')]

# print(response.text)

# # rows = []
# # for row in table.find_all('tr'):
# #     cells = [cell.text.strip() for cell in row.find_all('td')]
# #     if cells:
# #         rows.append(cells)
# # print(headers)
# # for row in rows:
# #     print(row)

# %%
#!pip install selenium
#!apt-get update 
#!apt install chromium-chromedriver
#!cp /usr/lib/chromium-browser/chromedriver /usr/bin/

# %%
# %%shell
# # DISCONNECT AND DELETE RUNTIME BEFORE RUNNING
# # Ubuntu no longer distributes chromium-browser outside of snap
# #
# # Proposed solution: https://askubuntu.com/questions/1204571/how-to-install-chromium-without-snap
#
# # Add debian buster
# cat > /etc/apt/sources.list.d/debian.list <<'EOF'
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster.gpg] http://deb.debian.org/debian buster main
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster-updates.gpg] http://deb.debian.org/debian buster-updates main
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-security-buster.gpg] http://deb.debian.org/debian-security buster/updates main
# EOF
#
# # Add keys
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A
#
# apt-key export 77E11517 | gpg --dearmour -o /usr/share/keyrings/debian-buster.gpg
# apt-key export 22F3D138 | gpg --dearmour -o /usr/share/keyrings/debian-buster-updates.gpg
# apt-key export E562B32A | gpg --dearmour -o /usr/share/keyrings/debian-security-buster.gpg
#
# # Prefer debian repo for chromium* packages only
# # Note the double-blank lines between entries
# cat > /etc/apt/preferences.d/chromium.pref << 'EOF'
# Package: *
# Pin: release a=eoan
# Pin-Priority: 500
#
#
# Package: *
# Pin: origin "deb.debian.org"
# Pin-Priority: 300
#
#
# Package: chromium*
# Pin: origin "deb.debian.org"
# Pin-Priority: 700
# EOF
#
# # Install chromium and chromium-driver
# apt-get update
# apt-get install --reinstall chromium chromium-driver
#
# # Install selenium
# pip install selenium
# Out:
# Executing: /tmp/apt-key-gpghome.mKqnLSvRGw/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
# gpg: key DCC9EFBF77E11517: public key "Debian Stable Release Key (10/buster) <debian-release@lists.debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Executing: /tmp/apt-key-gpghome.z2Q5pEtfBh/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
# gpg: key DC30D7C23CBBABEE: public key "Debian Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Executing: /tmp/apt-key-gpghome.3SUVe2DQPL/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A
# gpg: key 4DFAB270CAA96DFA: public key "Debian Security Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Get:1 http://deb.debian.org/debian buster InRelease [122 kB]
# Get:2 http://deb.debian.org/debian buster-updates InRelease [56.6 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:4 http://deb.debian.org/debian-security buster/updates InRelease [34.8 kB]
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:8 http://deb.debian.org/debian buster/main amd64 Packages [10.7 MB]
# Hit:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:10 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:12 http://deb.debian.org/debian buster-updates/main amd64 Packages [9,745 B]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:16 http://deb.debian.org/debian-security buster/updates/main amd64 Packages [616 kB]
# Hit:17 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:18 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ Packages [77.6 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,334 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,150 kB]
# Fetched 16.5 MB in 3s (4,834 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-common chromium-sandbox libevent-2.1-6 libfontenc1 libicu63
#   libimobiledevice6 libjpeg62-turbo libplist3 libre2-5 libu2f-udev libudev1
#   libupower-glib3 libusbmuxd6 libvpx5 libxkbfile1 libxtst6 libxxf86dga1
#   notification-daemon udev upower usbmuxd x11-utils
# Suggested packages:
#   chromium-l10n chromium-shell libusbmuxd-tools mesa-utils
# The following NEW packages will be installed:
#   chromium chromium-common chromium-driver chromium-sandbox libevent-2.1-6
#   libfontenc1 libicu63 libimobiledevice6 libjpeg62-turbo libplist3 libre2-5
#   libu2f-udev libupower-glib3 libusbmuxd6 libvpx5 libxkbfile1 libxtst6
#   libxxf86dga1 notification-daemon udev upower usbmuxd x11-utils
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 23 newly installed, 0 to remove and 24 not upgraded.
# Need to get 76.2 MB of archives.
# After this operation, 266 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian buster/main amd64 libevent-2.1-6 amd64 2.1.8-stable-4 [177 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libudev1 amd64 245.4-4ubuntu3.21 [75.9 kB]
# Get:3 http://deb.debian.org/debian buster/main amd64 libicu63 amd64 63.1-6+deb10u3 [8,293 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 udev amd64 245.4-4ubuntu3.21 [1,366 kB]
# Get:5 http://deb.debian.org/debian buster/main amd64 libjpeg62-turbo amd64 1:1.5.2-2+deb10u1 [133 kB]
# Get:6 http://deb.debian.org/debian buster/main amd64 libvpx5 amd64 1.7.0-3+deb10u1 [800 kB]
# Get:7 http://deb.debian.org/debian buster/main amd64 chromium-common amd64 90.0.4430.212-1~deb10u1 [1,423 kB]
# Get:8 http://deb.debian.org/debian buster/main amd64 chromium amd64 90.0.4430.212-1~deb10u1 [58.3 MB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libre2-5 amd64 20200101+dfsg-1build1 [162 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu1 [12.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-utils amd64 7.7+5 [199 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libplist3 amd64 2.1.0-4build2 [31.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libusbmuxd6 amd64 2.0.1-2 [19.1 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libimobiledevice6 amd64 1.2.1~git20191129.9f79242-1build1 [65.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 libu2f-udev all 1.1.10-1 [6,108 B]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libupower-glib3 amd64 0.99.11-1build2 [43.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/universe amd64 notification-daemon amd64 3.20.0-4 [37.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 upower amd64 0.99.11-1build2 [104 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 usbmuxd amd64 1.1.1~git20191130.9af2b12-1 [38.4 kB]
# Get:23 http://deb.debian.org/debian buster/main amd64 chromium-driver amd64 90.0.4430.212-1~deb10u1 [4,703 kB]
# Get:24 http://deb.debian.org/debian buster/main amd64 chromium-sandbox amd64 90.0.4430.212-1~deb10u1 [146 kB]
# Fetched 76.2 MB in 1s (57.2 MB/s)
# (Reading database ... 122518 files and directories currently installed.)
# Preparing to unpack .../libudev1_245.4-4ubuntu3.21_amd64.deb ...
# Unpacking libudev1:amd64 (245.4-4ubuntu3.21) over (245.4-4ubuntu3.19) ...
# Setting up libudev1:amd64 (245.4-4ubuntu3.21) ...
# Selecting previously unselected package udev.
# (Reading database ... 122518 files and directories currently installed.)
# Preparing to unpack .../00-udev_245.4-4ubuntu3.21_amd64.deb ...
# Unpacking udev (245.4-4ubuntu3.21) ...
# Selecting previously unselected package libevent-2.1-6:amd64.
# Preparing to unpack .../01-libevent-2.1-6_2.1.8-stable-4_amd64.deb ...
# Unpacking libevent-2.1-6:amd64 (2.1.8-stable-4) ...
# Selecting previously unselected package libicu63:amd64.
# Preparing to unpack .../02-libicu63_63.1-6+deb10u3_amd64.deb ...
# Unpacking libicu63:amd64 (63.1-6+deb10u3) ...
# Selecting previously unselected package libjpeg62-turbo:amd64.
# Preparing to unpack .../03-libjpeg62-turbo_1%3a1.5.2-2+deb10u1_amd64.deb ...
# Unpacking libjpeg62-turbo:amd64 (1:1.5.2-2+deb10u1) ...
# Selecting previously unselected package libre2-5:amd64.
# Preparing to unpack .../04-libre2-5_20200101+dfsg-1build1_amd64.deb ...
# Unpacking libre2-5:amd64 (20200101+dfsg-1build1) ...
# Selecting previously unselected package libvpx5:amd64.
# Preparing to unpack .../05-libvpx5_1.7.0-3+deb10u1_amd64.deb ...
# Unpacking libvpx5:amd64 (1.7.0-3+deb10u1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../06-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../07-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../08-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../09-libxxf86dga1_2%3a1.1.5-0ubuntu1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../10-x11-utils_7.7+5_amd64.deb ...
# Unpacking x11-utils (7.7+5) ...
# Selecting previously unselected package chromium-common.
# Preparing to unpack .../11-chromium-common_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium-common (90.0.4430.212-1~deb10u1) ...
# Selecting previously unselected package chromium.
# Preparing to unpack .../12-chromium_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium (90.0.4430.212-1~deb10u1) ...
# Selecting previously unselected package chromium-driver.
# Preparing to unpack .../13-chromium-driver_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium-driver (90.0.4430.212-1~deb10u1) ...
# Selecting previously unselected package chromium-sandbox.
# Preparing to unpack .../14-chromium-sandbox_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium-sandbox (90.0.4430.212-1~deb10u1) ...
# Selecting previously unselected package libplist3:amd64.
# Preparing to unpack .../15-libplist3_2.1.0-4build2_amd64.deb ...
# Unpacking libplist3:amd64 (2.1.0-4build2) ...
# Selecting previously unselected package libusbmuxd6:amd64.
# Preparing to unpack .../16-libusbmuxd6_2.0.1-2_amd64.deb ...
# Unpacking libusbmuxd6:amd64 (2.0.1-2) ...
# Selecting previously unselected package libimobiledevice6:amd64.
# Preparing to unpack .../17-libimobiledevice6_1.2.1~git20191129.9f79242-1build1_amd64.deb ...
# Unpacking libimobiledevice6:amd64 (1.2.1~git20191129.9f79242-1build1) ...
# Selecting previously unselected package libu2f-udev.
# Preparing to unpack .../18-libu2f-udev_1.1.10-1_all.deb ...
# Unpacking libu2f-udev (1.1.10-1) ...
# Selecting previously unselected package libupower-glib3:amd64.
# Preparing to unpack .../19-libupower-glib3_0.99.11-1build2_amd64.deb ...
# Unpacking libupower-glib3:amd64 (0.99.11-1build2) ...
# Selecting previously unselected package notification-daemon.
# Preparing to unpack .../20-notification-daemon_3.20.0-4_amd64.deb ...
# Unpacking notification-daemon (3.20.0-4) ...
# Selecting previously unselected package upower.
# Preparing to unpack .../21-upower_0.99.11-1build2_amd64.deb ...
# Unpacking upower (0.99.11-1build2) ...
# Selecting previously unselected package usbmuxd.
# Preparing to unpack .../22-usbmuxd_1.1.1~git20191130.9af2b12-1_amd64.deb ...
# Unpacking usbmuxd (1.1.1~git20191130.9af2b12-1) ...
# Setting up libplist3:amd64 (2.1.0-4build2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Setting up chromium-sandbox (90.0.4430.212-1~deb10u1) ...
# Setting up libicu63:amd64 (63.1-6+deb10u3) ...
# Setting up notification-daemon (3.20.0-4) ...
# Setting up libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up libjpeg62-turbo:amd64 (1:1.5.2-2+deb10u1) ...
# Setting up udev (245.4-4ubuntu3.21) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libevent-2.1-6:amd64 (2.1.8-stable-4) ...
# Setting up libusbmuxd6:amd64 (2.0.1-2) ...
# Setting up libupower-glib3:amd64 (0.99.11-1build2) ...
# Setting up libre2-5:amd64 (20200101+dfsg-1build1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# Setting up libimobiledevice6:amd64 (1.2.1~git20191129.9f79242-1build1) ...
# Setting up libvpx5:amd64 (1.7.0-3+deb10u1) ...
# Setting up libu2f-udev (1.1.10-1) ...
# Failed to send reload request: No such file or directory
# Setting up upower (0.99.11-1build2) ...
# Setting up usbmuxd (1.1.1~git20191130.9af2b12-1) ...
# Warning: The home dir /var/lib/usbmux you specified can't be accessed: No such file or directory
# Adding system user `usbmux' (UID 105) ...
# Adding new user `usbmux' (UID 105) with group `plugdev' ...
# Not creating home directory `/var/lib/usbmux'.
# Setting up x11-utils (7.7+5) ...
# Setting up chromium-common (90.0.4430.212-1~deb10u1) ...
# Setting up chromium (90.0.4430.212-1~deb10u1) ...
# update-alternatives: using /usr/bin/chromium to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-driver (90.0.4430.212-1~deb10u1) ...
# Processing triggers for systemd (245.4-4ubuntu3.21) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for dbus (1.12.16-2ubuntu2.3) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting selenium
#   Downloading selenium-4.9.0-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 45.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2022.12.7)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 31.9 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.10.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: urllib3[socks]~=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (1.26.15)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 h11-0.14.0 outcome-1.2.0 selenium-4.9.0 trio-0.22.0 trio-websocket-0.10.2 wsproto-1.2.0

# %%
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
import pandas as pd

# %%
url = 'https://structurae.net/en/structures/bridges/composite-bridges/list'

#service = Service("/usr/bin/chromedriver")
#service = Service("/usr/lib/chromium-browser/chromedriver")

options = Options()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument('--disable-dev-shm-usage')

#driver = webdriver.Chrome(service=service, options=options)
driver = webdriver.Chrome(service = Service("/usr/bin/chromedriver"), options = options)

# Load the website
driver.get(url)

# Wait for the table to load (optional)
# You may need to adjust the timeout depending on your internet speed and computer performance
driver.implicitly_wait(10)

# Get number of pages for table
num_pages = int(driver.find_element(By.CLASS_NAME, 'pageLinksPageNav').find_elements(By.TAG_NAME, 'a')[-1].get_attribute("data-page"))
print(num_pages)

# Extract the headers
table = driver.find_element(By.CLASS_NAME, 'mobile-scroll-table')
headers = [header.text.strip() for header in table.find_elements(By.TAG_NAME, 'th')]

print(headers)

driver.quit()


rows = []

for i in range(0, num_pages * 100, 100):
    url = 'https://structurae.net/en/structures/bridges/composite-bridges/list?min={}'.format(i)
    driver = webdriver.Chrome(service = Service("/usr/bin/chromedriver"), options = options)
    driver.get(url)
    driver.implicitly_wait(10)

    # Find the table element
    table = driver.find_element(By.CLASS_NAME, 'mobile-scroll-table')

    # Extract the rows
    for row in table.find_elements(By.TAG_NAME, 'tr'):
        i = 0
        row_data = []
        for cell in row.find_elements(By.TAG_NAME, 'td'):
            if(i == 4):
                img = cell.find_element(By.TAG_NAME, 'img')
                item = img.get_attribute("alt")#.text.strip()
                row_data.append(item)
            else:
                item = cell.text.strip()
                row_data.append(item)
            i += 1
        #cells = [cell.text.strip() for cell in row.find_elements(By.TAG_NAME, 'td')]
        if row_data:
            rows.append(row_data)

    # Close the browser
    driver.quit()

# Print the headers and rows
for row in rows:
    print(row)

#Create csv
df = pd.DataFrame(rows, columns = headers)
df.to_csv('/usr/bin/bridges.csv', index = False, encoding = 'utf-8-sig')
# Out:
# 16
# ['#', 'Name', 'Year', 'Location', 'Country', 'Status']
# ['1', '470 Odra River Bridge', '2009', 'Ostrava', 'Czechia', 'in use']
# ['2', '4708/C203 Bridge', '2009', 'Ostrava', 'Czechia', 'in use']
# ['3', '7th Avenue Pedestrian Bridge (N1)', '2010', 'Johannesburg', 'South Africa', 'in use']
# ['4', 'A 1 Lenne Bridge', '2009', 'Hagen (NRW)', 'Germany', 'in use']
# ['5', 'A 113 Teltowkanal Bridge', '2004', '- Berlin (BE)', 'Germany', 'in use']
# ['6', 'A 30 Werre East Bridge', '2012', 'Bad Oeynhausen (NRW)', 'Germany', 'in use']
# ['7', 'A 30 Werre West Bridge', '2012', 'Löhne (NRW)', 'Germany', 'in use']
# ['8', 'A 31 Lippe River Bridge', '1981', 'Dorsten (NRW)', 'Germany', 'in use']
# ['9', 'A-8 Directional Ramp Bridge', '', 'Bilbao', 'Spain', 'in use']
# ['10', 'A-8 Exit 115A Ramp Bridge', '', 'Bilbao', 'Spain', 'in use']
# ['11', 'A1 Area Tramway Bridge', '', 'Stuttgart (BW)', 'Germany', 'in use']
# ['12', 'A19 Tees Viaduct', '1975', 'Middlesbrough (GB-ENG)', 'United Kingdom', 'in use']
# ['13', 'A24 Müritz-Elde Canal Bridge', '2011', 'Neustadt-Glewe (MV)', 'Germany', 'in use']
# ['14', 'A26 Danube River Bridge', '2028', 'Linz (OOE)', 'Austria', 'under construction']
# ['15', 'A31 Rail Bridge', '2006', 'Lesménils (54)', 'France', 'in use']
# ['16', 'A4-TAV Torino-Milano Viaduct', '2008', 'Milano (LM)', 'Italy', 'in use']
# ['17', 'A42 Emscher Bridge', '', 'Bottrop (NRW)', 'Germany', 'in use']
# ['18', 'A82 Pulpit Rock Viaduct', '2015', 'Arrochar (GB-SCT)', 'United Kingdom', 'in use']
# ['19', 'A85 Motorway Bridge', '1993', '- Cinq-Mars-la-Pile (37)', 'France', 'in use']
# ['20', 'A9 Lez River Viaduct', '2017', 'Lattes (34)', 'France', 'in use']
# ['21', 'Abbas Ibn Firnás Bridge', '2011', 'Córdoba', 'Spain', 'in use']
# ['22', 'Abbeville Viaduct', '', 'Grand-Laviers (80)', 'France', 'in use']
# ['23', 'Abernethy Bridge', '1970', 'Oregon City (OR)', 'USA', 'in use']
# ['24', 'Abroñigal Viaduct', '', 'Madrid', 'Spain', 'in use']
# ['25', 'Abteibrücke', '1916', 'Berlin (BE)', 'Germany', 'in use']
# ['26', 'Ackermann Bridges', '2018', 'Augsburg (BY)', 'Germany', 'in use']
# ['27', 'Adàwe Crossing', '2015', 'Ottawa (ON)', 'Canada', 'in use']
# ['28', 'Adda Viaduct', '', 'Cassano d’Adda (LM)', 'Italy', 'under construction']
# ['29', 'Adda-Bitto Viaduct', '2018', 'Morbegno (LM)', 'Italy', 'in use']
# ['30', 'Adur Bridge', '1969', 'Shoreham-by-Sea (GB-ENG)', 'United Kingdom', 'in use']
# ['31', 'Afte Valley Bridge', '2021', 'Bad Wünnenberg (NRW)', 'Germany', 'in use']
# ['32', 'Aggerbrücke Höngesberg', '2014', 'Lohmar (NRW)', 'Germany', 'in use']
# ['33', 'Aggerbrücke Schiffarth', '2014', 'Lohmar (NRW)', 'Germany', 'in use']
# ['34', 'Aguas Vivas Footbridge', '', 'Guadalajara', 'Spain', 'in use']
# ['35', 'Aguilar de Ebro Viaduct', '', 'Osera de Ebro', 'Spain', 'in use']
# ['36', 'Aibre-Trémoins Viaduct', '2011', 'Aibre (25)', 'France', 'in use']
# ['37', 'Aiter Valley Bridge', '2003', 'Sattledt (OOE)', 'Austria', 'in use']
# ['38', 'Aiton Viaduct', '', 'Aiton (73)', 'France', 'in use']
# ['39', 'Alagnonnette Bridge', '1991', 'Massiac (15)', 'France', 'in use']
# ['40', 'Alamillo Bridge', '1992', 'Sevilla', 'Spain', 'in use']
# ['41', 'Albgrün Bridge', '1986', 'Karlsruhe (BW)', 'Germany', 'in use']
# ['42', 'Albino Viaduct', '2007', 'Bergamo (LM)', 'Italy', 'in use']
# ['43', 'Albrechtsgraben Viaduct', '2002', 'Suhl (TH)', 'Germany', 'in use']
# ['44', 'Alcoy Sur Viaduct', '2009', 'Alcoy', 'Spain', 'in use']
# ['45', 'Alex Fraser Bridge', '1986', 'Annacis (BC)', 'Canada', 'in use']
# ['46', 'Alexandra David-Néel Bridge', '2004', 'Digne-les-Bains (4)', 'France', 'in use']
# ['47', 'Alfred-Herrhausen-Brücke', '1965', 'Essen (NRW)', 'Germany', 'in use']
# ['48', 'Allegheny Station Viaduct', '2012', 'Pittsburgh (PA)', 'USA', 'in use']
# ['49', 'Alphonse Loubat Viaduct', '2006', 'Montpellier (34)', 'France', 'in use']
# ['50', 'Alte Elbebrücke Meissen', '1933', 'Meißen (SN)', 'Germany', 'demolished']
# ['51', 'Altenahr Bridge', '2005', 'Altenahr (RP)', 'Germany', 'in use']
# ['52', 'Altenreuth Overpass', '2014', 'Harsdorf (BY)', 'Germany', 'in use']
# ['53', 'Althaldenslebener Strasse Bridge', '2009', 'Haldensleben (ST)', 'Germany', 'in use']
# ['54', 'Altstadtbrücke Meißen', '2000', 'Meißen (SN)', 'Germany', 'in use']
# ['55', 'Altwies Viaduct', '', 'Altwies', 'Luxembourg', 'in use']
# ['56', 'Altwipfergrund Viaduct', '2001', 'Ilmenau (TH)', 'Germany', 'in use']
# ['57', 'Alvensleber Landstrasse Bridge', '', 'Haldensleben (ST)', 'Germany', 'in use']
# ['58', 'Am Listholze Bridge', '1998', 'Hanover (NI)', 'Germany', 'in use']
# ['59', 'Am Overbeck Bridge', '1914', 'Wetter (Ruhr) (NRW)', 'Germany', 'in use']
# ['60', 'Amolanas Bridge', '2000', 'Coquimbo', 'Chile', 'in use']
# ['61', 'Ampsin Bridge', '1978', 'Ampsin', 'Belgium', 'in use']
# ['62', 'Amstel Footbridge', '1993', 'Athens', 'Greece', 'in use']
# ['63', 'Angerbach Viaduct', '2020', 'Ratingen (NRW)', 'Germany', 'under construction']
# ['64', 'Annenbrücke', '1998', 'Bernburg (Saale) (ST)', 'Germany', 'in use']
# ['65', 'Añorga Rail Bridge', '', 'San Sebastián', 'Spain', 'in use']
# ['66', 'Antioch Bridge', '1978', '- Antioch (CA)', 'USA', 'in use']
# ['67', 'Antoniana Bridge', '2013', 'La Spezia (LG)', 'Italy', 'in use']
# ['68', 'Aogishi Bridge', '1985', 'Wakayama', 'Japan', 'in use']
# ['69', 'AP-1 Overpass', '', 'Bergara', 'Spain', 'in use']
# ['70', 'Aracaju-Barra Bridge', '2006', 'Aracaju (SE)', 'Brazil', 'in use']
# ['71', 'Arbizelai Viaduct', '2008', 'Mondragón', 'Spain', 'in use']
# ['72', 'Arbois Bridge', '1985', 'Arbois (39)', 'France', 'in use']
# ['73', 'Arbouans Viaduct', '2012', 'Arbouans (25)', 'France', 'in use']
# ['74', 'Archidona Viaduct', '2012', 'Archidona', 'Spain', 'in use']
# ['75', 'Ardre Viaduct', '', 'Tramery (51)', 'France', 'in use']
# ['76', 'Arenal Bridge', '1993', 'Córdoba', 'Spain', 'in use']
# ['77', 'Arenzana Bridge', '1993', 'Arenzana de Abajo', 'Spain', 'in use']
# ['78', 'Arenzana Bridge', '1991', 'Arenzana de Abajo', 'Spain', 'in use']
# ['79', 'Argentan Viaduct', '2010', 'Fontenai-sur-Orne (61)', 'France', 'in use']
# ['80', 'Ariege Viaduct', '1993', 'Montgaillard (9)', 'France', 'in use']
# ['81', 'Aristide Briand Bridge', '1966', 'Nantes (44)', 'France', 'in use']
# ['82', 'Arran Viaduct', '1990', 'Urt (64)', 'France', 'in use']
# ['83', 'Arriaca Bridge', '2006', 'Guadalajara', 'Spain', 'in use']
# ['84', 'Arroyo de las Piedras Viaduct', '2007', 'Álora', 'Spain', 'in use']
# ['85', 'Arroyo Meaques Bridge', '1992', 'Pozuelo de Alarcón', 'Spain', 'in use']
# ['86', 'Ashcroft Bridge', '', 'Ashcroft (BC)', 'Canada', 'in use']
# ['87', 'Astaneh Cable-Stayed Bridge', '2019', 'Astaneh-e Ashrafiyyeh', 'Iran', 'under construction']
# ['88', 'Attiki Odos Overpass', '2003', 'Paiania', 'Greece', 'in use']
# ['89', 'Auerswalde Footbridge', '2017', 'Lichtenau (SN)', 'Germany', 'in use']
# ['90', 'Aufkirchen Footbridge', '', 'Oberding (BY)', 'Germany', 'in use']
# ['91', 'Aulella Viaduct', '2005', 'Aulla (TC)', 'Italy', 'in use']
# ['92', 'Aurelia Viaduct', '', 'Pisa (TC)', 'Italy', 'in use']
# ['93', 'Austreberthe Viaduct', '2015', 'Barentin (76)', 'France', 'in use']
# ['94', 'Autobahnüberführung Fürstenwalde', '2001', 'Fürstenwalde (BB)', 'Germany', 'in use']
# ['95', 'Autoporto Viaduct', '1996', 'Ventimiglia (LG)', 'Italy', 'in use']
# ['96', 'Avenida de La Albufera Viaduct (M-30)', '1994', 'Madrid', 'Spain', 'in use']
# ['97', 'Avenida de Valdemarín Bridge', '', 'Madrid', 'Spain', 'in use']
# ['98', 'Avirons Bridge', '2006', 'Les Avirons', 'Réunion', 'in use']
# ['99', 'Avonmouth Bridge', '1974', 'Bristol (GB-ENG)', 'United Kingdom', 'in use']
# ['100', 'Awa Shirasagi Bridge', '', 'Tokushima', 'Japan', 'in use']
# ['101', 'B 247 Overpass', '', 'Leinefelde-Worbis (TH)', 'Germany', 'in use']
# ['102', 'B 247 Overpass', '', 'Bad Langensalza (TH)', 'Germany', 'in use']
# ['103', 'B 474n Dortmund-Ems Canal Bridge', '2021', 'Datteln (NRW)', 'Germany', 'in use']
# ['104', 'B184 Bridge at Podelwitz', '2015', 'Rackwitz (SN)', 'Germany', 'in use']
# ['105', 'B185 Mulde River Bridge', '2017', 'Dessau-Roßlau (ST)', 'Germany', 'in use']
# ['106', 'Bacchiglione Viaduct', '2012', 'Vicenza (VN)', 'Italy', 'in use']
# ['107', 'Bachstelzenweg Bridge', '1994', 'Berlin (BE)', 'Germany', 'in use']
# ['108', 'Bad Cannstatt Rail Bridge', '2021', 'Stuttgart (BW)', 'Germany', 'under construction']
# ['109', 'Bad Münster am Stein Bridge', '', 'Bad Kreuznach (RP)', 'Germany', 'in use']
# ['110', 'Badalona Footbridge', '', 'Badalona', 'Spain', 'in use']
# ['111', 'Bagley Street Pedestrian Bridge', '2010', 'Detroit (MI)', 'USA', 'in use']
# ['112', 'Bahnhofbrücke', '2013', 'Schwäbisch Gmünd (BW)', 'Germany', 'in use']
# ['113', 'Bahnhofsbrücke', '2003', 'Dessau-Roßlau (ST)', 'Germany', 'in use']
# ['114', 'Bahnhofsbrücke Eberswalde', '2005', 'Eberswalde (BB)', 'Germany', 'in use']
# ['115', 'Bahretal Viaduct', '2008', 'Bahretal (SN)', 'Germany', 'in use']
# ['116', 'Baibò Viaduct', '2002', 'Pisogne (LM)', 'Italy', 'in use']
# ['117', 'Barranca El Zapote Bridge', '1993', 'Guerrero (GRO)', 'Mexico', 'in use']
# ['118', 'Baudrecourt Viaduct', '', 'Baudrecourt (57)', 'France', 'in use']
# ['119', 'Bauwerk 188/1A', '2008', 'Jena (TH)', 'Germany', 'in use']
# ['120', 'Bazillac Bridge', '1989', 'Bazillac (65)', 'France', 'in use']
# ['121', 'Bear Creek Bridge', '2011', 'Ouray County (CO)', 'USA', 'in use']
# ['122', 'Beaucaire Bridge', '1990', '- Beaucaire (30)', 'France', 'in use']
# ['123', 'Becklem Bridge', '1960', 'Castrop-Rauxel (NRW)', 'Germany', 'in use']
# ['124', 'Beelitz Wildlife Crossing', '2018', 'Beelitz (BB)', 'Germany', 'in use']
# ['125', 'Beipan River Shuibai Rail Bridge', '2001', 'Guizhou', 'China', 'in use']
# ['126', 'Bekohlungsband-Brücke', '1988', 'Herne (NRW)', 'Germany', 'in use']
# ['127', 'Belchamp Viaduct', '2013', 'Arbouans (25)', 'France', 'in use']
# ['128', 'Bendola Bridge', '', 'Saorge (6)', 'France', 'in use']
# ['129', 'Benoîte-Vaux Railroad Bridge', '', 'Rambluzin-et-Benoîte-Vaux (55)', 'France', 'in use']
# ['130', 'Berlin Bridge', '', 'Gelsenkirchen (NRW)', 'Germany', 'in use']
# ['131', 'Berlin Ostkreuz Southern Rail Overfly', '2017', 'Berlin (BE)', 'Germany', 'in use']
# ['132', 'Berliner Brücke', '2006', 'Halle/Saale (ST)', 'Germany', 'in use']
# ['133', 'Bermecke Viaduct', '2019', 'Bestwig (NRW)', 'Germany', 'in use']
# ['134', 'Bertrange Flyover', '2013', 'Bertrange', 'Luxembourg', 'in use']
# ['135', 'Beverungen Bridge', '2020', 'Beverungen (NRW)', 'Germany', 'in use']
# ['136', 'Biathlonbrücke Chiemgau-Arena', '2010', 'Ruhpolding (BY)', 'Germany', 'in use']
# ['137', 'Bicycle and Pedestrian Bridge between Český Těšín and Cieszyn', '2012', '- Cesky Tesin', 'Czechia', 'in use']
# ['138', 'Bidston Moss Viaduct', '1969', 'Bidston (GB-ENG)', 'United Kingdom', 'in use']
# ['139', 'Bill Emerson Memorial Bridge', '2003', 'Cape Girardeau (MO)', 'USA', 'in use']
# ['140', 'Billy-le-Grand Bridge', '2004', 'Billy-le-Grand (51)', 'France', 'in use']
# ['141', 'Binh Bridge', '2005', 'Hải Phòng', 'Vietnam', 'in use']
# ['142', 'Blackwell Interchange Bridge', '1967', 'Conway County (AR)', 'USA', 'in use']
# ['143', 'Blattenbrücke', '2012', 'Malters (LU)', 'Switzerland', 'in use']
# ['144', 'Blazy Viaduct', '1998', 'Souillac (46)', 'France', 'in use']
# ['145', 'Bleichinselbrücke', '2015', 'Heilbronn (BW)', 'Germany', 'in use']
# ['146', 'Blue Bridge', '2019', '- Ecublens (VD)', 'Switzerland', 'in use']
# ['147', 'Blythe Valley Park - M42 Overbridge', '', 'Solihull (GB-ENG)', 'United Kingdom', 'in use']
# ['148', 'Böber Viaduct', '2009', 'Hörselberg-Hainich (TH)', 'Germany', 'in use']
# ['149', 'Bocognano Viaduct', '2009', 'Bocognano (2A)', 'France', 'in use']
# ['150', 'Bohumín-Skřečoň Road Bridge', '2011', 'Bohumin', 'Czechia', 'in use']
# ['151', 'Bonpas Viaduct', '2001', 'Avignon (84)', 'France', 'in use']
# ['152', 'Bouc Bridge', '', 'Rixheim (68)', 'France', 'in use']
# ['153', 'Boulevard Berthier Rail Bridge (II)', '', 'Paris (75)', 'France', 'in use']
# ['154', 'Bourke Street Footbridge', '', 'Melbourne (VIC)', 'Australia', 'in use']
# ['155', 'BP Pedestrian Bridge', '2004', 'Chicago (IL)', 'USA', 'in use']
# ['156', 'Bras-Grande-Ravine Viaduct', '2009', 'Trois-Bassins', 'Réunion', 'in use']
# ['157', 'Bras-Mouton Viaduct', '2007', 'Saint-Leu', 'Réunion', 'in use']
# ['158', 'Brembo Viaduct', '2003', 'San Pellegrino Terme (LM)', 'Italy', 'in use']
# ['159', 'Brenta Viaduct', '2020', 'Bassano del Grappa (VN)', 'Italy', 'in use']
# ['160', 'Bridge across Plaza Central at Parque Tecnológico de Andalucía', '1992', 'Málaga', 'Spain', 'in use']
# ['161', 'Bridge across the RN10', '2006', 'Saint-Yrieix-sur-Charente (16)', 'France', 'in use']
# ['162', 'Bridge across the tracks at Lieusaint Station', '1999', 'Lieusaint (77)', 'France', 'in use']
# ['163', 'Bridge H01', '2009', 'London (GB-ENG)', 'United Kingdom', 'in use']
# ['164', 'Bridge of the Bad Langensalza Bypass', '2006', 'Bad Langensalza (TH)', 'Germany', 'in use']
# ['165', 'Bridge of the Isles', '1966', 'Montreal (QC)', 'Canada', 'in use']
# ['166', 'Bridge over the First City Pond', '', 'Donetsk', 'Ukraine', 'in use']
# ['167', 'Brigandsbrug', '2020', 'Ingelmunster', 'Belgium', 'in use']
# ['168', 'Britz Canal Motorway Bridge', '2002', '- Berlin (BE)', 'Germany', 'in use']
# ['169', 'Bruche Viaduct', '2021', '- Kolbsheim (67)', 'France', 'in use']
# ['170', 'Brücke Aktienweg (über Eisenbahn)', '2001', 'Duisburg (NRW)', 'Germany', 'in use']
# ['171', 'Brücke Bahnhof Kabel', '2009', 'Hagen (NRW)', 'Germany', 'in use']
# ['172', 'Brücke der Hüttentalstraße über die Sieg', '2016', 'Siegen (NRW)', 'Germany', 'in use']
# ['173', 'Brücke Schlackenstrasse', '1997', 'Unterwellenborn (TH)', 'Germany', 'in use']
# ['174', 'Brücke über das Nesenbachtal', '2000', 'Stuttgart (BW)', 'Germany', 'in use']
# ['175', 'Brunn Overpass', '2020', 'Nürnberger Land (BY)', 'Germany', 'in use']
# ['176', 'Brunsbecke Viaduct', '1968', 'Hagen (NRW)', 'Germany', 'to be demolished']
# ['177', 'Bucheggplatz Footbridge', '', 'Zurich (ZH)', 'Switzerland', 'in use']
# ['178', 'Büchenau Bridge', '1956', 'Bruchsal (BW)', 'Germany', 'in use']
# ['179', 'Buendía Lake Bridge', '2006', '- Alcocer', 'Spain', 'in use']
# ['180', 'Bülstringen Bridge', '1998', 'Bülstringen (ST)', 'Germany', 'in use']
# ['181', 'Bünztalvidadukt', '2014', 'Othmarsingen (AG)', 'Switzerland', 'in use']
# ['182', 'Buschkrugallee Highway Bridge', '2000', 'Berlin (BE)', 'Germany', 'in use']
# ['183', 'Bussy-le-Château Bridge', '2004', '- Bussy-le-Château (51)', 'France', 'in use']
# ['184', 'Butarque Park Footbridge', '', 'Leganés', 'Spain', 'in use']
# ['185', 'Buthiers Viaduct', '2011', "Voray-sur-l'Ognon (70)", 'France', 'in use']
# ['186', 'Büttnerstrasse Bridge', '1998', 'Hanover (NI)', 'Germany', 'in use']
# ['187', 'Cà Bianca Viaduct', '2007', 'Nembro (LM)', 'Italy', 'in use']
# ['188', 'Cadagua Viaducts', '', 'Bilbao', 'Spain', 'in use']
# ['189', 'Cadavedo Viaduct', '1996', 'Valdés', 'Spain', 'in use']
# ['190', 'Cal Park Hill Pathway Bridge', '2016', 'Larkspur (CA)', 'USA', 'in use']
# ['191', 'Cala Galdana Bridge', '2005', 'Ferreries', 'Spain', 'in use']
# ['192', 'Calbe Bridge', '1997', 'Calbe (Saale) (ST)', 'Germany', 'in use']
# ['193', 'Calchere Viaduct', '2004', 'Sulzano (LM)', 'Italy', 'in use']
# ['194', 'Callús Bridge', '2017', 'Callús', 'Spain', 'in use']
# ['195', 'Calw Footbridge', '2014', 'Calw (BW)', 'Germany', 'in use']
# ['196', 'Cambrón Footbridge', '2002', 'Toledo', 'Spain', 'in use']
# ['197', 'Cami Les Aigües Footbridge', '2008', 'Barcelona', 'Spain', 'in use']
# ['198', 'Campo del Galdo Viaduct', '', 'Potenza (BC)', 'Italy', 'in use']
# ['199', 'Canal Basin Footbridge', '', 'Coventry (GB-ENG)', 'United Kingdom', 'in use']
# ['200', 'Canero Viaduct', '', 'Valdés', 'Spain', 'in use']
# ['201', 'Capilano Bridge', '1969', 'Edmonton (AB)', 'Canada', 'in use']
# ['202', 'Captain John Bissell Memorial Bridge', '1957', 'Windsor (CT)', 'USA', 'in use']
# ['203', 'Caracas-La Guaira Bridge I', '2007', 'Vargas', 'Venezuela', 'in use']
# ['204', 'Carlos Camacho Espiritu Boulevard Bridge', '', 'Puebla (PUE)', 'Mexico', 'in use']
# ['205', 'Castlefield (MSJ&AR) Viaduct', '2017', 'Manchester (GB-ENG)', 'United Kingdom', 'in use']
# ['206', 'Cavaillon Viaduct', '', 'Cavaillon (84)', 'France', 'in use']
# ['207', 'CD 11 Bridge', '1957', 'Ancône (26)', 'France', 'in use']
# ['208', 'Centron Downstream Viaduct', '2006', 'Montgirod (73)', 'France', 'in use']
# ['209', 'Českobratrská Road Bridges', '2011', 'Ostrava', 'Czechia', 'in use']
# ['210', 'Chadon Viaduct', '2002', 'Gimel-les-Cascades (19)', 'France', 'in use']
# ['211', 'Chain Bridge', '2010', 'Bamberg (BY)', 'Germany', 'in use']
# ['212', 'Chalonnes Suspension Bridge', '1948', 'Chalonnes-sur-Loire (49)', 'France', 'in use']
# ['213', 'Charente Bridge (North Arm)', '2002', 'Jarnac (16)', 'France', 'in use']
# ['214', 'Charente Bridge (South Arm)', '2004', 'Jarnac (16)', 'France', 'in use']
# ['215', 'Charente Viaduct for the A837', '1996', 'Saint-Savinien (17)', 'France', 'in use']
# ['216', 'Chaska Bridge', '2007', 'Chaska (MN)', 'USA', 'in use']
# ['217', 'Château-Gontier Northern Bypass Bridge', '2020', '- Loigné-sur-Mayenne (53)', 'France', 'project phase']
# ['218', 'Châtelard Overpass', '2003', 'Aigle (VD)', 'Switzerland', 'in use']
# ['219', 'Châtelet Viaduct', '1983', 'Châtelet', 'Belgium', 'in use']
# ['220', 'Chatelles Viaduct', '', 'Etival-Clairefontaine (88)', 'France', 'in use']
# ['221', 'Chatillon Bridge', '1951', 'Châtillon-sur-Loire (45)', 'France', 'in use']
# ['222', 'Châtillon Viaduct', '1987', 'Châtillon-en-Michaille (1)', 'France', 'in use']
# ['223', 'Chauvigny Bridge', '1999', 'Chauvigny (86)', 'France', 'in use']
# ['224', 'Chavanon Viaduct', '2000', 'Merlines (19)', 'France', 'in use']
# ['225', 'Chelles Bridge', '2008', 'Chelles (77)', 'France', 'in use']
# ['226', 'Cheongpung Bridge', '2010', 'Jecheon', 'South Korea', 'in use']
# ['227', 'Cheval-Blanc Viaduct', '2001', 'Cheval-Blanc (84)', 'France', 'in use']
# ['228', 'Chienti 2 Viaduct', '2016', 'Muccia (MH)', 'Italy', 'in use']
# ['229', 'Chiers Viaduct', '1987', 'Réhon (54)', 'France', 'in use']
# ['230', 'Chihuly Bridge of Glass', '2002', 'Tacoma (WA)', 'USA', 'in use']
# ['231', 'Chirajara Bridge', '', 'Guayabetal', 'Colombia', 'collapsed']
# ['232', 'Chiusaforte Viaduct', '1986', 'Chiusaforte (FB)', 'Italy', 'in use']
# ['233', 'ChongYang Bridge', '1990', '- New Taipei City', 'Taiwan', 'in use']
# ['234', 'Chorzów Footbridges', '2001', 'Chorzów (SL)', 'Poland', 'in use']
# ['235', 'Choshi Bridge', '2013', '- Choshi', 'Japan', 'in use']
# ['236', 'Chuan Nanpu Bridge', '2003', 'Zhejiang', 'China', 'in use']
# ['237', 'Circle Drive North Bridge', '1983', 'Saskatoon (SK)', 'Canada', 'in use']
# ['238', 'Clain Viaduct', '', 'Poitiers (86)', 'France', 'in use']
# ['239', 'Clain Viaduct', '2005', 'Poitiers (86)', 'France', 'in use']
# ['240', 'Clifton Hill Rail Bridge', '2009', 'Clifton Hill (VIC)', 'Australia', 'in use']
# ['241', 'Cluzan Viaduct', '2005', 'Malemort-sur-Corrèze (19)', 'France', 'in use']
# ['242', 'Cognac Bridge', '1986', 'Cognac (16)', 'France', 'in use']
# ['243', 'Colmar-Berg Viaduct', '2001', 'Colmar-Berg', 'Luxembourg', 'in use']
# ['244', 'Colombo Viaduct', '1996', 'Airole (LG)', 'Italy', 'in use']
# ['245', 'Colosseum-Theater Access Bridge', '1996', 'Essen (NRW)', 'Germany', 'in use']
# ['246', 'Condezaygues Bridge', '', 'Condezaygues (47)', 'France', 'in use']
# ['247', 'Conflans-Sainte-Honorine Bridge', '1976', 'Conflans-Sainte-Honorine (78)', 'France', 'in use']
# ['248', 'Constantine Overpass', '2015', 'Constantine', 'Algeria', 'in use']
# ['249', 'Coop Distribution Center Connecting Bridge', '2016', 'Schafisheim (AG)', 'Switzerland', 'in use']
# ['250', 'Corcelles Viaduct', '2011', 'Saulnot (70)', 'France', 'in use']
# ['251', 'Coretta Viaduct', '1960', 'Barberino di Mugello (TC)', 'Italy', 'in use']
# ['252', 'Crempse Viaduct', '', 'Bourgnac (24)', 'France', 'in use']
# ['253', 'Crescenza Viaduct', '2005', 'Rome (LZ)', 'Italy', 'in use']
# ['254', 'Crestawaldbrücke', '1996', 'Sufers (GR)', 'Switzerland', 'in use']
# ['255', 'Creüe Viaduct', '', 'Lamorville (55)', 'France', 'in use']
# ['256', 'Criquebeuf Viaduct', '1994', 'Criquebeuf-sur-Seine (27)', 'France', 'in use']
# ['257', 'Cross Westchester Expressway Bridge I', '', 'Greenburgh (NY)', 'USA', 'in use']
# ['258', 'Cross Westchester Expressway Bridge II', '', 'White Plains (NY)', 'USA', 'in use']
# ['259', 'Cubzac High-Speed Rail Bridge', '2014', 'Cubzac-les-Ponts (33)', 'France', 'completed']
# ['260', 'Częstochowa Footbridge', '', 'Częstochowa (SL)', 'Poland', 'in use']
# ['261', 'D 433 Bridge', '', 'Brunstatt (68)', 'France', 'in use']
# ['262', 'D-201 Skalité Road Bridge', '', 'Skalité', 'Slovakia', 'in use']
# ['263', 'D-204 Skalité Road Bridge', '', 'Skalité', 'Slovakia', 'in use']
# ['264', 'D1 Motorway Bridge across Hlásenec Creeek', '2008', 'Loucka', 'Czechia', 'in use']
# ['265', 'D1 Motorway Bridge over Opava River', '2007', 'Ostrava', 'Czechia', 'in use']
# ['266', 'D1 Motorway Bridge over Rojek pond and railway line', '2007', 'Ostrava', 'Czechia', 'in use']
# ['267', 'D1 Odra River Motorway Bridge', '2003', 'Ostrava', 'Czechia', 'in use']
# ['268', 'D1 Ostravice River Motorway Bridge', '2007', 'Ostrava', 'Czechia', 'in use']
# ['269', 'D59 Railroad Overpass', '', 'Pierrelatte (26)', 'France', 'in use']
# ['270', 'D8 Trmice Motorway Viaduct', '', '- Trmice', 'Czechia', 'in use']
# ['271', 'Dagersheim Footbridge', '2015', 'Böblingen (BW)', 'Germany', 'in use']
# ['272', 'Dagu River Bridge', '1977', 'Shandong', 'China', 'in use']
# ['273', 'Dala Gorge Bridge', '1989', '- Varen (VS)', 'Switzerland', 'in use']
# ['274', 'Dambach Viaduct', '2005', 'Sankt Kilian (TH)', 'Germany', 'in use']
# ['275', 'Dammühlenweg Bridge', '', 'Haldensleben (ST)', 'Germany', 'in use']
# ['276', 'Daolasa Viaduct', '2003', 'Commezzadura (TT)', 'Italy', 'in use']
# ['277', 'Deelbögebrücke', '2013', 'Hamburg (HH)', 'Germany', 'in use']
# ['278', 'Delta Ponds Pedestrian Bridge', '2010', 'Eugene (OR)', 'USA', 'in use']
# ['279', 'Deltebre Bridge', '2009', "Sant Jaume d'Enveja", 'Spain', 'in use']
# ['280', 'Demorieux Footbridge', '2003', 'Le Mans (72)', 'France', 'in use']
# ['281', 'Dessau-Süd Overpass', '1998', '- Raguhn-Jeßnitz (ST)', 'Germany', 'in use']
# ['282', 'Dexter Coffin Jr. Bridge', '1959', '- Windsor Locks (CT)', 'USA', 'in use']
# ['283', 'Diatomea Footbridge', '2016', 'Los Lagos', 'Chile', 'in use']
# ['284', 'Diepmannsbach Bridge at Remscheid-Lennep', '1995', 'Remscheid (NRW)', 'Germany', 'in use']
# ['285', 'Directional Ramp Across AP-9 Motorway at Santiago de Compostela', '', 'Santiago de Compostela', 'Spain', 'in use']
# ['286', 'Ditgesbaach Viaduct', '', 'Ettelbruck', 'Luxembourg', 'in use']
# ['287', 'Diveria Viaduct', '2006', 'Verbano-Cusio-Ossola (PM)', 'Italy', 'in use']
# ['288', 'Dora Baltea Viaduct', '2013', 'Saluggia (PM)', 'Italy', 'in use']
# ['289', 'Dorlar Viaduct', '2019', 'Lahnau (HE)', 'Germany', 'in use']
# ['290', 'Dos Valires Tunnel Access Bridge', '2012', 'Encamp', 'Andorra', 'in use']
# ['291', 'Douai Bridge', '1982', 'Lambres-lez-Douai (59)', 'France', 'in use']
# ['292', 'Doublement du viaduc de Beauregard', '', 'Thionville (57)', 'France', 'in use']
# ['293', 'Douime Viaduct', '2003', 'Azerat (24)', 'France', 'in use']
# ['294', 'Dozza Footbridge', '2009', 'Bologna (ER)', 'Italy', 'in use']
# ['295', 'Dragon Bridge', '2008', 'Recklinghausen (NRW)', 'Germany', 'in use']
# ['296', 'Dragon Gate Bridge', '2010', 'Chongqing', 'China', 'in use']
# ['297', 'Dreirosen Bridge', '2004', 'Basel (BS)', 'Switzerland', 'in use']
# ['298', 'Dresden Elbe Bridge', '1936', 'Dresden (SN)', 'Germany', 'demolished']
# ['299', 'Drolshagen-Eichenermühle Cycleway Bridge', '2018', 'Drolshagen (NRW)', 'Germany', 'in use']
# ['300', 'Drome Viaduct', '2001', 'Crest (26)', 'France', 'in use']
# ['301', 'Dublin Link', '2020', 'Dublin (OH)', 'USA', 'in use']
# ['302', 'Dultenaugrabenbrücke', '2002', 'Rheinfelden (Baden) (BW)', 'Germany', 'in use']
# ['303', 'Dundas Street Bridge', '', 'Quinte West (ON)', 'Canada', 'in use']
# ['304', 'Durance Viaduct', '2005', 'Embrun (5)', 'France', 'in use']
# ['305', 'East Fork White River Bridge', '2002', 'Columbus (IN)', 'USA', 'in use']
# ['306', 'East Huntington Bridge', '1985', 'Huntington (WV)', 'USA', 'in use']
# ['307', 'Echinghen Viaduct', '1997', 'Saint-Léonard (62)', 'France', 'in use']
# ['308', 'Eibar Footbridge I', '2020', 'Eibar', 'Spain', 'in use']
# ['309', 'Eibar Footbridge II', '2020', 'Eibar', 'Spain', 'in use']
# ['310', 'Eilandbrug', '2003', 'Kampen', 'Netherlands', 'in use']
# ['311', 'Einhausen Werra Viaduct', '2003', '- Einhausen (TH)', 'Germany', 'in use']
# ['312', 'Einsiedelstein Viaduct', '2008', 'Wermelskirchen (NRW)', 'Germany', 'in use']
# ['313', 'Eisenbahnüberführung Lindenthaler Straße', '2004', 'Leipzig (SN)', 'Germany', 'in use']
# ['314', 'El Carrizo Bridge', '2012', 'Sinaloa (SIN)', 'Mexico', 'in use']
# ['315', 'El Hachef Viaduct', '2018', 'Tanger-Tétouan-Al Hoceïma', 'Morocco', 'in use']
# ['316', 'El Mek Nimir Bridge', '2007', 'Khartoum', 'Sudan', 'in use']
# ['317', 'Elbebrücke Dresden', '1998', 'Dresden (SN)', 'Germany', 'in use']
# ['318', 'Elben Viaduct', '2005', 'Wenden (NRW)', 'Germany', 'in use']
# ['319', 'Eldetalbrücke Grabow', '2018', 'Grabow (MV)', 'Germany', 'in use']
# ['320', 'Elizabeth River Viaduct', '', 'Elizabeth (NJ)', 'USA', 'in use']
# ['321', 'Elle Viaduct', '2007', 'Villac (24)', 'France', 'in use']
# ['322', 'Elpidio de Almeida Bridge', '2008', 'Campina Grande (PB)', 'Brazil', 'in use']
# ['323', 'Eltmann Bridge', '1987', 'Eltmann (BY)', 'Germany', 'in use']
# ['324', 'Emamzadeh Hassan Bridge', '1996', 'Tehran', 'Iran', 'in use']
# ['325', 'Emäsalo Bridge', '', 'Porvoo', 'Finland', 'in use']
# ['326', 'Endarlatsa Bridge', '2009', '- Gipuzkoa', 'Spain', 'in use']
# ['327', 'English Bridge', '', '- Łęknica (LB)', 'Poland', 'in use']
# ['328', 'Enrique de la Mata Gorostizaga Bridge', '1970', 'Madrid', 'Spain', 'in use']
# ['329', 'Entrevías Footbridge I', '', 'Madrid', 'Spain', 'in use']
# ['330', 'Entrevías Footbridge II', '', 'Madrid', 'Spain', 'in use']
# ['331', 'Entrevias Footbridge III', '', 'Madrid', 'Spain', 'in use']
# ['332', 'Epenottes Viaduct', '2011', 'Vyans-le-Val (70)', 'France', 'in use']
# ['333', 'Erasmusrand Pedestrian bridge', '2019', 'Pretoria', 'South Africa', 'in use']
# ['334', 'Erdre Bridge', '1993', '- La Chapelle-sur-Erdre (44)', 'France', 'in use']
# ['335', 'Erlenstrasse Footbridge', '1965', 'Gladbeck (NRW)', 'Germany', 'in use']
# ['336', 'Erques Viaduct', '2015', 'Adeje', 'Spain', 'in use']
# ['337', 'Erste Ellerholzrampe', '2002', 'Hamburg (HH)', 'Germany', 'in use']
# ['338', 'Erwin-Fuchs-Brücke', '', 'Heilbronn (BW)', 'Germany', 'in use']
# ['339', 'Escaleritas Viaduct', '2006', 'Las Palmas de Gran Canaria', 'Spain', 'in use']
# ['340', 'Eschenlohe Bridge', '2006', 'Eschenlohe (BY)', 'Germany', 'in use']
# ['341', 'Escudo Viaduct', '2001', 'San Vicente de la Barquera', 'Spain', 'in use']
# ['342', 'Eskilstuna West Bridge', '2016', 'Eskilstuna', 'Sweden', 'in use']
# ['343', 'Esperance Bridge', '2021', 'London (GB-ENG)', 'United Kingdom', 'in use']
# ['344', 'Essalam-Salé Tramway Bridge', '2020', 'Salé', 'Morocco', 'in use']
# ['345', 'Essômes-sur-Marne Viaduct', '2006', 'Essômes-sur-Marne (2)', 'France', 'in use']
# ['346', 'Estacade du Vicoin', '2014', '- Saint-Berthevin (53)', 'France', 'completed']
# ['347', 'Este River Bridge (A26)', '2018', 'Buxtehude (NI)', 'Germany', 'completed']
# ['348', 'Ettelbruck Sûre River Rail Bridge', '2019', 'Ettelbruck', 'Luxembourg', 'in use']
# ['349', 'Exeter Bypass Bridge', '', 'Exeter (GB-ENG)', 'United Kingdom', 'in use']
# ['350', 'Fachbach Bridge', '2002', 'Bad Ems (RP)', 'Germany', 'in use']
# ['351', 'Falaise Bridge', '1993', 'Falaise (14)', 'France', 'in use']
# ['352', 'Fardes Reservoir Intake Tower Bridge', '1996', 'La Peza', 'Spain', 'in use']
# ['353', 'Father Louis Hennepin Bridge', '1990', 'Minneapolis (MN)', 'USA', 'in use']
# ['354', 'Fayrac Bridge', '2020', '- Vézac (24)', 'France', 'under construction']
# ['355', 'Fengjie Meixi River Bridge', '2000', 'Chongqing', 'China', 'in use']
# ['356', 'Fifth Amol Bridge', '', 'Amol', 'Iran', 'in use']
# ['357', 'Firth of Tay Road Bridge', '1966', '- Newport-on-Tay (GB-SCT)', 'United Kingdom', 'in use']
# ['358', 'Fischerdorf Bridge', '1991', 'Deggendorf (BY)', 'Germany', 'in use']
# ['359', "Fisher's Bridge", '1996', 'Mount Pleasant (MI)', 'USA', 'in use']
# ['360', 'Flora Bridge', '2019', 'Ottawa (ON)', 'Canada', 'in use']
# ['361', 'Floreffe Bridge', '', 'Floreffe', 'Belgium', 'in use']
# ['362', 'Floride Railroad Bridge', '', 'Bayonne (64)', 'France', 'in use']
# ['363', 'Flügelwegbrücke', '2004', 'Dresden (SN)', 'Germany', 'in use']
# ['364', 'Footbridge "Asubio"', '', 'Oleiros', 'Spain', 'in use']
# ['365', 'Footbridge across Avenida das Nacoes Unidas', '2014', 'São Paulo (SP)', 'Brazil', 'in use']
# ['366', 'Footbridge across B463', '2014', 'Calw (BW)', 'Germany', 'in use']
# ['367', 'Footbridge across Mia-Seeger-Strasse', '1993', 'Stuttgart (BW)', 'Germany', 'in use']
# ['368', 'Footbridge across the "Langer See" lake', '2016', '- Böblingen (BW)', 'Germany', 'in use']
# ['369', 'Footbridge across the B33', '', 'Konstanz (BW)', 'Germany', 'in use']
# ['370', 'Footbridge across the S8', '', 'Warsaw (MZ)', 'Poland', 'in use']
# ['371', 'Footbridge across the Scarpe', '2019', 'Arras (62)', 'France', 'in use']
# ['372', 'Footbridge over the A-2', '2008', 'Guadalajara', 'Spain', 'in use']
# ['373', 'Footbridge over the Charles-de-Gaulle-Strasse', '2003', 'Bonn (NRW)', 'Germany', 'in use']
# ['374', 'Footbridge over Wilcza Street', '', 'Szczecin (ZP)', 'Poland', 'in use']
# ['375', 'Fornace Viaduct', '2007', 'Albino (LM)', 'Italy', 'in use']
# ['376', 'Fornello Viaduct', '2011', 'Verghereto (ER)', 'Italy', 'in use']
# ['377', 'Fort Duquene Bridge North Approach Viaducts', '1970', 'Pittsburgh (PA)', 'USA', 'in use']
# ['378', 'Fort Nelson River Bridge', '2004', 'Fort Nelson (BC)', 'Canada', 'in use']
# ['379', 'Fosso delle Coste Viaduct', '1996', 'Sarsina (ER)', 'Italy', 'in use']
# ['380', 'Fourth Xiangtan Bridge', '2007', 'Xiangtan', 'China', 'in use']
# ['381', 'Fozières Motorway Bridge', '', 'Fozières (34)', 'France', 'in use']
# ['382', 'Frachthofknotenbrücke', '2005', 'Stuttgart (BW)', 'Germany', 'in use']
# ['383', 'Frâncești Bridge', '', 'Frâncești', 'Romania', 'in use']
# ['384', 'Francisco Aura Boronat Bridge', '2014', 'Alcoy', 'Spain', 'in use']
# ['385', 'Franjo Tudjman Bridge', '2002', 'Dubrovnik', 'Croatia', 'in use']
# ['386', 'Frankfurt-Slubice Bridge', '2002', 'Frankfurt on the Oder (BB)', 'Germany', 'in use']
# ['387', 'Franzosenbrücke', '2012', 'Gera (TH)', 'Germany', 'in use']
# ['388', 'Frauental Overpass', '2010', 'Frauental an der Laßnitz (STM)', 'Austria', 'in use']
# ['389', 'Frédéric Mistral Bridge', '1967', 'Valence (26)', 'France', 'in use']
# ['390', 'Friarton Bridge', '1978', 'Perth (GB-SCT)', 'United Kingdom', 'in use']
# ['391', 'Friedaubrücke', '', 'Chur (GR)', 'Switzerland', 'in use']
# ['392', 'Friedberg Overpass', '2008', 'Friedberg (Hessen) (HE)', 'Germany', 'in use']
# ['393', 'Friedrich-Ebert-Strasse Overpass', '2017', 'Recklinghausen (NRW)', 'Germany', 'in use']
# ['394', 'Friedrichsbrücke', '1982', 'Berlin (BE)', 'Germany', 'in use']
# ['395', 'Friendship Bridge at Kleinblittersdorf', '1993', 'Kleinblittersdorf (SL)', 'Germany', 'in use']
# ['396', 'Frocourt Viaduct', '2005', 'Frocourt (60)', 'France', 'in use']
# ['397', 'Fruttlibrücke', '2020', 'Arth (SZ)', 'Switzerland', 'in use']
# ['398', 'Fudo Bridge', '2010', 'Gunma', 'Japan', 'in use']
# ['399', 'Fuenlabrada Footbridge', '2005', 'Fuenlabrada', 'Spain', 'in use']
# ['400', 'Fumay Railroad Bridge', '', 'Fumay (8)', 'France', 'in use']
# ['401', 'G4 Bridge', '2007', 'Thesprotia', 'Greece', 'in use']
# ['402', 'Gabriel Narutowicz Viaduct', '2003', 'Poznań (WP)', 'Poland', 'in use']
# ['403', 'Gądki Footbridge', '2007', 'Gądki (WP)', 'Poland', 'in use']
# ['404', 'Gahmener Strasse Bridge', '2021', 'Lünen (NRW)', 'Germany', 'under construction']
# ['405', 'Gaillac Bridge', '', 'Cajarc (46)', 'France', 'in use']
# ['406', 'Galgenbergbrücke', '2003', 'Regensburg (BY)', 'Germany', 'in use']
# ['407', 'Galp Energia Footbridge', '2014', 'Lisbon', 'Portugal', 'in use']
# ['408', 'Ganslandsiepen Viaduct', '2015', 'Heiligenhaus (NRW)', 'Germany', 'in use']
# ['409', 'Gaoming Bridge', '1991', 'Gaoming', 'China', 'in use']
# ['410', 'Garabit Bridge', '', 'Loubaresse (15)', 'France', 'in use']
# ['411', 'Gardon Viaduct', '', 'Montfrin (30)', 'France', 'in use']
# ['412', 'Gargan Viaduct', '2006', 'Livry-Gargan (93)', 'France', 'in use']
# ['413', 'Gärtnerplatzbrücke', '2007', 'Kassel (HE)', 'Germany', 'in use']
# ['414', 'Gäsibrücke', '1959', 'Glaris (GL)', 'Switzerland', 'in use']
# ['415', 'Gatineau Parc Covered Bridge', '1958', 'Sainte-Cécile-de-Masham (QC)', 'Canada', 'in use']
# ['416', 'Gauchachtalbrücke Döggingen', '2002', 'Bräunlingen (BW)', 'Germany', 'in use']
# ['417', 'GAV Bridge', '2004', 'Villach (KTN)', 'Austria', 'in use']
# ['418', 'Gaztelako Atea Rail Bridge', '', 'Vitoria-Gasteiz', 'Spain', 'in use']
# ['419', 'Geel Bridge', '2013', '- Geel', 'Belgium', 'in use']
# ['420', 'Gehannesbour Viaduct', '2001', 'Perl (SL)', 'Germany', 'in use']
# ['421', 'Gemünden Bridge', '2018', 'Gemünden am Main (BY)', 'Germany', 'in use']
# ['422', 'Genil River Bridge', '2007', 'Granada', 'Spain', 'in use']
# ['423', 'Georges Clémenceau Bridge', '1952', 'Lyon (69)', 'France', 'in use']
# ['424', 'Georges Clémenceau Bridge', '1966', 'Nantes (44)', 'France', 'in use']
# ['425', 'Giano Viaduct', '2003', 'Fabriano (MH)', 'Italy', 'in use']
# ['426', 'Gießen Footbridge', '2014', 'Gießen (HE)', 'Germany', 'in use']
# ['427', 'Giffre Viaduct', '2018', 'Marignier (74)', 'France', 'in use']
# ['428', 'Giovanni Paolo II Bridge', '2007', 'Pesaro (MH)', 'Italy', 'in use']
# ['429', 'Glaasbuurgronn Viaduct', '2002', 'Niederanven', 'Luxembourg', 'in use']
# ['430', 'Glennerbrücke (RhB)', '1960', 'Ilanz (GR)', 'Switzerland', 'in use']
# ['431', 'Gletschersandbrücke', '2018', 'Grindelwald (BE)', 'Switzerland', 'in use']
# ['432', 'Gobba Bridge', '1995', 'City of Wagga Wagga (NSW)', 'Australia', 'in use']
# ['433', 'Goldswil Viaduct', '1983', 'Interlaken (BE)', 'Switzerland', 'in use']
# ['434', 'Gollstrasse Bridge', '1999', 'Hanover (NI)', 'Germany', 'in use']
# ['435', 'Golo Bridge', '', 'Lucciana (2B)', 'France', 'in use']
# ['436', 'Gordie Howe Bridge', '2013', 'Saskatoon (SK)', 'Canada', 'in use']
# ['437', 'Goutte Vignole Viaduct', '2011', "- Saint-Marcel-l'Éclairé (69)", 'France', 'in use']
# ['438', 'Governor Mario M. Cuomo Bridge', '2018', '- Nyack (NY)', 'USA', 'in use']
# ['439', 'Gragnola Viaduct', '2017', 'Fivizzano (TC)', 'Italy', 'in use']
# ['440', 'Grand Canal Bridge at Le Havre', '1994', 'Le Havre (76)', 'France', 'in use']
# ['441', 'Granger Road Pedestrian Overpass', '', 'Valley View (OH)', 'USA', 'in use']
# ['442', 'Granyanella Footbridge', '1993', 'Granyanella', 'Spain', 'in use']
# ['443', 'Greisselbach Overpass', '', 'Mühlhausen (BY)', 'Germany', 'in use']
# ['444', 'Grimsel Lake Bridge', '', 'Guttannen (BE)', 'Switzerland', 'unrealized project']
# ['445', 'Grosser Kolonnenweg Road Bridge', '1998', 'Hanover (NI)', 'Germany', 'in use']
# ['446', 'Grossharthau Overpass', '2021', 'Großharthau (SN)', 'Germany', 'in use']
# ['447', 'Groussheck Viaduct', '2002', 'Niederanven', 'Luxembourg', 'in use']
# ['448', 'Grünhaufen Bridge', '1994', 'Vienna', 'Austria', 'in use']
# ['449', 'Gschnitztalbrücke', '', 'Steinach am Brenner (TIR)', 'Austria', 'in use']
# ['450', 'Guanyin-Kengxi Bridge', '', 'New Taipei City', 'Taiwan', 'in use']
# ['451', 'Guarda Footbridge', '2007', 'Guarda', 'Portugal', 'in use']
# ['452', 'Guerville Viaduct', '2020', 'Guerville (78)', 'France', 'in use']
# ['453', 'Guiche Bridge', '', 'Guiche (64)', 'France', 'in use']
# ['454', 'Gustave Eiffel Bridge', '', 'Grasse (6)', 'France', 'in use']
# ['455', 'Hafenbahn Bridge', '2003', 'Duisburg (NRW)', 'Germany', 'in use']
# ['456', 'Haiger Bridge', '2002', 'Haiger (HE)', 'Germany', 'in use']
# ['457', 'Haipesawa Bridge', '2014', 'Tanohata', 'Japan', 'in use']
# ['458', 'Halfway River Bridge', '2022', 'British Columbia (BC)', 'Canada', 'under construction']
# ['459', 'Ham Bridge', '1997', 'Ham-sur-Meuse (8)', 'France', 'in use']
# ['460', 'Hamilton Bridge Overfly', '', 'New York (NY)', 'USA', 'in use']
# ['461', 'Hammacherstrasse Bridge', '2018', 'Hagen (NRW)', 'Germany', 'in use']
# ['462', 'Hangbrücke Simmelsdorf', '1997', 'Simmelsdorf (BY)', 'Germany', 'in use']
# ['463', 'Hangbrücke Würgau', '1993', 'Scheßlitz (BY)', 'Germany', 'in use']
# ['464', 'Hannover-Stöcken Eastern Bypass Bridge', '1992', 'Hanover (NI)', 'Germany', 'in use']
# ['465', 'Hanover-Herrenhausen Overpass', '1992', 'Hanover (NI)', 'Germany', 'in use']
# ['466', 'Hanover-Stöcken Bridge (B6)', '1992', 'Hanover (NI)', 'Germany', 'in use']
# ['467', 'Harchies Bridge', '2014', 'Bernissart', 'Belgium', 'in use']
# ['468', 'Hardter Brücke', '1961', 'Dorsten (NRW)', 'Germany', 'in use']
# ['469', 'Haseltalbrücke', '2006', 'Suhl (TH)', 'Germany', 'in use']
# ['470', 'Hasenpohl Viaduct', '', 'Königswinter (NRW)', 'Germany', 'in use']
# ['471', 'Haspelbaechel Viaduct', '2013', 'Eckartswiller (67)', 'France', 'in use']
# ['472', 'Hassmersheim Footbridge', '2014', 'Haßmersheim (BW)', 'Germany', 'in use']
# ['473', 'Hattingen Bridge', '1937', 'Hattingen (NRW)', 'Germany', 'demolished']
# ['474', 'Haufertsgraben Bridge', '2011', 'Traunstein (BY)', 'Germany', 'in use']
# ['475', 'Haute-Colme Viaduct', '1992', 'Watten (59)', 'France', 'in use']
# ['476', 'He Ara Kotahi Bridge', '', 'Palmerston North', 'New Zealand', 'in use']
# ['477', 'Hechuan Jialingjiang Bridge', '', 'Chongqing', 'China', 'in use']
# ['478', 'Hedemünden Rail Viaduct', '1993', 'Hann. Münden (NI)', 'Germany', 'in use']
# ['479', 'Hedemünden Viaduct', '1952', 'Hann. Münden (NI)', 'Germany', 'demolished']
# ['480', 'Hedemünden Viaduct', '1993', 'Hann. Münden (NI)', 'Germany', 'in use']
# ['481', 'Heer-Agimont Bridge', '1973', 'Heer', 'Belgium', 'in use']
# ['482', 'Heerstraßenbrücke', '2006', 'Stuttgart (BW)', 'Germany', 'in use']
# ['483', 'Heidingsfeld Viaduct', '2020', 'Würzburg (BY)', 'Germany', 'under construction']
# ['484', 'Heidingsfeld Viaduct', '1963', 'Würzburg (BY)', 'Germany', 'in use']
# ['485', 'Heilbronn Viaduct (A6)', '2022', 'Neckarsulm (BW)', 'Germany', 'in use/under construction']
# ['486', 'Heisei Memorial Bridge', '1992', 'Toyota', 'Japan', 'in use']
# ['487', 'Hemboog', '2003', 'Amsterdam', 'Netherlands', 'in use']
# ['488', 'Henry Grenet Bridge', '1993', 'Bayonne (64)', 'France', 'in use']
# ['489', 'Herbstwiesenweg Footbridge', '2020', 'Erlangen (BY)', 'Germany', 'in use']
# ['490', 'Herdecke Bridge', '1951', 'Herdecke (NRW)', 'Germany', 'in use']
# ['491', 'Hermann Gladenbeck Bridge', '', 'Berlin (BE)', 'Germany', 'in use']
# ['492', 'Hermann Liebmann Bridge', '2004', 'Leipzig (SN)', 'Germany', 'in use']
# ['493', 'Herstal Bridge', '', 'Liège', 'Belgium', 'in use']
# ['494', 'High Road Bridge', '2008', 'Lockport Township (IL)', 'USA', 'in use']
# ['495', 'Highway Bridge No. 366', '1981', 'Castrop-Rauxel (NRW)', 'Germany', 'in use']
# ['496', 'Highway Bridge No. 704', '1936', 'Duisburg (NRW)', 'Germany', 'demolished']
# ['497', 'Highway Bridge over the Dahme at Niederlehme', '2002', 'Königs Wusterhausen (BB)', 'Germany', 'in use']
# ['498', 'Himi Bridge', '2004', 'Nagasaki', 'Japan', 'in use']
# ['499', 'Hindenburgstrasse Bridge', '2003', 'Pöcking (BY)', 'Germany', 'in use']
# ['500', 'Hindmarsh Island Bridge', '2001', 'Goolwa (SA)', 'Australia', 'in use']
# ['501', 'Hisingsbron', '2022', 'Gothenborg', 'Sweden', 'project phase']
# ['502', 'Hlásná Třebaň Footbridge', '', 'Hlásná Třebaň', 'Czechia', 'project phase']
# ['503', 'Hledan Flyover', '2013', 'Yangôn', 'Myanmar', 'in use']
# ['504', 'Hochbuchbrücke', '', 'Heilbronn (BW)', 'Germany', 'in use']
# ['505', 'Hogeweidebrug', '2008', 'Utrecht', 'Netherlands', 'in use']
# ['506', 'Hohe Brücke', '2011', 'Blaichach (BY)', 'Germany', 'in use']
# ['507', 'Hohenwarthe Viaduct', '1997', 'Möser (ST)', 'Germany', 'in use']
# ['508', 'Hohenzollerndammbrücke (A 100)', '2002', 'Berlin (BE)', 'Germany', 'in use']
# ['509', 'Hollandsch Diep High Speed Rail Bridge', '2005', 'Moerdijk', 'Netherlands', 'in use']
# ['510', 'Hontani Bridge', '1998', 'Gifu', 'Japan', 'in use']
# ['511', "Hôpital-sur-Rhins Viaduct l'", '', 'Saint-Cyr-de-Favières (42)', 'France', 'in use']
# ['512', 'Horotiu Paa Bridge', '2016', 'Cambridge', 'New Zealand', 'in use']
# ['513', 'Horsterdamm Bridge', '2014', 'Lauenburg (SH)', 'Germany', 'in use']
# ['514', 'Hričov Canal D1 Motorway Viaduct', '2010', 'Považská Bystrica', 'Slovakia', 'in use']
# ['515', 'Huangbohe Bridge', '1996', 'Yichang', 'China', 'in use']
# ['516', 'Hubert Touya Bridge', '2011', 'Bayonne (64)', 'France', 'in use']
# ['517', 'Hudälvenbro', '2010', 'Tanum', 'Sweden', 'in use']
# ['518', 'Hundwilertobelbrücke', '1992', 'Hundwil (AR)', 'Switzerland', 'in use']
# ['519', 'Huron Parkway Bridge', '1968', 'Ann Arbor (MI)', 'USA', 'in use']
# ['520', "Hyères Viaduct l'", '2003', 'Carhaix-Plouguer (29)', 'France', 'in use']
# ['521', 'Hygna Bridge', '1967', 'Reith im Alpbachtal (TIR)', 'Austria', 'in use']
# ['522', 'I-435 Missouri River Bridge', '', 'Kansas City (MO)', 'USA', 'in use']
# ['523', 'I-94 Saint Croix River Bridge', '1995', 'Hudson (WI)', 'USA', 'in use']
# ['524', 'I-95 Androscoggin River Bridge', '1955', 'Lewiston (ME)', 'USA', 'in use']
# ['525', 'I/11 Hrabyňka Creek Bridge', '', 'Hrabyně', 'Czechia', 'under construction']
# ['526', 'I/11 Kremlice Creek Bridge', '', 'Velká Polom', 'Czechia', 'under construction']
# ['527', 'Igor I. Sikorsky Memorial Bridge', '2003', 'Stratford (CT)', 'USA', 'in use']
# ['528', 'Ikuno Bridge', '', 'Kobe', 'Japan', 'in use']
# ['529', 'Ilonse Bridge', '2010', 'Ilonse (6)', 'France', 'in use']
# ['530', 'Ilzbrücke Passau', '2009', 'Passau (BY)', 'Germany', 'in use']
# ['531', 'Imarsund Bridge', '2007', 'Tustna', 'Norway', 'in use']
# ['532', 'Imja Bridge, First', '2020', 'South Jeolla', 'South Korea', 'in use']
# ['533', 'Imja Bridge, Second', '2020', 'South Jeolla', 'South Korea', 'in use']
# ['534', 'Immensitzbrücke (A81)', '2017', 'Geisingen (BW)', 'Germany', 'in use']
# ['535', "Incile dell'Arno Viaduct", '1990', 'Pisa (TC)', 'Italy', 'in use']
# ['536', 'Ingeldorf Viaduct', '1986', 'Erpeldange-sur-Sûre', 'Luxembourg', 'in use']
# ['537', 'Ingolstadt Rail Bridge', '2002', 'Ingolstadt (BY)', 'Germany', 'in use']
# ['538', 'Innbrücke Landeck', '2009', 'Landeck (TIR)', 'Austria', 'in use']
# ['539', 'Inntalbrücke', '1993', 'Innsbruck (TIR)', 'Austria', 'in use']
# ['540', 'Inseliquai Footbridge', '', 'Lucerne (LU)', 'Switzerland', 'in use']
# ['541', 'Interstate 95 Brandywine Creek Bridge', '1968', 'Wilmington (DE)', 'USA', 'in use']
# ['542', 'Intrepid Sea Museum Footbridge', '', 'New York (NY)', 'USA', 'in use']
# ['543', 'Irbich Viaduct', '2022', 'Clervaux', 'Luxembourg', 'under construction']
# ['544', 'Isando Pedestrian Bridge', '2013', 'Ekurhuleni', 'South Africa', 'in use']
# ['545', 'Isarbrücke Dingolfing', '2000', 'Dingolfing (BY)', 'Germany', 'in use']
# ['546', 'Isardückerbrücke', '', 'Munich (BY)', 'Germany', 'in use']
# ['547', 'Isère Viaduct', '1993', 'Clérieux (26)', 'France', 'in use']
# ['548', 'Iztueta Kalea Rail Overpass', '', 'San Sebastián', 'Spain', 'in use']
# ['549', 'Jablunkov Railroad Bridge', '2009', 'Jablunkov', 'Czechia', 'in use']
# ['550', 'Jackfield Bridge', '1994', 'Ironbridge (GB-ENG)', 'United Kingdom', 'in use']
# ['551', 'James D. Pfluger Pedestrian Bridge', '2001', 'Austin (TX)', 'USA', 'in use']
# ['552', 'Jannello Viaduct', '2016', 'Cosenza (CI)', 'Italy', 'in use']
# ['553', 'Jargeau Bridge', '1988', 'Jargeau (45)', 'France', 'in use']
# ['554', 'Jarmen Bridge', '2012', 'Jarmen (MV)', 'Germany', 'in use']
# ['555', 'Jarmen Viaduct', '2001', 'Jarmen (MV)', 'Germany', 'in use']
# ['556', 'Jassans-Riottier Bridge', '2000', 'Jassans-Riottier (1)', 'France', 'in use']
# ['557', 'Jaulny Viaduct', '2006', 'Jaulny (54)', 'France', 'in use']
# ['558', 'Jean Moulin Bridge', '1989', 'Angers (49)', 'France', 'in use']
# ['559', 'Jean Richard Bridge', '1952', 'Chalon-sur-Saône (71)', 'France', 'in use']
# ['560', 'Jean-Médecin Rail Bridge, Avenue', '', 'Nice (6)', 'France', 'in use']
# ['561', 'Jena-Göschwitz Overpass', '2012', 'Jena (TH)', 'Germany', 'in use']
# ['562', 'Jiantiao Bridge', '', 'Sanmen', 'China', 'under construction']
# ['563', 'John Greenleaf Whittier Bridge', '2018', '- Amesbury (MA)', 'USA', 'in use']
# ['564', 'John V. Tunney Bridge', '2015', 'Los Angeles (CA)', 'USA', 'in use']
# ['565', 'Joigny-sur-Meuse Bridge', '', 'Joigny-sur-Meuse (8)', 'France', 'in use']
# ['566', 'Jökulsá Canyon Bridge', '1994', 'Egilsstaðir', 'Iceland', 'in use']
# ['567', 'José Antonio Aguirre Bridge', '2011', 'San Sebastián', 'Spain', 'in use']
# ['568', 'Josefbrücke', '1998', 'Saarbrücken (SL)', 'Germany', 'in use']
# ['569', 'Joshua Chamberlain Bridge', '1959', 'Bangor (ME)', 'USA', 'in use']
# ['570', 'Joutsen Bridge', '1996', 'Oulu', 'Finland', 'in use']
# ['571', 'Jubilee Bridge', '2002', 'Stockton-on-Tees (GB-ENG)', 'United Kingdom', 'in use']
# ['572', 'Júcar River Bridge', '2007', 'Cullera', 'Spain', 'in use']
# ['573', 'Jungfernheide Rail Bridge', '', '- Berlin (BE)', 'Germany', 'in use']
# ['574', 'Junglinster Viaduct', '2013', 'Junglinster', 'Luxembourg', 'in use']
# ['575', 'K1653 Bridge across the Mittelland Canal', '1997', 'Haldensleben (ST)', 'Germany', 'in use']
# ['576', 'Kahalo Jinsha River Bridge', '', 'Sichuan', 'China', 'under construction']
# ['577', 'Kaldvell Bridge', '2008', 'Lillesand', 'Norway', 'in use']
# ['578', 'Kaligone Overpass', '1994', 'Kingersheim (68)', 'France', 'in use']
# ['579', 'Kalkgraben Bridge at Rüdersdorf', '1996', 'Rüdersdorf bei Berlin (BB)', 'Germany', 'in use']
# ['580', 'Kalvarienbrücke', '1992', 'Graz (STM)', 'Austria', 'in use']
# ['581', 'Kamień Vistula River Bridge', '2015', '- Kamień (LU)', 'Poland', 'in use']
# ['582', 'Kampmann Bridge', '2019', 'Essen (NRW)', 'Germany', 'in use']
# ['583', 'Kanalbrücke', '2017', 'Riedlingen (BW)', 'Germany', 'in use']
# ['584', 'Kap Shui Mun Bridge', '1997', 'Hong Kong', 'China', 'in use']
# ['585', 'Karabel Bridge', '', 'Hernani', 'Spain', 'in use']
# ['586', 'Karl-Heine-Bogen', '2000', 'Leipzig (SN)', 'Germany', 'in use']
# ['587', 'Karolingerbrücke', '2005', 'Karlstadt (BY)', 'Germany', 'in use']
# ['588', 'Katsurajima Viaduct', '2005', 'Shizuoka', 'Japan', 'in use']
# ['589', 'Kauppenbrücke A3', '1959', 'Waldaschaff (BY)', 'Germany', 'demolished']
# ['590', 'Kellog Central Business District Viaduct', '1996', 'Wichita (KS)', 'USA', 'in use']
# ['591', 'Kepplerbrücke', '2000', 'Rottenburg am Neckar (BW)', 'Germany', 'in use']
# ['592', 'Kerstelenbach Viaduct', '1972', 'Silenen (UR)', 'Switzerland', 'in use']
# ['593', 'Khor al Batah Bridge', '2010', 'Sur', 'Oman', 'in use']
# ['594', 'Khorramshahr Bridge', '1991', 'Khorramshahr', 'Iran', 'in use']
# ['595', 'Kinderode Bridge', '1909', 'Nohra (TH)', 'Germany', 'in use']
# ['596', 'Kingsway Footbridge', '', 'Burnaby (BC)', 'Canada', 'in use']
# ['597', 'Kinokawa Viaduct', '2003', 'Shingu', 'Japan', 'in use']
# ['598', 'Kirkonsalmi Bridge', '2002', 'Merimasku', 'Finland', 'in use']
# ['599', 'Kirumi Bridge', '1985', 'Mara', 'Tanzania', 'in use']
# ['600', 'Kleine Elsterflutbrücke (B91)', '2016', 'Halle/Saale (ST)', 'Germany', 'in use']
# ['601', 'Kleine Larchwiesenbrücke', '1996', 'Matrei am Brenner (TIR)', 'Austria', 'in use']
# ['602', 'Klingenberg Bridge', '1949', 'Klingenberg am Main (BY)', 'Germany', 'demolished']
# ['603', 'Klingenthal Ski Bridge', '1997', 'Klingenthal (SN)', 'Germany', 'in use']
# ['604', 'Knocklyon Cable Stay Footbridge', '2000', 'Dublin', 'Ireland', 'in use']
# ['605', 'Kochenbach Viaduct', '', 'Bad Honnef (NRW)', 'Germany', 'in use']
# ['606', 'Koinumarukawa Bridge', '', 'Japan', 'Japan', 'in use']
# ['607', 'Kolbäck Bridge', '', 'Umeå', 'Sweden', 'in use']
# ['608', 'Konstanz Station Footbridge', '2009', 'Konstanz (BW)', 'Germany', 'in use']
# ['609', 'Kopu Bridge', '2011', 'Coromandel', 'New Zealand', 'in use']
# ['610', 'Korabelny Fairway Bridge', '', 'Saint Petersburg', 'Russia', 'under construction']
# ['611', 'Korntal-Münchingen Bridge', '2005', 'Korntal-Münchingen (BW)', 'Germany', 'in use']
# ['612', 'Krzemionki Railway Viaduct', '2017', 'Cracow (MA)', 'Poland', 'in use']
# ['613', 'Kuchl Overpass', '2008', 'Kuchl (SBG)', 'Austria', 'in use']
# ['614', 'Kuokkala Bridge', '1989', 'Jyväskylä', 'Finland', 'in use']
# ['615', 'Kurobegawa Bridge', '2004', '- Nyūzen', 'Japan', 'in use']
# ...
# ['1302', 'Trapagaran Viaduct', '2010', 'Valle de Trápaga-Trapagaran', 'Spain', 'in use']
# ['1303', 'Trauntalbrücke', '2012', 'Traunstein (BY)', 'Germany', 'in use']
# ['1304', 'Trenton-Morrisville Route 1 Toll Bridge', '1952', 'Trenton (NJ)', 'USA', 'in use']
# ['1305', 'Tréry Viaduct', '', 'Vinay (38)', 'France', 'in use']
# ['1306', 'Triel-sur-Seine Bridge', '2003', 'Triel-sur-Seine (78)', 'France', 'in use']
# ['1307', 'Trinità Viaduct', '2007', 'Albino (LM)', 'Italy', 'in use']
# ['1308', 'Trinquetaille Bridge', '1951', 'Arles (13)', 'France', 'in use']
# ['1309', 'Trois-Puits Railroad Overpass', '2010', 'Trois-Puits (51)', 'France', 'in use']
# ['1310', 'Trowell Railroad Bridge', '', 'Trowell (GB-ENG)', 'United Kingdom', 'in use']
# ['1311', 'Tsakona Bridge', '2016', 'Oichalia', 'Greece', 'in use']
# ['1312', 'Tuiranväylä Footbridge', '1985', 'Oulu', 'Finland', 'in use']
# ['1313', 'Turia River Bridge (AP-7)', '', '- Paterna', 'Spain', 'in use']
# ['1314', 'Turia River Bridge (N-220)', '1992', '- Paterna', 'Spain', 'in use']
# ['1315', 'Txomin-Enea Bridge', '', 'San Sebastián', 'Spain', 'project']
# ['1316', 'U.S. 20 Swinomish Channel Bridge', '', 'Anacortes (WA)', 'USA', 'in use']
# ['1317', 'Überführung der B 105 über die BAB A 19', '2000', 'Bentwisch (MV)', 'Germany', 'in use']
# ['1318', 'Uddevalla Bridge', '2000', 'Uddevalla', 'Sweden', 'in use']
# ['1319', 'Uichteritz-Leißling Footbridge', '2016', 'Weißenfels (ST)', 'Germany', 'in use']
# ['1320', 'Ulla Estuary Viaduct', '2015', 'Catoira', 'Spain', 'in use']
# ['1321', 'Unionbrücke', '2000', 'Dresden (SN)', 'Germany', 'in use']
# ['1322', 'United States Naval Academy Bridge', '1995', 'Annapolis (MD)', 'USA', 'in use']
# ['1323', 'University District Gateway Bridge', '', 'Spokane (WA)', 'USA', 'in use']
# ['1324', 'Unstrutbrücke Nebra (B250)', '2017', 'Nebra (Unstrut) (ST)', 'Germany', 'in use']
# ['1325', 'Untermassfeld Bridge', '2004', 'Untermaßfeld (TH)', 'Germany', 'in use']
# ['1326', 'Ural River Bridge', '1998', 'Oral', 'Kazakhstan', 'in use']
# ['1327', 'Urçay Bridge', '1994', 'Urçay (3)', 'France', 'in use']
# ['1328', 'Urumea River Bridge, Sixth', '2010', 'San Sebastián', 'Spain', 'in use']
# ['1329', 'Urumea River Rail Bridge', '2016', 'San Sebastián', 'Spain', 'in use']
# ['1330', 'Usses Viaduct', '2008', 'Cruseilles (74)', 'France', 'in use']
# ['1331', 'Utsumi Bridge', '1988', 'Fukuyama', 'Japan', 'in use']
# ['1332', 'Val-de-Seine Tramway Bridge', '2006', 'Suresnes (92)', 'France', 'in use']
# ['1333', 'Val-Saint-Léger Viaduct', '2003', 'Saint-Germain-en-Laye (78)', 'France', 'in use']
# ['1334', 'Vallparadís Footbridge', '2007', 'Terrassa', 'Spain', 'in use']
# ['1335', 'Valserrhein Bridge at Vals', '2009', 'Vals (GR)', 'Switzerland', 'in use']
# ['1336', 'Vandières Rail Bridge', '2005', 'Vandières (54)', 'France', 'in use']
# ['1337', 'Vaux Viaduct', '1999', 'Yvonand (VD)', 'Switzerland', 'in use']
# ['1338', 'Vayringe Bridge', '', '- Malzéville (54)', 'France', 'in use']
# ['1339', 'Velsdorfer Strasse Bridge', '2000', 'Calvörde (ST)', 'Germany', 'in use']
# ['1340', 'Vendenheim Viaduct', '2021', 'Vendenheim (67)', 'France', 'in use']
# ['1341', 'Venterol Bridge', '2010', 'Venterol (4)', 'France', 'in use']
# ['1342', 'Verden Railroad Bridge', '2015', 'Verden (Aller) (NI)', 'Germany', 'in use']
# ['1343', 'Vermillion-Newcastle Bridge', '2001', 'Vermillion (SD)', 'USA', 'in use']
# ['1344', 'Verrières Viaduct', '2002', 'Verrières (12)', 'France', 'in use']
# ['1345', 'Veterans Memorial Bridge', '1990', 'Weirton (WV)', 'USA', 'in use']
# ['1346', 'Veterans Memorial Bridge', '1997', 'Beverly (MA)', 'USA', 'in use']
# ['1347', 'Veterans Memorial Bridge', '1981', 'Ottawa (IL)', 'USA', 'in use']
# ['1348', 'Veveyse Bridge', '1969', 'Corsier-sur-Vevey (VD)', 'Switzerland', 'in use']
# ['1349', "Viaduc d'Itzig", '1994', 'Hesperange', 'Luxembourg', 'in use']
# ['1350', 'Viaduc de Belleville', '', 'Belleville (54)', 'France', 'in use']
# ['1351', 'Viaduc de Caramany', '', 'Caramany (66)', 'France', 'in use']
# ['1352', 'Viaduc de Claye-Souilly', '2004', 'Claye-Souilly (77)', 'France', 'in use']
# ['1353', 'Viaduc de Criviller', '', 'Baccarat (54)', 'France', 'in use']
# ['1354', 'Viaduc de Hamm', '1994', '- Hesperange', 'Luxembourg', 'in use']
# ['1355', "Viaduc de l'Alses", '', 'Arabaux (9)', 'France', 'in use']
# ['1356', "Viaduc de l'Arc", '1997', 'Ventabren (13)', 'France', 'in use']
# ['1357', "Viaduc de l'Erve", '2014', 'Ballée (53)', 'France', 'completed']
# ['1358', "Viaduc de l'Hyrôme", '2000', 'Chemillé (49)', 'France', 'in use']
# ['1359', "Viaduc de l'Orne", '2020', '- Hérouville-Saint-Clair (14)', 'France', 'in use']
# ['1360', 'Viaduc de la Boivre', '', 'Vouneuil-sous-Biard (86)', 'France', 'completed']
# ['1361', 'Viaduc de la Charente Sud', '', '- Nersac (16)', 'France', 'completed']
# ['1362', 'Viaduc de la Courbe', '2014', '- La Milesse (72)', 'France', 'completed']
# ['1363', 'Viaduc de la Drosbach', '1994', 'Hesperange', 'Luxembourg', 'in use']
# ['1364', 'Viaduc de la Fontaine des Filles', '', 'Saint-Léger (16)', 'France', 'completed']
# ['1365', 'Viaduc de la Garrigue', '2001', 'Verrières (12)', 'France', 'in use']
# ['1366', 'Viaduc de la Gartempe', '1996', 'Bessines-sur-Gartempe (87)', 'France', 'in use']
# ['1367', 'Viaduc de la Goujonne', '', 'Montguyon (17)', 'France', 'completed']
# ['1368', 'Viaduc de la Grande-Ravine', '2009', 'Trois-Bassins', 'Réunion', 'in use']
# ['1369', 'Viaduc de la Jouanne', '2014', 'Argentré (53)', 'France', 'completed']
# ['1370', 'Viaduc de la Laize', '2006', 'Fresney-le-Puceux (14)', 'France', 'in use']
# ['1371', 'Viaduc de la Manse', '', 'Sepmes (37)', 'France', 'completed']
# ['1372', 'Viaduc de la Marne', '', 'Annet-sur-Marne (77)', 'France', 'in use']
# ['1373', 'Viaduc de la Mayenne', '2014', 'Changé (53)', 'France', 'completed']
# ['1374', 'Viaduc de la Planchette', '1994', 'Bourgs-sur-Colagne (48)', 'France', 'in use']
# ['1375', 'Viaduc de la ravine Fontaine', '2009', 'Saint-Leu', 'Réunion', 'in use']
# ['1376', 'Viaduc de la Réole', '1994', 'La Réole (33)', 'France', 'in use']
# ['1377', 'Viaduc de la Sèvre Nantaise', '2004', 'Clisson (44)', 'France', 'in use']
# ['1378', 'Viaduc de la Somme (PI 4)', '1995', 'Amiens (80)', 'France', 'in use']
# ['1379', 'Viaduc de la Vaige', '2014', 'Saint-Denis-du-Maine (53)', 'France', 'completed']
# ['1380', 'Viaduc de la Vézère', '1996', 'Uzerche (19)', 'France', 'in use']
# ['1381', 'Viaduc de la Vézère-Corrèze', '2005', 'Brive-la-Gaillarde (19)', 'France', 'in use']
# ['1382', 'Viaduc de la Vienne', '', 'Nouâtre (37)', 'France', 'completed']
# ['1383', 'Viaduc de la Vonne', '', 'Marigny-Chemereau (86)', 'France', 'completed']
# ['1384', 'Viaduc de Marnaval', '1998', 'Saint-Dizier (52)', 'France', 'in use']
# ['1385', 'Viaduc de Minez-Leihon', '2000', 'Le Moustoir (22)', 'France', 'in use']
# ['1386', "Viaduc de Monistrol-d'Allier", '1998', "Monistrol-d'Allier (43)", 'France', 'in use']
# ['1387', 'Viaduc de Remouchamps', '1980', 'Remouchamps', 'Belgium', 'in use']
# ['1388', 'Viaduc de Volesvres', '1998', 'Volesvres (71)', 'France', 'in use']
# ['1389', 'Viaduc des Croupets du Moulin', '', 'Sart', 'Belgium', 'in use']
# ['1390', 'Viaduc des Lorettes Nord', '', '- Saint-Vallier (16)', 'France', 'completed']
# ['1391', 'Viaduc des Lorettes Sud', '', 'Saint-Vallier (16)', 'France', 'completed']
# ['1392', 'Viaduc du Bec', '2005', 'Brionne (27)', 'France', 'in use']
# ['1393', 'Viaduc du CA.MI.FE.MO', '', 'Moulins-lès-Metz (57)', 'France', 'in use']
# ['1394', "Viaduc du Canal de l'Est", '2005', 'Lacroix-sur-Meuse (55)', 'France', 'in use']
# ['1395', 'Viaduc du Douy', '1994', 'Collioure (66)', 'France', 'in use']
# ['1396', 'Viaduc du Lez', '2017', 'Lattes (34)', 'France', 'in use']
# ['1397', 'Viaduc du Lignon', '1993', 'Saint-Maurice-de-Lignon (43)', 'France', 'in use']
# ['1398', 'Viaduc du Lot', '2021', 'Mende (48)', 'France', 'completed']
# ['1399', 'Viaduc du Mouzon', '', 'Montguyon (17)', 'France', 'completed']
# ['1400', 'Viaduc du Palais', '', '- Boresse-et-Martron (17)', 'France', 'completed']
# ['1401', 'Viaduc du Quartier', '2014', 'Bonchamp-lès-Laval (53)', 'France', 'completed']
# ['1402', 'Viaduc du Vicoin', '2014', '- Saint-Berthevin (53)', 'France', 'completed']
# ['1403', "Viaduc sur l'A54", '2017', 'Caissargues (30)', 'France', 'in use']
# ['1404', 'Viaduc sur la Sorge', '1975', 'Valangin (NE)', 'Switzerland', 'in use']
# ['1405', 'Viaduct over the Yonne', '1997', 'Sens (89)', 'France', 'in use']
# ['1406', 'Viaducto del Centenario', '', 'Ponferrada', 'Spain', 'in use']
# ['1407', 'Viaducto sobre el embalse del Ebro', '2002', 'Cantabria', 'Spain', 'in use']
# ['1408', 'Viaducto sobre la calle Comercio', '', 'Madrid', 'Spain', 'in use']
# ['1409', 'Viaduto do Cais das Pedras', '', 'Porto', 'Portugal', 'in use']
# ['1410', 'Vicario Viaduct', '2009', 'Velez de Benaudalla', 'Spain', 'in use']
# ['1411', 'Vicima Bridge', '1969', 'Tartano (LM)', 'Italy', 'in use']
# ['1412', 'Victor Bodson Bridge', '1993', 'Hesperange', 'Luxembourg', 'in use']
# ['1413', 'Vidourle Viaduct', '2016', 'Gallargues-le-Montueux (30)', 'France', 'in use']
# ['1414', 'Vidyasagar Setu', '1992', 'Kolkata', 'India', 'in use']
# ['1415', 'Vienne Bridge', '2006', 'Aixe-sur-Vienne (87)', 'France', 'in use']
# ['1416', 'Vigo University Footbridge', '2003', 'Vigo', 'Spain', 'in use']
# ['1417', 'Vila-Seca Footbridge', '', 'Vila-seca', 'Spain', 'in use']
# ['1418', 'Vila-Seca Railroad Bridge', '2013', 'Vila-seca', 'Spain', 'in use']
# ['1419', 'Vilafant Footbridges', '2011', 'Vilafant', 'Spain', 'in use']
# ['1420', 'Villa Bedretto Ticino River Bridge', '1997', 'Bedretto (TI)', 'Switzerland', 'in use']
# ['1421', 'Ville-sur-Haine Bridge', '', 'Ville-sur-Haine', 'Belgium', 'in use']
# ['1422', 'Vimy Memorial Bridge', '2014', 'Ottawa (ON)', 'Canada', 'in use']
# ['1423', 'Violette Viaduct', '', 'Grenier-Montgon (43)', 'France', 'in use']
# ['1424', 'Vispa Footbridge', '2014', 'Visp (VS)', 'Switzerland', 'in use']
# ['1425', 'Vistre Viaduct', '2017', 'Vestric-et-Candiac (30)', 'France', 'in use']
# ['1426', 'Viuz-la-Chiesaz Footbridge', '2003', 'Viuz-la-Chiesaz (74)', 'France', 'in use']
# ['1427', 'Vockerode Motorway Bridge', '2000', 'Oranienbaum-Wörlitz (ST)', 'Germany', 'in use']
# ['1428', 'Volonne Bridge', '2006', 'Volonne (4)', 'France', 'in use']
# ['1429', 'Vorchdorf Overpass', '2008', 'Vorchdorf (OOE)', 'Austria', 'in use']
# ['1430', 'Voreppe Bridge', '1990', 'Voreppe (38)', 'France', 'in use']
# ['1431', 'Wainwright Bridge', '2008', 'Blackburn (GB-ENG)', 'United Kingdom', 'in use']
# ['1432', 'Waldschlösschen Bridge', '2013', 'Dresden (SN)', 'Germany', 'in use']
# ['1433', 'Wallhausen Motorway Bridge', '2003', 'Wallhausen (ST)', 'Germany', 'in use']
# ['1434', 'Waltherstrasse Bridge', '2004', 'Dresden (SN)', 'Germany', 'in use']
# ['1435', 'Walton Bridge', '2013', 'Walton (GB-ENG)', 'United Kingdom', 'in use']
# ['1436', 'Wanbian Bridge', '2008', 'Fuzhou', 'China', 'in use']
# ['1437', 'Warner Road Pedestrian Overpass', '', 'Valley View (OH)', 'USA', 'in use']
# ['1438', 'Warschauer Strasse Footbridge', '2019', 'Berlin (BE)', 'Germany', 'in use']
# ['1439', 'Wartburg Strasse Bridge', '1956', 'Castrop-Rauxel (NRW)', 'Germany', 'in use']
# ['1440', 'Waschmühl Viaduct', '2013', 'Kaiserslautern (RP)', 'Germany', 'in use']
# ['1441', 'Washimi Bridge', '2019', 'Gujō', 'Japan', 'in use']
# ['1442', 'Waterkant Footbridge', '2010', 'Cape Town', 'South Africa', 'in use']
# ['1443', 'Wedringer Strasse Bridge', '', 'Haldensleben (ST)', 'Germany', 'in use']
# ['1444', 'Weinberg Bridge', '2014', 'Rathenow (BB)', 'Germany', 'in use']
# ['1445', 'Weinlandbrücke', '2000', 'Andelfingen (ZH)', 'Switzerland', 'in use']
# ['1446', 'Weitingen-Neuenhof Rail Bridge', '1988', 'Wettingen (AG)', 'Switzerland', 'in use']
# ['1447', 'Werder Bridge', '1939', 'Werder (Havel) (BB)', 'Germany', 'in use']
# ['1448', 'Werkspoorbrug', '2002', 'Utrecht', 'Netherlands', 'in use']
# ['1449', 'Wernshausen Schmalkaden River Bridge (B19)', '2013', 'Schmalkalden (TH)', 'Germany', 'in use']
# ['1450', 'Werratalbrücke Bad Salzungen', '', 'Bad Salzungen (TH)', 'Germany', 'project phase']
# ['1451', 'Wertachtalbrücke (B309)', '2014', 'Nesselwang (BY)', 'Germany', 'in use']
# ['1452', 'West India Quay DLR Bridge', '', 'London (GB-ENG)', 'United Kingdom', 'in use']
# ['1453', 'Wetter Road Bridge', '1931', 'Wetter (Ruhr) (NRW)', 'Germany', 'in use']
# ['1454', 'Whites Hill Sidehill Viaduct', '2002', 'Marin County (CA)', 'USA', 'in use']
# ['1455', 'Wiedersbach Viaduct', '2008', 'Auengrund (TH)', 'Germany', 'in use']
# ['1456', 'Wienerbergbrücke', '1966', 'Vienna', 'Austria', 'in use']
# ['1457', 'Wiesbaden-Schierstein Bridge', '2019', 'Wiesbaden (HE)', 'Germany', 'in use/under construction']
# ['1458', 'Wildlife Overpass', '', 'Urcel (2)', 'France', 'in use']
# ['1459', 'Wilkau-Hasslau Bridge', '1995', 'Wilkau-Hasslau (SN)', 'Germany', 'in use']
# ['1460', 'Willerzell Viaduct', '1936', 'Einsiedeln (SZ)', 'Switzerland', 'in use']
# ['1461', 'William H. Harsha Bridge', '2000', 'Maysville (KY)', 'USA', 'in use']
# ['1462', 'William O. Lee Memorial Bridge', '', 'Frederick (MD)', 'USA', 'in use']
# ['1463', 'Wilrijk Viaduct', '1970', 'Antwerp', 'Belgium', 'in use']
# ['1464', 'Wilson Pinheiro Bridge', '2004', 'Brasiléia (AC)', 'Brazil', 'in use']
# ['1465', 'Wilwisheim Viaduct', '', 'Wilwisheim (67)', 'France', 'in use']
# ['1466', 'Windelbach Viaduct', '2012', 'Herborn (HE)', 'Germany', 'in use']
# ['1467', 'Winden Bridge', '2001', 'Melk (NOE)', 'Austria', 'in use']
# ['1468', 'Winterbrook Bridge', '1993', 'Wallingford (GB-ENG)', 'United Kingdom', 'in use']
# ['1469', 'Wittenberge Road Bridge', '1978', '- Wittenberge (BB)', 'Germany', 'in use']
# ['1470', 'Wolkenstein Bridge', '', 'Wolkenstein (SN)', 'Germany', 'in use']
# ['1471', 'Wroclaw Stadium Footbridge', '2012', 'Wroclaw (DS)', 'Poland', 'in use']
# ['1472', 'Wushan Bridge', '2005', 'Chongqing', 'China', 'in use']
# ['1473', 'Xai-Xai Bridge', '1964', 'Xai-Xai', 'Mozambique', 'in use']
# ['1474', 'Xialaoxi Bridge', '1996', 'Yichang', 'China', 'in use']
# ['1475', 'Xiangyun Bridge', '', 'Taiyuan', 'China', 'in use']
# ['1476', 'Xiaohe River Bridge', '2010', 'Enshi', 'China', 'in use']
# ['1477', 'Ximonde Footbridge', '2012', '- A Estrada', 'Spain', 'in use']
# ['1478', 'Xindian River Metro Bridge', '', 'New Taipei City', 'Taiwan', 'in use']
# ['1479', 'Xiqiao Bridge', '1987', 'Foshan', 'China', 'in use']
# ['1480', 'Xupu Bridge', '1997', 'Shanghai', 'China', 'in use']
# ['1481', 'Yajisha Bridge', '2000', 'Guangzhou', 'China', 'in use']
# ['1482', 'Yamaguragawa Bridge', '', 'Niigata', 'Japan', 'in use']
# ['1483', 'Yamato Bridge', '1975', 'Osaka', 'Japan', 'in use']
# ['1484', 'Yangpu Bridge', '1993', 'Shanghai', 'China', 'in use']
# ['1485', 'Yesanhe River Railway Bridge', '2010', 'Hubei', 'China', 'in use']
# ['1486', 'Yoxall Bridge', '1998', "King's Bromley (GB-ENG)", 'United Kingdom', 'in use']
# ['1487', 'Yukon River Bridge', '', 'Dawson (YT)', 'Canada', 'project phase']
# ['1488', 'Zabeel Park Footbridge', '2005', 'Dubai', 'United Arab Emirates', 'in use']
# ['1489', 'Zanjan Cable-Stayed Bridge', '2018', 'Zanjan', 'Iran', 'in use']
# ['1490', 'Zaragoza Bridge', '', 'Puebla (PUE)', 'Mexico', 'in use']
# ['1491', 'Zaragoza-Delicias Flyover Bridge', '2002', 'Zaragoza', 'Spain', 'in use']
# ['1492', 'Zarautz Elevator', '2008', 'San Sebastián', 'Spain', 'in use']
# ['1493', 'Zedtlitzer Grund Viaduct', '2011', 'Borna (SN)', 'Germany', 'in use']
# ['1494', 'Zeitz Bypass Viaduct', '2000', 'Zeitz (ST)', 'Germany', 'in use']
# ['1495', 'Zemst Railroad Overpass', '2012', 'Zemst', 'Belgium', 'in use']
# ['1496', 'Zhijing River Bridge', '2009', 'Hubei', 'China', 'in use']
# ['1497', 'Zigui Qinggan River Bridge', '1998', 'Hubei', 'China', 'in use']
# ['1498', 'Zirndorf Footbridge', '1995', 'Zirndorf (BY)', 'Germany', 'in use']
# ['1499', 'Zörbig Overpass (B 6n/A9)', '2017', 'Zörbig (ST)', 'Germany', 'in use']
# ['1500', 'Zorn Viaduct', '', 'Wilwisheim (67)', 'France', 'in use']
# ['1501', 'Zuidhorn Rail Bridge', '2018', 'Zuidhorn', 'Netherlands', 'in use']
# ['1502', 'Zumaia Footbridge', '', 'Zumaia', 'Spain', 'in use']
# ['1503', 'Zwelitsha Pedestrian Bridge', '', 'Zwelitsha', 'South Africa', 'in use']

# %%
url = 'https://structurae.net/en/structures/bridges/composite-material-bridges/list'

#service = Service("/usr/bin/chromedriver")
#service = Service("/usr/lib/chromium-browser/chromedriver")

options = Options()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument('--disable-dev-shm-usage')

#driver = webdriver.Chrome(service=service, options=options)
driver = webdriver.Chrome(service = Service("/usr/bin/chromedriver"), options = options)

# Load the website
driver.get(url)

# Wait for the table to load (optional)
# You may need to adjust the timeout depending on your internet speed and computer performance
driver.implicitly_wait(10)

# Get number of pages for table
num_pages = int(driver.find_element(By.CLASS_NAME, 'pageLinksPageNav').find_elements(By.TAG_NAME, 'a')[-1].get_attribute("data-page"))
print(num_pages)

# Extract the headers
table = driver.find_element(By.CLASS_NAME, 'mobile-scroll-table')
headers = [header.text.strip() for header in table.find_elements(By.TAG_NAME, 'th')]

print(headers)

driver.quit()

rows = []

for i in range(0, num_pages * 100, 100):
    url = 'https://structurae.net/en/structures/bridges/composite-material-bridges/list?min={}'.format(i)
    driver = webdriver.Chrome(service = Service("/usr/bin/chromedriver"), options = options)
    driver.get(url)
    driver.implicitly_wait(10)

    # Find the table element
    table = driver.find_element(By.CLASS_NAME, 'mobile-scroll-table')

    # Extract the rows
    for row in table.find_elements(By.TAG_NAME, 'tr'):
        i = 0
        row_data = []
        for cell in row.find_elements(By.TAG_NAME, 'td'):
            if(i == 4):
                img = cell.find_element(By.TAG_NAME, 'img')
                item = img.get_attribute("alt")#.text.strip()
                row_data.append(item)
            else:
                item = cell.text.strip()
                row_data.append(item)
            i += 1
        #cells = [cell.text.strip() for cell in row.find_elements(By.TAG_NAME, 'td')]
        if row_data:
            rows.append(row_data)

    # Close the browser
    driver.quit()

# Print the headers and rows
for row in rows:
    print(row)
#Append data to csv
df2 = pd.DataFrame(rows, columns = headers)
df2.to_csv('/usr/bin/bridges.csv', mode='a', index = False, header = False, encoding = 'utf-8-sig')
# Out:
# 1
# ['#', 'Name', 'Year', 'Location', 'Country', 'Status']
# ['1', 'Aberfeldy Footbridge', '1992', 'Aberfeldy (GB-SCT)', 'United Kingdom', 'in use']
# ['2', 'Ait Bayoud Footbridge', '2013', 'Morocco', 'Morocco', 'in use']
# ['3', 'Biobridge', '2016', 'Eindhoven', 'Netherlands', 'in use']
# ['4', 'Bradkirk Footbridge', '2009', 'Blackpool (GB-ENG)', 'United Kingdom', 'in use']
# ['5', 'Chamberlain Bridge', '2006', 'Bridgetown', 'Barbados', 'in use']
# ['6', 'Fiberline Bridge', '1997', 'Kolding', 'Denmark', 'in use']
# ['7', 'Footbridge over the Kempt', '2001', 'Winterthur (ZH)', 'Switzerland', 'in use']
# ['8', 'Forrest & Maxie Preston Memorial Suspension Bridge', '1999', 'River (KY)', 'USA', 'in use']
# ['9', 'Foryd Harbour Footbridge', '2013', 'Rhyl (GB-WLS)', 'United Kingdom', 'in use']
# ['10', 'Fredrikstad Footbridge', '2006', 'Fredrikstad', 'Norway', 'in use']
# ['11', 'Halgavor Bridge', '2001', 'Bodmin (GB-ENG)', 'United Kingdom', 'in use']
# ['12', 'Holländerbrücke', '2009', 'Reinbek (SH)', 'Germany', 'in use']
# ['13', 'Kaponjärbron', '2019', 'Gothenborg', 'Sweden', 'project phase']
# ['14', 'Kings Stormwater Channel Bridge', '', 'Riverside County (CA)', 'USA', 'in use']
# ['15', 'Lleida Footbridge', '2001', 'Lleida', 'Spain', 'in use']
# ['16', 'Ooypoort Footbridge', '2014', 'Nijmegen', 'Netherlands', 'in use']
# ['17', 'Pasarela de Almuñécar', '2011', 'Madrid', 'Spain', 'in use']
# ['18', 'Pine Barrens Bridge', '2002', 'Wharton State Forest (NJ)', 'USA', 'in use']
# ['19', 'Pontresina Footbridge', '1997', 'Pontresina (GR)', 'Switzerland', 'in use']
# ['20', 'Regenbach Bridge', '2004', 'Klipphausen (SN)', 'Germany', 'in use']
# ['21', 'River Leri Footbridge', '2009', 'Ynyslas (GB-WLS)', 'United Kingdom', 'in use']
# ['22', 'Sant Fruitós Footbridge', '', 'Sant Fruitós de Bages', 'Spain', 'in use']
# ['23', 'Schwerin-Neumühle Bridge', '2003', 'Schwerin (MV)', 'Germany', 'in use']
# ['24', 'Seebrücke', '2000', 'Bitterfeld-Wolfen (ST)', 'Germany', 'in use']
# ['25', 'Smart Circular Bridge', '2022', 'Almere', 'Netherlands', 'in use']
# ['26', 'Stanislas Bridge', '2007', 'Delft', 'Netherlands', 'in use']
# ['27', 'TU Berlin Experimental Footbridge', '2006', 'Berlin (BE)', 'Germany', 'in use']
# ['28', 'Via Allende Footbridge', '', 'Prato (TC)', 'Italy', 'in use']

# %%
url = 'https://structurae.net/en/structures/bridges/concrete-bridges/list'

#service = Service("/usr/bin/chromedriver")
#service = Service("/usr/lib/chromium-browser/chromedriver")

options = Options()
options.add_argument("--headless")
#options.headless = True
options.add_argument("--no-sandbox")
options.add_argument('--disable-dev-shm-usage')

#driver = webdriver.Chrome(service=service, options=options)
driver = webdriver.Chrome(service = Service("/usr/bin/chromedriver"), options = options)

# Load the website
driver.get(url)

# Wait for the table to load (optional)
# You may need to adjust the timeout depending on your internet speed and computer performance
driver.implicitly_wait(10)

# Get number of pages for table
num_pages = int(driver.find_element(By.CLASS_NAME, 'pageLinksPageNav').find_elements(By.TAG_NAME, 'a')[-1].get_attribute("data-page"))
print(num_pages)

# Extract the headers
table = driver.find_element(By.CLASS_NAME, 'mobile-scroll-table')
headers = [header.text.strip() for header in table.find_elements(By.TAG_NAME, 'th')]

print(headers)

rows = []

for i in range(0, num_pages * 100, 100):
    url = 'https://structurae.net/en/structures/bridges/concrete-bridges/list?min={}'.format(i)
    #driver = webdriver.Chrome(service = Service("/usr/bin/chromedriver"), options = options)
    driver.get(url)
    driver.implicitly_wait(10)

    # Find the table element
    table = driver.find_element(By.CLASS_NAME, 'mobile-scroll-table')

    # Extract the rows
    for row in table.find_elements(By.TAG_NAME, 'tr'):
        i = 0
        row_data = []
        for cell in row.find_elements(By.TAG_NAME, 'td'):
            if(i == 4):
                img = cell.find_element(By.TAG_NAME, 'img')
                item = img.get_attribute("alt")#.text.strip()
                row_data.append(item)
            else:
                item = cell.text.strip()
                row_data.append(item)
            i += 1
        #cells = [cell.text.strip() for cell in row.find_elements(By.TAG_NAME, 'td')]
        if row_data:
            rows.append(row_data)

    # Close the browser
    #driver.quit()

driver.quit()

# Print the headers and rows
for row in rows:
    print(row)

#Append data to csv
df2 = pd.DataFrame(rows, columns = headers)
df2.to_csv('/usr/bin/bridges.csv', mode='a', index = False, header = False, encoding = 'utf-8-sig')
# Out:
# Streaming output truncated to the last 5000 lines.
# ['992', 'Clarence L. Hussey Memorial Bridge', '1925', 'North Kingstown (RI)', 'USA', 'in use']
# ['993', 'Clark Street CTA Rail Bridge', '', 'Evanston (IL)', 'USA', 'in use']
# ['994', 'Clearwater Memorial Causeway', '2005', 'Clearwater (FL)', 'USA', 'in use']
# ['995', 'Cleft-Ridge Span', '1872', 'New York (NY)', 'USA', 'in use']
# ['996', 'Clemmer Bridge', '', 'Perth East (ON)', 'Canada', 'in use']
# ['997', 'Clichy Bridge', '1975', 'Clichy (92)', 'France', 'in use']
# ['998', 'Clichy Metro Viaduct', '1980', 'Clichy (92)', 'France', 'in use']
# ['999', 'Clidane Viaduct', '1999', 'Bourg-Lastic (63)', 'France', 'in use']
# ['1000', 'Clifton Avenue Bridge', '2002', 'Baltimore (MD)', 'USA', 'in use']
# ['1001', 'Clifton Bridge', '1967', 'Penrith (GB-ENG)', 'United Kingdom', 'in use']
# ['1002', 'Clifton Bridge', '1958', 'Nottingham (GB-ENG)', 'United Kingdom', 'in use']
# ['1003', 'Clifton Bridge', '1972', 'Nottingham (GB-ENG)', 'United Kingdom', 'in use']
# ['1004', 'Climax Bridge', '', 'Climax (KS)', 'USA', 'demolished']
# ['1005', 'Cline Avenue Bridge', '2020', 'East Chicago (IN)', 'USA', 'in use']
# ['1006', 'Clozzatobelbrücke', '1965', 'Scuol (GR)', 'Switzerland', 'in use']
# ['1007', 'Club Nautico Puerto Colon de Adeje Footbridge', '', 'Adeje', 'Spain', 'in use']
# ['1008', 'Coassack Bridge', '1965', 'Saint Petersburg', 'Russia', 'in use']
# ['1009', 'Coatzacoalcos II Bridge', '1984', 'Veracruz (VER)', 'Mexico', 'in use']
# ['1010', 'Cobden Bridge', '1928', 'Southampton (GB-ENG)', 'United Kingdom', 'in use']
# ['1011', 'Cocâtre Bridge', '2006', 'Trois-Bassins', 'Réunion', 'in use']
# ['1012', 'Cochem Bridge', '', 'Cochem (RP)', 'Germany', 'in use']
# ['1013', 'Cochrane-Africatown USA Bridge', '1991', 'Mobile (AL)', 'USA', 'in use']
# ['1014', 'Coffeyville Bridge', '1926', 'Coffeyville (KS)', 'USA', 'in use']
# ['1015', 'Colagne Viaduct', '2006', 'Bourgs-sur-Colagne (48)', 'France', 'in use']
# ['1016', 'Colbitz Wildlife Crossing', '2020', 'Colbitz (ST)', 'Germany', 'in use']
# ['1017', 'Colceresa Viaduct', '2020', 'Mason Vicentino (VN)', 'Italy', 'in use']
# ['1018', 'Colfax Avenue Viaduct', '1984', 'Denver (CO)', 'USA', 'in use']
# ['1019', 'Colle Isarco Viaduct', '1969', 'Brenner (TT)', 'Italy', 'in use']
# ['1020', 'College Road Bridge', '', 'Pietermaritzburg', 'South Africa', 'in use']
# ['1021', 'Colo River Bridge', '', 'New South Wales (NSW)', 'Australia', 'in use']
# ['1022', 'Colonnade Bridge', '1933', 'Piešťany', 'Slovakia', 'in use']
# ['1023', 'Colorado River Bridge (US 191)', '2010', 'Moab (UT)', 'USA', 'in use']
# ['1024', 'Colorado Street Bridge', '1913', 'Pasadena (CA)', 'USA', 'in use']
# ['1025', 'Coltano Viaduct', '1993', '- Pisa (TC)', 'Italy', 'in use']
# ['1026', 'Colwood Refueling Jetty', '', 'Esquimalt (BC)', 'Canada', 'in use']
# ['1027', 'Combóio Viaduct', '2000', 'Funchal', 'Portugal', 'in use']
# ['1028', 'Commelles Viaduct', '1982', 'Coye-la-Forêt (60)', 'France', 'in use']
# ['1029', 'Commerce Street Bridge', '1915', 'San Antonio (TX)', 'USA', 'in use']
# ['1030', 'Commercial Street Bridge', '1905', 'Trinidad (CO)', 'USA', 'demolished']
# ['1031', 'Communal Bridge', '', 'Krasnoyarsk', 'Russia', 'in use']
# ['1032', 'Communal Bridge', '1967', 'Perm', 'Russia', 'in use']
# ['1033', 'Commuter rail bridge at Nuremberg Central Station', '2000', 'Nuremberg (BY)', 'Germany', 'in use']
# ['1034', 'Como Park Footbridge', '1904', 'Saint Paul (MN)', 'USA', 'in use']
# ['1035', 'Compiègne Southern Bypass Bridge', '', 'Compiègne (60)', 'France', 'in use']
# ['1036', 'Compiègne Viaduct', '2009', 'Choisy-au-Bac (60)', 'France', 'in use']
# ['1037', 'Concejo Viaduct', '1990', 'Adamuz', 'Spain', 'in use']
# ['1038', 'Conde B. McCullough Memorial Bridge', '1936', 'North Bend (OR)', 'USA', 'in use']
# ['1039', 'Confederation Bridge', '1997', 'Port Borden (PE)', 'Canada', 'in use']
# ['1040', 'Congressman Joseph P. Addabbo Bridge', '', 'New York (NY)', 'USA', 'in use']
# ['1041', 'Conroe Bridge', '1925', 'Geary County (KS)', 'USA', 'in use']
# ['1042', 'Containerbahnhofbrücke Mannheim', '1978', 'Mannheim (BW)', 'Germany', 'in use']
# ['1043', 'Conveyor Bridge of the Holderbank-Wildegg Cement Factory', '1964', 'Möriken-Wildegg (AG)', 'Switzerland', '']
# ['1044', 'Coperta de la Dora', '', 'Turin (PM)', 'Italy', 'in use']
# ['1045', 'Coprincep Joan Martí Alanis Bridge', '', 'Escaldes-Engordany', 'Andorra', 'in use']
# ['1046', 'Corace River Bridge', '', 'Gimigliano (CI)', 'Italy', 'in use']
# ['1047', 'Corbeil-Essonnes Highway Bridge', '2003', '- Seine-Port (77)', 'France', 'in use']
# ['1048', 'Cordon Bridge', '', 'Brégnier-Cordon (1)', 'France', 'in use']
# ['1049', 'Corgo Viaduct', '2004', 'Peso da Regua', 'Portugal', 'in use']
# ['1050', 'Corinth Canal Highway Bridge', '', 'Isthmia', 'Greece', 'in use']
# ['1051', 'Corredor Sur Viaduct', '', 'Panama City', 'Panama', 'in use']
# ['1052', 'Corso di Francia Viaduct', '1960', 'Rome (LZ)', 'Italy', 'in use']
# ['1053', 'Corso Italia Viaduct', '1915', 'Bari (PU)', 'Italy', 'disused']
# ['1054', 'Cortaceros Viaduct', '1990', 'Montoro', 'Spain', 'in use']
# ['1055', 'Coslada Transportation Center Overpasses', '1994', 'Coslada', 'Spain', 'in use']
# ['1056', 'Costa Revoira Viaduct', '1984', 'Cadenazzo (TI)', 'Switzerland', 'in use']
# ['1057', 'Costa Viaduct', '1974', "Cornedo all'Isarco (TT)", 'Italy', 'in use']
# ['1058', 'Costa Viaduct (SS12)', '', "Cornedo all'Isarco (TT)", 'Italy', 'in use']
# ['1059', 'Costigliole Govone Viaduct', '2007', 'Asti (PM)', 'Italy', 'in use']
# ['1060', 'Costigliole Viaduct', '1988', 'Costigliole d’Asti (PM)', 'Italy', 'in use']
# ['1061', 'Cotter Bridge', '1930', 'Cotter (AR)', 'USA', 'in use']
# ['1062', 'Cotton Tree Drive Footbridge', '', 'Hong Kong', 'China', 'in use']
# ['1063', 'Coubon Bridge', '1984', 'Coubon (43)', 'France', 'in use']
# ['1064', 'Coubon Bridge', '1930', 'Coubon (43)', 'France', 'collapsed']
# ['1065', 'Coudette Bridge', '1942', 'Peyrehorade (40)', 'France', 'in use']
# ['1066', 'Couillet Viaduct', '', 'Charleroi', 'Belgium', 'in use']
# ['1067', 'Courrière N4 Bridges', '', 'Courrière', 'Belgium', 'in use']
# ['1068', 'Courtineau Viaduct', '', 'Sainte-Maure-de-Touraine (37)', 'France', 'in use']
# ['1069', 'Cova do Til Bridge', '1993', 'Madeira', 'Portugal', 'in use']
# ['1070', 'Covering of the Vilaine River', '1913', 'Rennes (35)', 'France', 'in use']
# ['1071', 'Cowen Park Bridge', '1936', 'Seattle (WA)', 'USA', 'in use']
# ['1072', 'Cowlitz River Bridge', '1968', 'Mossyrock (WA)', 'USA', 'in use']
# ['1073', 'Creamery Bridge', '1930', 'Osawatomie (KS)', 'USA', 'in use']
# ['1074', 'Crepacuore Viaduct', '1992', 'Terranuova Bracciolini (TC)', 'Italy', 'in use']
# ['1075', 'Cressage Bridge', '1913', 'Cressage (GB-ENG)', 'United Kingdom', 'in use']
# ['1076', 'Crestawald Bridge', '1959', 'Sufers (GR)', 'Switzerland', 'in use']
# ['1077', 'Creugenat Viaducts', '2010', 'Courtedoux (JU)', 'Switzerland', 'in use']
# ['1078', 'Creve Coeur Lake Memorial Park Bridge', '', 'Maryland Heights (MO)', 'USA', 'in use']
# ['1079', 'Cristoforo Colombo (West), Ponte Via', '', 'Rome (LZ)', 'Italy', 'in use']
# ['1080', 'Crna Draga Bridge', '', 'Jasenice', 'Croatia', 'in use']
# ['1081', 'Črni Kal Viaduct', '2004', 'Koper', 'Slovenia', 'in use']
# ['1082', 'Crooked River Bridge', '2000', 'Jefferson County (OR)', 'USA', 'in use']
# ['1083', 'Cross Bay Veterans Memorial Bridge', '1970', 'New York (NY)', 'USA', 'in use']
# ['1084', 'Cross Canyon Bridge', '1992', 'Portland (OR)', 'USA', 'in use']
# ['1085', 'Crould Viaduct', '', 'Goussainville (95)', 'France', 'in use']
# ['1086', 'Crown Point Viaduct', '1914', 'Multnomah County (OR)', 'USA', 'in use']
# ['1087', 'Crozet Viaduct', '1998', 'Vif (38)', 'France', 'in use']
# ['1088', 'Crozet Wharf', '1974', 'Crozet Islands', 'French Southern and Antarctic Lands', 'in use']
# ['1089', 'Cruces Pedestrian Bridge', '1985', 'Barakaldo', 'Spain', 'in use']
# ['1090', 'Cruzul Viaduct', '', 'Becerreá', 'Spain', 'in use']
# ['1091', 'Crystal Springs Road Bridge', '1901', 'San Mateo (CA)', 'USA', 'in use']
# ['1092', 'CSX Grand River Bridge', '1908', 'Painesville (OH)', 'USA', 'in use']
# ['1093', 'Cubzac High-Speed Rail Bridge', '2014', 'Cubzac-les-Ponts (33)', 'France', 'completed']
# ['1094', 'Cugnielertobelbrücke I', '1961', 'Sils im Domleschg (GR)', 'Switzerland', 'in use']
# ['1095', 'Cugnielertobelbrücke II', '1962', 'Sils im Domleschg (GR)', 'Switzerland', 'in use']
# ['1096', 'Cummins Creek Bridge', '1931', 'Lane County (OR)', 'USA', 'in use']
# ['1097', 'Curli Viaduct', '1977', 'Alessandria (PM)', 'Italy', 'in use']
# ['1098', 'Cuu Long Bridge', '2009', 'Cần Thơ', 'Vietnam', 'in use']
# ['1099', 'Cuyaguateje River Bridge', '1956', 'Pinar del Río', 'Cuba', 'in use']
# ['1100', 'Cycling Bridge', '', 'Caldes (TT)', 'Italy', 'in use']
# ['1101', 'Cypress Street Viaduct', '1957', 'Oakland (CA)', 'USA', 'collapsed']
# ['1102', 'Czerniakowski Bridge', '2003', 'Warsaw (MZ)', 'Poland', 'in use']
# ['1103', 'D 24 Bridge', '', 'Cabasse (83)', 'France', 'in use']
# ['1104', 'D 4 Bridge', '', 'Malijai (4)', 'France', 'in use']
# ['1105', 'D 5 Radbuza River Bridge', '2000', 'Pilsen', 'Czechia', 'in use']
# ['1106', 'D 940 Loire Bridge', '', 'Gien (45)', 'France', 'in use']
# ['1107', 'D 954 Bridge', '1960', 'Le Lauzet-Ubaye (4)', 'France', 'in use']
# ['1108', 'D1 Bohumín Footbridge', '2011', 'Bohumin', 'Czechia', 'in use']
# ['1109', 'D1 Motorway Bridge over Odra River and Antošovice Lake', '2007', 'Antošovice', 'Czechia', 'in use']
# ['1110', 'D1 Splavná Creek Bridge', '2008', 'Hrabuvka', 'Czechia', 'in use']
# ['1111', 'D1504 Bridge', '1981', 'Belley (1)', 'France', 'in use']
# ['1112', 'D50 Artuby River Bridge', '1927', 'Saïx (81)', 'France', 'in use']
# ['1113', 'D8 Knínice Motorway Bridge', '2006', 'Knínice', 'Czechia', 'in use']
# ['1114', 'Dahlenrode Overpass', '1987', 'Rosdorf (NI)', 'Germany', 'in use']
# ['1115', 'Dahu 2nd Bridge', '1989', 'Liuyang', 'China', 'in use']
# ['1116', 'Dala Gorge Railroad Bridge', '', 'Leuk (VS)', 'Switzerland', 'in use']
# ['1117', 'Dalgopol Railroad Bridge', '', 'Dalgopol', 'Bulgaria', 'in use']
# ['1118', 'Dalgopol Road Bridge', '', 'Dalgopol', 'Bulgaria', 'in use']
# ['1119', 'Dallas-Oak Cliff Viaduct', '1912', 'Dallas (TX)', 'USA', 'in use']
# ['1120', 'Dalmazi Bridge', '', 'Berne (BE)', 'Switzerland', 'in use']
# ['1121', 'Daluis Bridge', '', 'Daluis (6)', 'France', 'in use']
# ['1122', 'Dalvazza Bridge', '1925', 'Luzein (GR)', 'Switzerland', 'in use']
# ['1123', 'Dames Point Bridge', '1989', 'Jacksonville (FL)', 'USA', 'in use']
# ['1124', 'Dammbrücke', '1918', 'Hamburg (HH)', 'Germany', 'in use']
# ['1125', 'Danhe Bridge', '1959', 'China', 'China', 'in use']
# ['1126', 'DanLin Bridge', '', 'Pingtung', 'Taiwan', 'in use']
# ['1127', 'Danube Bridge of the Hohenzollerische Landesbahn', '1909', 'Sigmaringen (BW)', 'Germany', 'in use']
# ['1128', 'Danube Canal Bridge in Vienna', '1975', 'Vienna', 'Austria', 'in use']
# ['1129', 'Danyang Kunshan Grand Bridge', '2011', 'Jiangsu', 'China', 'in use']
# ['1130', 'Daolasa Viaduct', '2003', 'Commezzadura (TT)', 'Italy', 'in use']
# ['1131', 'Dar Drius Bridge', '1961', 'Dar Drius', 'Morocco', 'in use']
# ['1132', 'Dardanelli Viaduct', '', 'Étroubles (VD)', 'Italy', 'in use']
# ['1133', 'Darnytskyi Bridge, Old', '1951', 'Kyiv', 'Ukraine', 'in use']
# ['1134', 'Dasbach Viaduct', '', 'Krunkel (RP)', 'Germany', 'in use']
# ['1135', 'Dasbecker Weg Bridge', '2006', 'Hamm (NRW)', 'Germany', 'in use']
# ['1136', 'Dasburg Bridge', '1953', 'Dasburg (RP)', 'Germany', 'in use']
# ['1137', 'Dauphin Island Bridge', '1982', 'Mobile (AL)', 'USA', 'in use']
# ['1138', 'Davle Bridge', '1991', 'Davle', 'Czechia', 'in use']
# ['1139', 'Davos-Monstein Landwasser Bridge', '1974', 'Davos (GR)', 'Switzerland', 'in use']
# ['1140', 'Dazza Bridge', '1909', 'Sonico (LM)', 'Italy', 'in use']
# ['1141', 'De Lentloper', '2015', 'Nijmegen', 'Netherlands', 'in use/under construction']
# ['1142', 'De Oversteek', '2013', 'Nijmegen', 'Netherlands', 'in use']
# ['1143', 'Deadwood Creek Bridge', '1937', 'Pierce County (WA)', 'USA', 'demolished']
# ['1144', 'Deagon Deviation Bridge', '1996', 'Deagon (QLD)', 'Australia', 'in use']
# ['1145', 'Deba River Bridge', '2003', 'Eibar', 'Spain', 'in use']
# ['1146', 'Deba River Viaduct (AP-1)', '', 'Bergara', 'Spain', 'in use']
# ['1147', 'Deba River Viaduct (Basque Y)', '2014', 'Bergara', 'Spain', 'completed']
# ['1148', 'Dedin Tunnel', '', 'Delnice', 'Croatia', 'in use']
# ['1149', 'Dee Bridge', '1926', 'Kirkcudbright (GB-SCT)', 'United Kingdom', 'in use']
# ['1150', 'Dee Viaduct', '1990', 'Newbridge (GB-WLS)', 'United Kingdom', 'in use']
# ['1151', 'Deering Bridge', '1916', 'Sutton (NE)', 'USA', 'in use']
# ['1152', 'Del Casello Viaduct', '1986', 'Malborghetto Valbruna (FB)', 'Italy', 'in use']
# ['1153', 'Delaware Memorial Ditch Bridge', '', 'New Castle (DE)', 'USA', 'in use']
# ['1154', 'Delaware River Viaduct', '1911', 'Portland (PA)', 'USA', 'out of service']
# ['1155', 'Dell Avenue Carroll Canal Bridge', '1907', 'Los Angeles (CA)', 'USA', 'in use']
# ['1156', 'Dell Avenue Howland Canal Bridge', '1907', 'Los Angeles (CA)', 'USA', 'in use']
# ['1157', 'Dell Avenue Linnie Canal Bridge', '1907', 'Los Angeles (CA)', 'USA', 'in use']
# ['1158', 'Dell Avenue Sherman Canal Bridge', '1907', 'Los Angeles (CA)', 'USA', 'in use']
# ['1159', 'Depoe Bay Bridge', '1927', 'Lincoln County (OR)', 'USA', 'in use']
# ['1160', 'Depot Street Bridge', '2006', 'Rogue River (OR)', 'USA', 'in use']
# ['1161', 'Derby-Shelton Bridge', '1918', 'Derby (CT)', 'USA', 'in use']
# ['1162', 'Derenbach Bridge', '1927', 'Siegburg (NRW)', 'Germany', 'submerged']
# ['1163', 'Des Plaines River Valley Bridge', '2007', 'Bolingbrook (IL)', 'USA', 'in use']
# ['1164', 'Dessau Mulde Bridge', '1998', 'Dessau-Roßlau (ST)', 'Germany', 'in use']
# ['1165', 'Desselgem-Ooigem Bridge', '1968', 'Wielsbeke', 'Belgium', 'demolished']
# ['1166', 'Dettelbach Bridge', '2003', 'Dettelbach (BY)', 'Germany', 'in use']
# ['1167', 'Dettenbach Viaduct', '', 'Neukirchen vorm Wald (BY)', 'Germany', 'in use']
# ['1168', 'Deusto Overfly', '2003', 'Bilbao', 'Spain', 'in use']
# ['1169', 'Deutzer Brücke', '1980', 'Cologne (NRW)', 'Germany', 'in use']
# ['1170', 'Deveys Viaduct', '1992', 'Torino (PM)', 'Italy', 'in use']
# ['1171', "Devil's Bridge (Tartu)", '1913', 'Tartu', 'Estonia', 'in use']
# ['1172', 'Dewlen-Spohnhauer Bridge', '1926', 'Independence (KS)', 'USA', 'in use']
# ['1173', 'Deza River Viaduct', '2009', 'Silleda', 'Spain', 'in use']
# ['1174', 'Diamond Island Access Bridges', '2011', 'Phnom Penh', 'Cambodia', 'in use']
# ['1175', 'Diaterna Viaduct', '2009', 'Firenzuola (TC)', 'Italy', 'in use']
# ['1176', 'Dibamba River Bridge', '1984', 'Douala', 'Cameroon', 'in use']
# ['1177', 'Diekirch Footbridge', '1974', 'Diekirch', 'Luxembourg', 'in use']
# ['1178', 'Diepoldsau Bridge', '1985', 'Diepoldsau (SG)', 'Switzerland', 'in use']
# ['1179', 'Dieterode Rail Overpass', '', 'Dieterode (TH)', 'Germany', 'in use']
# ['1180', 'Dietikon Motorway Bridge (A1)', '1968', 'Dietikon (ZH)', 'Switzerland', 'in use']
# ['1181', 'Diez Bridge', '1948', 'Diez (RP)', 'Germany', 'in use']
# ['1182', 'Digoin Viaduct', '', 'Digoin (71)', 'France', 'in use']
# ['1183', 'Dilldorfer Höhe Footbridge', '', 'Essen (NRW)', 'Germany', 'in use']
# ['1184', 'Dillingen Bridge', '1952', 'Wallendorf (RP)', 'Germany', 'in use']
# ['1185', 'Dinghai Bridge', '', 'Hainan', 'China', 'under construction']
# ['1186', 'Dinquan Viaduct', '', 'Arta Terme (FB)', 'Italy', 'in use']
# ['1187', 'Dinslakener Strasse Bridge', '1962', 'Hünxe (NRW)', 'Germany', 'demolished']
# ['1188', 'Dintelhaven Road Bridge', '2001', 'Rotterdam', 'Netherlands', 'in use']
# ['1189', 'Diou Road Bridge', '1942', 'Diou (3)', 'France', 'in use']
# ['1190', 'Dischinger Bridge', '', 'Berlin (BE)', 'Germany', 'in use']
# ['1191', 'Discovery Bridge', '1992', 'Columbus (OH)', 'USA', 'in use']
# ['1192', 'Dittenbrunn Viaduct', '1984', 'Obersinn (BY)', 'Germany', 'in use']
# ['1193', 'Dittichenroder Talbrücke', '2002', 'Südharz (ST)', 'Germany', 'in use']
# ['1194', 'Djedeida Bridge', '1946', 'Djedeida', 'Tunisia', 'in use']
# ['1195', 'Djerba-Zarzis Island Causeway Bridge', '2006', 'Djerba Island', 'Tunisia', 'in use']
# ['1196', 'Djupfjordstraumen Bridge', '1983', 'Sortland', 'Norway', 'in use']
# ['1197', 'Dlouhá lávka', '2002', 'České Budějovice', 'Czechia', 'in use']
# ['1198', 'Dnipropetrovsk Bridge', '1966', 'Dnipro', 'Ukraine', 'in use']
# ['1199', 'Dobra River Bridge', '', 'Vrbovsko', 'Croatia', 'in use']
# ['1200', 'Doctor D. Pedro Gómez Bosque Footbridge', '2011', 'Valladolid', 'Spain', 'in use']
# ['1201', 'Dodan Nallah Arch Bridge', '', 'Dharamsala', 'India', 'in use']
# ['1202', 'Dodge Street Overpass', '1934', 'Omaha (NE)', 'USA', 'in use']
# ['1203', 'Dogali Bridge', '', 'Dogali', 'Eritrea', 'in use']
# ['1204', 'Dogna Viaduct', '1975', 'Dogna (FB)', 'Italy', 'in use']
# ['1205', 'Dogna Viaduct', '', 'Dogna (FB)', 'Italy', 'in use']
# ['1206', 'Doha Street Directional Ramp', '2009', 'Dubai', 'United Arab Emirates', 'in use']
# ['1207', 'Doksany Bridge', '1997', 'Doksany', 'Czechia', 'in use']
# ['1208', 'Dole Viaduct', '2007', 'Novo Mesto', 'Slovenia', 'in use']
# ['1209', 'Dollarton Bridge', '2005', 'North Vancouver (BC)', 'Canada', 'in use']
# ['1210', 'Dolný Hričov Viaduct', '2018', 'Dolný Hričov', 'Slovakia', 'in use']
# ['1211', 'Domat/Ems Overpass', '1963', 'Domat/Ems (GR)', 'Switzerland', 'in use']
# ['1212', 'Dömitz Bridge', '1992', 'Dömitz (MV)', 'Germany', 'in use']
# ['1213', 'Don Bosco Bridge', '2007', 'Naples (CM)', 'Italy', 'in use']
# ['1214', 'Donaubrücke Ingolstadt (A9)', '1976', 'Ingolstadt (BY)', 'Germany', 'in use']
# ['1215', 'Donaubrücke Melk', '1972', 'Melk (NOE)', 'Austria', 'disused']
# ['1216', 'Donauelisenbrücke', '1989', 'Neuburg an der Donau (BY)', 'Germany', 'in use']
# ['1217', 'Donautalbrücke Untermarchtal', '1953', 'Untermarchtal (BW)', 'Germany', 'in use']
# ['1218', 'Donauviadukt Untermarchtal', '2013', 'Untermarchtal (BW)', 'Germany', 'in use']
# ['1219', 'Donauwörth-Wörnitzstein Bridge', '1948', 'Donauwörth (BY)', 'Germany', 'in use']
# ['1220', 'Donggang Bridge', '1956', 'Lanzhou', 'China', 'in use']
# ['1221', 'Donghe Bridge', '1990', 'Wangcang', 'China', 'in use']
# ['1222', 'Dongting Lake Bridge', '2000', 'Yueyang', 'China', 'in use']
# ['1223', 'Donnersbergerbrücke', '1972', 'Munich (BY)', 'Germany', 'in use']
# ['1224', 'Donzère Road Bridge', '1952', 'Donzère (26)', 'France', 'in use']
# ['1225', 'Donzère-Mondragon Canal Bridge', '1950', 'Mondragon (84)', 'France', 'in use']
# ['1226', 'Dordogne Bridge', '1962', 'Strasbourg (67)', 'France', 'in use']
# ['1227', 'Dordrechtring Footbridge', '', 'Recklinghausen (NRW)', 'Germany', 'in use']
# ['1228', 'Dorénaz Bridge', '1933', 'Dorénaz (VS)', 'Switzerland', 'in use']
# ['1229', 'Dorfbach Viaduct', '1999', 'Rheinfelden (Baden) (BW)', 'Germany', 'in use']
# ['1230', 'Dorfbachbrücke Hinterrhein', '1967', 'Hinterrhein (GR)', 'Switzerland', 'in use']
# ['1231', 'Dorney Lake Finish Bridge', '2004', 'Buckinghamshire (GB-ENG)', 'United Kingdom', 'in use']
# ['1232', 'Dorney Lake Middle Bridge', '2004', 'Buckinghamshire (GB-ENG)', 'United Kingdom', 'in use']
# ['1233', 'Dorney Lake Start Bridge', '2004', 'Buckinghamshire (GB-ENG)', 'United Kingdom', 'in use']
# ['1234', 'Dornoch Firth Bridge', '1991', 'Dornoch (GB-SCT)', 'United Kingdom', 'in use']
# ['1235', 'Dortmunder Strasse Bridge', '1928', '- Hagen (NRW)', 'Germany', 'in use']
# ['1236', 'Doss da Servi Bridge', '1956', 'Trento (TT)', 'Italy', 'in use']
# ['1237', 'Doublement du Pont de Jonches', '', 'Auxerre (89)', 'France', 'in use']
# ['1238', 'Downers Grove Interchange East-North Ramp', '', 'Downers Grove (IL)', 'USA', 'in use']
# ['1239', 'Downers Grove Interchange South-East Ramp', '', 'Downers Grove (IL)', 'USA', 'in use']
# ['1240', 'Downers Grove Interchange South-West Ramp', '', 'Downers Grove (IL)', 'USA', 'in use']
# ['1241', 'Dr. Edvard Beneš Bridge', '1939', 'Štechovice', 'Czechia', 'in use']
# ['1242', 'Dr. Vom Bruch Bridge', '1927', 'Leer (Ostfriesland) (NI)', 'Germany', 'in use']
# ['1243', 'Dr.-Gustav-Heinemann-Brücke', '', 'Nuremberg (BY)', 'Germany', 'in use']
# ['1244', 'Draaiberg River Bridge', '', 'Cape Town', 'South Africa', 'in use']
# ['1245', 'Drac Bridge', '1950', 'Grenoble (38)', 'France', 'in use']
# ['1246', 'Dragon Bridge', '2007', 'Alcalá de Guadaíra', 'Spain', 'in use']
# ['1247', 'Dragon Gate Bridge', '1987', 'Chongqing', 'China', 'demolished']
# ['1248', 'Drammen Bridge', '2007', 'Drammen', 'Norway', 'in use']
# ['1249', 'Drammen City Bridge', '1936', 'Drammen', 'Norway', 'in use']
# ['1250', 'Draubrücke (A10)', '1986', 'Villach (KTN)', 'Austria', 'in use']
# ['1251', 'Drežnik Viadukt', '', 'Karlovac', 'Croatia', 'in use']
# ['1252', 'Droanello Bridge', '1962', '- Valvestino (LM)', 'Italy', 'in use']
# ['1253', 'Droppingwell Footbridge', '1968', '- Rotherham (GB-ENG)', 'United Kingdom', 'in use']
# ['1254', 'Drususbrücke', '1931', 'Bozen (TT)', 'Italy', 'in use']
# ['1255', 'Dry Bridge', '1962', 'Zrenjanin', 'Serbia', 'in use']
# ['1256', 'Dry Canyon Creek Bridge', '1921', 'Wasco County (OR)', 'USA', 'in use']
# ['1257', 'Dry Slough Bridge', '1913', 'Yolo County (CA)', 'USA', 'in use']
# ['1258', 'Duarte Pacheco Viaduct', '1944', 'Lisbon', 'Portugal', 'in use']
# ['1259', 'Dubai Water Canal Bridge', '2016', 'Dubai', 'United Arab Emirates', 'in use']
# ['1260', 'Dubbele Pijp', '', 'Leeuwarden', 'Netherlands', 'in use']
# ['1261', 'Dübendorf S-Bahn Bridges', '', 'Dübendorf (ZH)', 'Switzerland', 'in use']
# ['1262', 'Dubu Bridge (I)', '2008', 'Guangdong', 'China', 'in use']
# ['1263', 'Dubu Bridge (II)', '2008', 'Guangdong', 'China', 'in use']
# ['1264', 'Duca Martenapijp', '1983', 'Leeuwarden', 'Netherlands', 'in use']
# ['1265', 'Duckabush River Bridge', '1934', 'Brinnon (WA)', 'USA', 'in use']
# ['1266', 'Dudley B. Menzies Bridge', '1992', 'Edmonton (AB)', 'Canada', 'in use']
# ['1267', 'Duero Viaduct', '2015', 'Toro', 'Spain', 'in use']
# ['1268', 'Duferco-Clabecq Railroad Bridge', '1961', 'Clabecq', 'Belgium', 'in use']
# ['1269', 'Dugi Vrh Bridge', '', 'Možđenec', 'Croatia', 'in use']
# ['1270', 'Dukenburgsebrug', '1973', 'Nijmegen', 'Netherlands', 'in use']
# ['1271', 'Dukouhe Railway Bridge', '2010', 'Enshi', 'China', 'in use']
# ['1272', 'Duliujiang Bridge No. 1', '2010', 'Rongjiang', 'China', 'in use']
# ['1273', 'Dumbarton Bridge', '1982', 'Menlo Park (CA)', 'USA', 'in use']
# ['1274', 'Dunant Footbridge', '1976', 'Stuttgart (BW)', 'Germany', 'in use']
# ['1275', 'Dunbyeong Bridge', '', 'South Jeolla', 'South Korea', 'in use']
# ['1276', 'Dundee Road Bridge', '1932', 'Wheeling (IL)', 'USA', 'in use']
# ['1277', 'Dunkeltalbrücke', '2013', 'Goldisthal (TH)', 'Germany', 'completed']
# ['1278', 'Durchlass Kunitzer Strasse', '', 'Jena (TH)', 'Germany', 'in use']
# ['1279', 'Dürrbach Viaduct', '', 'Würzburg (BY)', 'Germany', 'in use']
# ['1280', 'Dürwaringbrücke', '1910', 'Vienna', 'Austria', 'in use']
# ['1281', 'Düsseldorfer Strasse Overpass', '2003', 'Duisburg (NRW)', 'Germany', 'in use']
# ['1282', 'Düsseldorfer Strasse Railroad Bridge', '', 'Duisburg (NRW)', 'Germany', 'in use']
# ['1283', 'Düsseltalbrücke', '1985', 'Erkrath (NRW)', 'Germany', 'in use']
# ['1284', 'Duyun Bridge', '1978', 'Duyun', 'China', 'in use']
# ['1285', 'Dyckerhoff Bridge', '1967', 'Wiesbaden (HE)', 'Germany', 'in use']
# ['1286', 'Dyrøy Bridge', '1994', 'Dyrøya', 'Norway', 'in use']
# ['1287', 'Đurđevića Tara Bridge', '1941', 'Žabljak', 'Montenegro', 'in use']
# ['1288', 'E 134 Langfoss Bridge', '', 'Vestland', 'Norway', 'in use']
# ['1289', 'E 40 Motorway Bridge across the N3', '', 'Melen', 'Belgium', 'in use']
# ['1290', 'E-1 Overpass over the Palma Ring Road', '', 'Palma de Mallorca', 'Spain', 'in use']
# ['1291', 'E17 Motorway Bridge', '', 'Harelbeke', 'Belgium', 'in use']
# ['1292', 'Earthquake Memorial Bridge', '2014', 'Muzaffarabad', 'Pakistan', 'in use']
# ['1293', 'East 12th Street Bridge', '1931', 'Austin (TX)', 'USA', 'in use']
# ['1294', 'East 21st Street Bridge', '1997', 'Tacoma (WA)', 'USA', 'in use']
# ['1295', 'East 34th Street Bridge', '1937', 'Tacoma (WA)', 'USA', 'in use']
# ['1296', 'East Branch Hudson River Bridge', '1916', 'Fort Edward (NY)', 'USA', 'in use']
# ['1297', 'East Golf Cart Bridge', '', 'Rancho Santa Fe (CA)', 'USA', 'in use']
# ['1298', 'East Huntington Bridge', '1985', 'Huntington (WV)', 'USA', 'in use']
# ['1299', 'East Michigan Avenue Bridge', '1923', 'Galesburg (MI)', 'USA', 'demolished']
# ['1300', 'East Park Dam', '1910', 'Colusa County (CA)', 'USA', 'in use']
# ['1301', 'East Street Bridge', '', 'West Malling (GB-ENG)', 'United Kingdom', 'collapsed']
# ['1302', 'East Tsing Yi Viaduct', '2009', 'Hong Kong', 'China', 'in use']
# ['1303', 'East Verdi Bridge', '1938', 'Verdi (NV)', 'USA', 'in use']
# ['1304', 'Eastern Bridge over the Canal E.D.F.', '', 'Saint-Paul-lès-Durance (13)', 'France', 'in use']
# ['1305', 'Eastern Channel Bridge', '2020', 'Brunei', 'Brunei', 'in use']
# ['1306', 'Eastern Valley Road Bridge', '1930', 'Tuscaloosa County (AL)', 'USA', 'in use']
# ['1307', 'Eastgate Mall Bridge', '1971', 'San Diego (CA)', 'USA', 'in use']
# ['1308', 'Eastwood Park Bridge', '1927', 'Minot (ND)', 'USA', 'in use']
# ['1309', 'Eberbach Bridge', '', 'Eberbach (BW)', 'Germany', 'in use']
# ['1310', 'Eberswalde Canal Bridge', '2006', 'Eberswalde (BB)', 'Germany', 'in use']
# ['1311', 'Eblé Bridge', '', 'Metz (57)', 'France', 'in use']
# ['1312', 'Ebnat-Kappel Viaduct', '2020', 'Wattwil (SG)', 'Switzerland', 'under construction']
# ['1313', 'Ebro River Footbridge', '1986', 'Logroño', 'Spain', 'in use']
# ['1314', 'Echarlod Viaduct', '1994', 'La Salle (VD)', 'Italy', 'in use']
# ['1315', 'Echelsbach Bridge', '2022', 'Rottenbuch (BY)', 'Germany', 'in use']
# ['1316', 'Echelsbach Bridge', '1929', 'Rottenbuch (BY)', 'Germany', 'under demolition']
# ['1317', 'Echternach Bridge', '1950', '- Echternach', 'Luxembourg', 'in use']
# ['1318', 'Echternach Bridge', '1973', '- Echternach', 'Luxembourg', 'completed']
# ['1319', 'Echthausen Bridge', '', 'Wickede (Ruhr) (NRW)', 'Germany', 'in use']
# ['1320', 'Eckbachtalbrücke Kirchheim', '2018', 'Kirchheim an der Weinstraße (RP)', 'Germany', 'in use']
# ['1321', 'Ed Hendler Bridge', '1978', 'Pasco (WA)', 'USA', 'in use']
# ['1322', 'Eddersheim Rail Bridge', '2000', '- Hattersheim am Main (HE)', 'Germany', 'in use']
# ['1323', 'Eden Park Bridge', '1895', 'Cincinnati (OH)', 'USA', 'in use']
# ['1324', 'Ederbringhausen Bridge', '', 'Vöhl (HE)', 'Germany', 'in use']
# ['1325', 'Ederbrücke Grifte', '', 'Edermünde (HE)', 'Germany', 'in use']
# ['1326', 'Edith Cavell Bridge', '1919', 'Otago', 'New Zealand', 'in use']
# ['1327', 'Edouard-Daladier Bridge', '1961', 'Avignon (84)', 'France', 'in use']
# ['1328', 'Eduardo Casavilca Viaduct', '1972', 'Martorell', 'Spain', 'in use']
# ['1329', 'Eefde Bridge', '1955', 'Eefde', 'Netherlands', 'in use']
# ['1330', 'Egg-Graben-Brücke', '2009', 'Großarl (SBG)', 'Austria', 'in use']
# ['1331', 'Egratz Viaduct', '1981', 'Passy (74)', 'France', 'in use']
# ['1332', 'Egua Bridge', '1967', 'Genoa (LG)', 'Italy', 'in use']
# ['1333', 'Eigenbilzen Bridge', '', 'Bilzen', 'Belgium', 'to be demolished']
# ['1334', 'Eiksund Bridge', '2008', 'Møre og Romsdal', 'Norway', 'in use']
# ['1335', 'Eilandbrug', '2003', 'Kampen', 'Netherlands', 'in use']
# ['1336', 'Eisenbachtalbrücke', '1990', 'Bavaria (BY)', 'Germany', 'in use']
# ['1337', 'Eisenbachtalbrücke', '', 'Nomborn (RP)', 'Germany', 'in use']
# ['1338', 'Eisenbahnbrücke über die Apfelstädt', '', 'Ingersleben (ST)', 'Germany', 'in use']
# ['1339', 'Eisenbahnbrücken A13', '1954', '- Kerpen (NRW)', 'Germany', 'in use']
# ['1340', 'Eisenbahnüberführung Lehrter Bahnhof (I)', '1999', 'Berlin (BE)', 'Germany', 'in use']
# ['1341', 'Eisenbahnüberführung Lehrter Bahnhof (II-IV)', '1999', 'Berlin (BE)', 'Germany', 'in use']
# ['1342', 'Eisenbahnüberführung Margarete-Steffin-Straße', '', 'Berlin (BE)', 'Germany', 'in use']
# ['1343', 'Eisern Viaduct', '1967', 'Siegen (NRW)', 'Germany', 'partially demolished']
# ['1344', 'Eixendorf Lake Bridge', '1974', 'Neunburg vorm Wald (BY)', 'Germany', 'in use']
# ['1345', 'Eko Bridge', '1975', 'Lagos', 'Nigeria', 'in use']
# ['1346', 'Ekole Creek Bridge', '', 'Yenagoa', 'Nigeria', 'in use']
# ['1347', 'El Burguillo Bridge', '2000', 'El Tiemblo', 'Spain', 'in use']
# ['1348', 'El Carril Viaduct', '', 'Carucedo', 'Spain', 'in use']
# ['1349', 'El Giza Bridge', '', 'Cairo', 'Egypt', 'in use']
# ['1350', 'El Portal Viaduct', '', 'Jerez de la Frontera', 'Spain', 'in use']
# ['1351', 'El Samán Bridge', '2015', 'Miranda', 'Venezuela', 'in use']
# ['1352', 'Elberon Avenue Bridge', '1936', 'Los Angeles (CA)', 'USA', 'in use']
# ['1353', 'Elbmarsch Viaduct', '1974', 'Hamburg (HH)', 'Germany', 'in use']
# ['1354', 'Elbschebach Bridge', '2002', 'Wetter (Ruhr) (NRW)', 'Germany', 'in use']
# ['1355', 'Elbsteg Herrenkrugpark', '1998', 'Magdeburg (ST)', 'Germany', 'in use']
# ['1356', 'Elgin Bridge', '1929', 'Singapore', 'Singapore', 'in use']
# ['1357', 'Elgoibar Viaduct', '', 'Elgóibar', 'Spain', 'in use']
# ['1358', 'Eliot Bridge', '1950', '- Boston (MA)', 'USA', 'in use']
# ['1359', 'Elizabeth Way Bridge', '1971', 'Cambridge (GB-ENG)', 'United Kingdom', 'in use']
# ['1360', 'Elkahatchee Creek Bridge', '1931', 'Tallapoosa County (AL)', 'USA', 'in use']
# ['1361', 'Ellera Viaduct', '', 'Corciano (UM)', 'Italy', 'in use']
# ['1362', 'Ellis Memorial Bridge', '1926', 'Newfoundland and Labrador (NL)', 'Canada', 'in use']
# ['1363', 'Elsenbrücke', '1968', '- Berlin (BE)', 'Germany', 'partially in service']
# ['1364', 'Elsensteg', '', 'Berlin (BE)', 'Germany', 'in use']
# ['1365', 'Elsterbrücke A38', '2005', 'Leipzig (SN)', 'Germany', 'in use']
# ['1366', 'Elsterbrücke Jessen', '1965', 'Jessen (Elster) (ST)', 'Germany', 'in use']
# ['1367', 'Eltmann Bridge', '2006', 'Eltmann (BY)', 'Germany', 'in use']
# ['1368', 'Elwha River Bridge', '2009', 'Clallam County (WA)', 'USA', 'in use']
# ['1369', 'Elz Viaduct', '1967', 'Kehrig (RP)', 'Germany', 'in use']
# ['1370', 'Emanuele Filliberto Bridge', '', 'Turin (PM)', 'Italy', 'in use']
# ['1371', 'Emílio Baumgart Bridge', '1930', "Herval d'Oeste (SC)", 'Brazil', 'destroyed']
# ['1372', 'Emmendingen Bridge', '1949', 'Emmendingen (BW)', 'Germany', 'in use']
# ['1373', 'Emmenschachen Bridge', '1922', 'Zielebach (BE)', 'Switzerland', 'in use']
# ['1374', 'Emmenweid Bridge', '1943', '- Emmen (LU)', 'Switzerland', 'in use']
# ['1375', 'Emmeramssteg', '', '- Munich (BY)', 'Germany', 'demolished']
# ['1376', 'Emmeramssteg', '2004', 'Munich (BY)', 'Germany', 'in use']
# ['1377', 'Empalme Metro Bridge', '', '- Burjassot', 'Spain', 'in use']
# ['1378', 'Empalot Bridge', '1977', 'Toulouse (31)', 'France', 'in use']
# ['1379', 'Empalot Bridge (A620)', '1995', 'Toulouse (31)', 'France', 'in use']
# ['1380', "Emperor's Bridge", '', 'Sarajevo', 'Bosnia and Herzegovina', 'in use']
# ['1381', 'Emskirchen Viaduct', '2016', 'Emskirchen (BY)', 'Germany', 'in use']
# ['1382', 'Encamp Viaduct', '', 'Encamp', 'Andorra', 'in use']
# ['1383', 'Engeløy Bridge', '1978', 'Steigen', 'Norway', 'in use']
# ['1384', 'Enger Viaduct', '', 'Enger (NRW)', 'Germany', 'in use']
# ['1385', 'Engineer Carlos Fernández Casado Bridge', '1983', '- Los Barrios de Luna', 'Spain', 'in use']
# ['1386', 'Engis Bridge', '1950', 'Engis', 'Belgium', 'in use']
# ['1387', 'Engøysund Bridge', '1983', 'Vågan', 'Norway', 'in use']
# ['1388', 'Ennsbrücke B1', '', 'Enns (OOE)', 'Austria', 'in use']
# ['1389', 'Ennsbrücke Westbahn', '', 'Enns (OOE)', 'Austria', 'in use']
# ['1390', 'Entrance Gateway Metrolink Bridge', '2006', 'Manchester (GB-ENG)', 'United Kingdom', 'in use']
# ['1391', 'Entre Aguas Bridge', '2004', 'Madeira', 'Portugal', 'in use']
# ['1392', 'Enz Viaduct', '', 'Vaihingen an der Enz (BW)', 'Germany', 'in use']
# ['1393', 'Enzenstetten Viaduct', '2010', 'Hopferau (BY)', 'Germany', 'in use']
# ['1394', 'Épinay Bridge', '', 'Épinay-sur-Seine (93)', 'France', 'in use']
# ['1395', 'Erdberger Brücke', '1971', 'Vienna', 'Austria', 'demolished']
# ['1396', 'Erdberger Brücke', '2016', 'Vienna', 'Austria', 'in use']
# ['1397', 'Erftbrücke Am Römerlager', '', 'Neuss (NRW)', 'Germany', 'in use']
# ['1398', 'Ergo Road Pedestrian Bridge', '2017', 'Brakpan', 'South Africa', 'in use']
# ['1399', 'Ernest F. Lyons Bridge', '2007', 'Stuart (FL)', 'USA', 'in use']
# ['1400', 'Ernesto Dornelles Bridge', '1952', 'Bento Gonçalves (RS)', 'Brazil', 'in use']
# ['1401', 'Errenteria Overfly', '', 'Errenteria', 'Spain', 'in use']
# ['1402', 'Erzebach Viaduct', '', 'Neuenstein (HE)', 'Germany', 'in use']
# ['1403', 'Erzherzog Karl Elevated Rail Bridge', '', 'Vienna', 'Austria', 'in use']
# ['1404', 'Erzherzog-Johann-Brücke', '', 'Graz (STM)', 'Austria', 'in use']
# ['1405', 'Esbly Bridge', '1949', '- Isles-lès-Villenoy (77)', 'France', 'in use']
# ['1406', "Escale Dam l'", '1963', '- Château-Arnoux-Saint-Auban (4)', 'France', 'in use']
# ['1407', 'Escalès Footbridge', '2006', 'Saint-Sever (40)', 'France', 'in use']
# ['1408', 'Eschachtalbrücke', '1977', 'Rottweil (BW)', 'Germany', 'in use']
# ['1409', 'Eschwege Bridge', '', 'Eschwege (HE)', 'Germany', 'in use']
# ['1410', 'Esclangon Bridge', '1986', 'Grenoble (38)', 'France', 'in use']
# ['1411', 'Eselsbachtalbrücke', '2004', 'Kaiserslautern (RP)', 'Germany', 'in use']
# ['1412', 'Eshima Bridge', '2004', 'Matsue', 'Japan', 'in use']
# ['1413', 'Esneux Bridge', '', 'Esneux', 'Belgium', 'in use']
# ['1414', 'Esperanto Bridge', '1948', 'Liège', 'Belgium', 'demolished']
# ['1415', 'Espéraza Footbridge', '', 'Espéraza (11)', 'France', 'in use']
# ['1416', 'Espiñeriro Viaduct', '2000', 'Lugo', 'Spain', 'in use']
# ['1417', 'Essinge Bridge', '1967', 'Stockholm', 'Sweden', 'in use']
# ['1418', 'Estacade de la Couronne', '', 'La Couronne (16)', 'France', 'completed']
# ['1419', 'Estacade de la Falaise', '', 'Cubzac-les-Ponts (33)', 'France', 'completed']
# ['1420', 'Estacade de la Folie', '', 'Poitiers (86)', 'France', 'completed']
# ['1421', 'Estadio Metro Station', '1996', 'Medellin', 'Colombia', 'in use']
# ['1422', 'Étaples Station Footbridge', '', 'Etaples (62)', 'France', 'in use']
# ['1423', 'Ettehad Melli Bridge', '2007', 'Tabriz', 'Iran', 'in use']
# ['1424', 'Etzelsbachtalbrücke', '2003', 'Wingerode (TH)', 'Germany', 'in use']
# ['1425', 'Eulenkamp Bridge', '1911', 'Hanover (NI)', 'Germany', 'demolished']
# ['1426', 'Eume River Bridge (AP-9)', '', '- Pontedeume', 'Spain', 'in use']
# ['1427', 'Europa Bridge', '', 'Pescia (TC)', 'Italy', 'in use']
# ['1428', 'Europabrücke', '1962', 'Zurich (ZH)', 'Switzerland', 'in use']
# ['1429', 'Europabrug', '1972', 'Vilvoorde', 'Belgium', 'in use']
# ['1430', 'Europe Bridge', '1954', 'Koblenz (RP)', 'Germany', 'in use']
# ['1431', 'Europe Bridge', '1983', 'Hamburg (HH)', 'Germany', 'in use']
# ['1432', 'Europe Bridge', '1978', 'Frankfurt (HE)', 'Germany', 'in use']
# ['1433', 'Europe Bridge', '1984', 'Fumel (47)', 'France', 'in use']
# ['1434', 'Euskaldun berria zubia', '2009', 'Tolosa', 'Spain', 'in use']
# ['1435', 'Eutinger Waagsteg', '1991', 'Pforzheim (BW)', 'Germany', 'in use']
# ['1436', 'Evans Crary Sr. Bridge', '2001', 'Stuart (FL)', 'USA', 'in use']
# ['1437', 'Eve Street Viaduct', '2001', 'Sydney (NSW)', 'Australia', 'in use']
# ['1438', 'Evelated road Francisco Silvela-Joaquin Costa', '', 'Madrid', 'Spain', 'demolished']
# ['1439', 'Evelyn Moakley Bridge', '', 'Boston (MA)', 'USA', 'in use']
# ['1440', 'Evripos Bridge', '1992', 'Chalcis', 'Greece', 'in use']
# ['1441', 'Evry Bridge', '', '- Etiolles (91)', 'France', 'in use']
# ['1442', 'Exposiciones Metro Station', '1995', 'Medellin', 'Colombia', 'in use']
# ['1443', 'Exter Viaduct', '1998', 'Vlotho (NRW)', 'Germany', 'in use']
# ['1444', 'Fachbach-Nievern Bridge', '1928', 'Fachbach (RP)', 'Germany', 'in use']
# ['1445', 'Faery Bridge', '1911', 'Dunblane (GB-SCT)', 'United Kingdom', 'in use']
# ['1446', 'Fairfield Bridge', '1937', 'Hamilton', 'New Zealand', 'in use']
# ['1447', 'Fairfield Bridge', '1937', 'Fairfield', 'New Zealand', 'in use']
# ['1448', 'Fairfield Street Bridge', '', 'Manchester (GB-ENG)', 'United Kingdom', 'in use']
# ['1449', 'Fairmont Avenue Overpass (I-70)', '', 'Collinsville (IL)', 'USA', 'in use']
# ['1450', 'Fairmount Avenue Bridge', '2003', 'Jamestown (NY)', 'USA', 'in use']
# ['1451', 'Fairway Road Bridge', '', 'Kitchener (ON)', 'Canada', 'in use']
# ['1452', 'Fajir Bridge', '1976', 'Fajir', 'Iraq', 'in use']
# ['1453', 'Falconara 1 Viaduct', '', 'Falconara Marittima (MH)', 'Italy', 'in use']
# ['1454', 'Falkenstein Bridge', '1973', 'Obervellach (KTN)', 'Austria', 'in use']
# ['1455', 'Fallersleber-Tor-Brücke', '2011', 'Brunswick (NI)', 'Germany', 'in use']
# ['1456', 'Fallujah Bridge', '1967', 'Fallujah', 'Iraq', 'in use']
# ['1457', 'Färjsund Bridge', '1981', 'Mariehamn', 'Finland', 'in use']
# ['1458', 'Fatala River Bridge', '2004', 'Boffa', 'Guinea', 'in use']
# ['1459', 'Fatihita Bridge', '', 'Fatihita', 'Madagascar', 'destroyed']
# ['1460', 'Fatihita Bridge', '2005', 'Fatihita', 'Madagascar', 'in use']
# ['1461', 'Fausto Bisantis Bridge', '1961', 'Catanzaro (CI)', 'Italy', 'in use']
# ['1462', 'Favazzina Viaduct', '1966', 'Scilla (CI)', 'Italy', 'demolished']
# ['1463', 'Feeder Road Bridge', '', 'Bristol (GB-ENG)', 'United Kingdom', 'in use']
# ['1464', 'Fehrlesteg', '2011', 'Schwäbisch Gmünd (BW)', 'Germany', 'in use']
# ['1465', 'Feldmoching Overpass', '1992', 'Munich (BY)', 'Germany', 'in use']
# ['1466', 'Felice Bridge', '1949', 'Civita Castellana (LZ)', 'Italy', 'in use']
# ['1467', 'Felipe Pazos Bridge', '1956', 'Sagua la Grande', 'Cuba', 'in use']
# ['1468', 'Félix Houphouët-Boigny Bridge', '1957', 'Abidjan', 'Côte d', 'in use']
# ['1469', 'Fella I Viaduct', '1986', 'Moggio Udinese (FB)', 'Italy', 'in use']
# ['1470', 'Fella II Viaduct', '1986', 'Chiusaforte (FB)', 'Italy', 'in use']
# ['1471', 'Fella IV Viaduct', '1986', 'Chiusaforte (FB)', 'Italy', 'in use']
# ['1472', 'Fella Railroad Viaduct', '1995', 'Amaro (FB)', 'Italy', 'in use']
# ['1473', 'Fella V Viaduct', '1986', 'Dogna (FB)', 'Italy', 'in use']
# ['1474', 'Fella VI Viaduct', '', 'Pontebba (FB)', 'Italy', 'in use']
# ['1475', 'Fella VII Viaduct', '1986', 'Pontebba (FB)', 'Italy', 'in use']
# ['1476', 'Fella VIII Viaduct', '1986', 'Pontebba (FB)', 'Italy', 'in use']
# ['1477', 'Fella X Viaduct', '1986', 'Tarvisio (FB)', 'Italy', 'in use']
# ['1478', 'Felli Viaduct', '', 'Gurtnellen (UR)', 'Switzerland', 'in use']
# ['1479', 'Felsegg Bridge', '1932', 'Uzwil (SG)', 'Switzerland', 'in use']
# ['1480', 'Felsenau Viaduct', '1974', 'Berne (BE)', 'Switzerland', 'in use']
# ['1481', 'Felsenbach Bridge', '1963', '- Valzeina (GR)', 'Switzerland', 'in use']
# ['1482', 'Felsenbach Bridge (II)', '', '- Valzeina (GR)', 'Switzerland', 'in use']
# ['1483', 'Fengping Bridge, New', '', 'Shoufeng', 'Taiwan', 'in use']
# ['1484', 'Fengshihe River Viaduct', '2008', 'Jiyuan', 'China', 'in use']
# ['1485', 'Fenhe Rail Bridge Menghua', '2019', 'Hejin', 'China', 'in use']
# ['1486', 'Fenice Viaduct', '', '- Cercola (CM)', 'Italy', 'in use']
# ['1487', 'Fenouillet Bridge', '', 'Fenouillet (31)', 'France', 'in use']
# ['1488', 'Fensterbach Viaduct', '2007', 'Fensterbach (BY)', 'Germany', 'in use']
# ['1489', 'Feo Viaduct', '', 'Perugia (UM)', 'Italy', 'in use']
# ['1490', 'Ferdinando di Savoia Bridge', '1928', 'Turin (PM)', 'Italy', 'in use']
# ['1491', 'Fern Bridge', '1911', 'Ferndale (CA)', 'USA', 'in use']
# ['1492', 'Fern Canyon Bridge', '1931', 'Los Angeles County (CA)', 'USA', 'in use']
# ['1493', 'Fern Dell Drive Bridge', '1923', 'Los Angeles (CA)', 'USA', 'in use']
# ['1494', 'Fernando Hué Viaduct', '1929', 'Teruel', 'Spain', 'in use']
# ['1495', 'Fernando Reig Bridge', '1987', 'Alcoy', 'Spain', 'in use']
# ['1496', 'Ferreiras Viaduct (A-6)', '2000', 'Lugo', 'Spain', 'in use']
# ['1497', 'Ferriere Viaduct', '1975', 'La Spezia (LG)', 'Italy', 'in use']
# ['1498', 'Ferrières Bridges', '', 'Martigues (13)', 'France', 'in use']
# ['1499', 'FEUP Foobridge', '', 'Porto', 'Portugal', 'in use']
# ['1500', 'Fiddler’s Elbow Bridge', '1915', 'Newark (GB-ENG)', 'United Kingdom', 'in use']
# ['1501', 'Fiddletown Road Bridge', '1930', 'Fiddletown (CA)', 'USA', 'in use']
# ['1502', 'Fifth Ahvaz Bridge', '1996', 'Ahvaz', 'Iran', 'in use']
# ['1503', 'Fifth Dezful Bridge', '2012', 'Dezful', 'Iran', 'in use']
# ['1504', 'Fifth Street Bridge', '2008', 'Atlanta (GA)', 'USA', 'in use']
# ['1505', 'Figols Suspension Bridge', '1984', 'Organyà', 'Spain', 'in use']
# ['1506', 'Filssteg', '2008', 'Süßen (BW)', 'Germany', 'in use']
# ['1507', 'Filstalbrücke', '2022', 'Mühlhausen (BW)', 'Germany', 'under construction']
# ['1508', 'Fin sous Montoz Bridges', '2017', 'Sorvilier (BE)', 'Switzerland', 'in use']
# ['1509', 'Finley Road Bridge', '', 'Downers Grove (IL)', 'USA', 'in use']
# ['1510', 'Finnevik Bridge', '2015', 'Espoo', 'Finland', 'in use']
# ['1511', 'First Avenue Bridge', '1920', 'Cedar Rapids (IA)', 'USA', 'in use']
# ['1512', 'First Cloister Bridge', '1972', 'Saint Petersburg', 'Russia', 'in use']
# ['1513', 'First Narmada Bridge', '', 'Bharuch', 'India', 'in use']
# ['1514', 'First Street Bridge (Napa River)', '1915', 'Napa (CA)', 'USA', 'demolished']
# ['1515', 'First Street Los Angeles River Bridge', '1929', 'Los Angeles (CA)', 'USA', 'in use']
# ['1516', 'First Thai–Lao Friendship Bridge', '1994', '- Nong Khai', 'Thailand', 'in use']
# ['1517', 'Fischerdorf Bridge', '1991', 'Deggendorf (BY)', 'Germany', 'in use']
# ['1518', 'Fischerhaus Viaduct', '2000', 'Windhagen (RP)', 'Germany', 'in use']
# ['1519', 'Fish River Bridge', '1940', 'Otago', 'New Zealand', 'in use']
# ['1520', 'Fisherman Inlet Bridge', '1965', 'Northampton County (VA)', 'USA', 'in use']
# ['1521', "Fishermen's Bridge", '1963', 'Kyiv', 'Ukraine', 'out of service']
# ['1522', 'Fishery Port Disembarkation Quay', '2001', 'La Turballe (44)', 'France', 'in use']
# ['1523', 'Fitzherbert Bridge', '1935', 'Palmerston North', 'New Zealand', 'demolished']
# ['1524', 'Fitzherbert Bridge', '', 'Palmerston North', 'New Zealand', 'in use']
# ['1525', 'FIU-Sweetwater Pedestrian Bridge', '2018', 'Miami (FL)', 'USA', 'collapsed']
# ['1526', 'Fiumarella Viaduct', '', 'Catanzaro (CI)', 'Italy', 'in use']
# ['1527', 'Flaesheimer Damm Bridge', '1963', 'Haltern am See (NRW)', 'Germany', 'in use']
# ['1528', 'Flaminia Viaduct', '', 'Perugia (UM)', 'Italy', 'in ruins']
# ['1529', 'Flehe Bridge', '1979', '- Düsseldorf (NRW)', 'Germany', 'in use']
# ['1530', 'Fleissenbachtalbrücke Bad Brambach', '2001', 'Bad Brambach (SN)', 'Germany', 'in use']
# ['1531', 'Fleurimont Viaduct', '', 'Saint-Paul', 'Réunion', 'in use']
# ['1532', 'Fleurus Motorway Bridge (E42)', '', 'Fleurus', 'Belgium', 'in use']
# ['1533', 'Fleury Bridge', '1927', 'Fleury (11)', 'France', 'in use']
# ['1534', 'Flintshire Bridge', '1997', 'Shotton (GB-WLS)', 'United Kingdom', 'in use']
# ['1535', 'Flora Bridge', '1963', 'Mülheim an der Ruhr (NRW)', 'Germany', 'in use']
# ['1536', 'Floresta Metro Station', '1996', 'Medellin', 'Colombia', 'in use']
# ['1537', 'Floriffoux Bridge', '', 'Floreffe', 'Belgium', 'in use']
# ['1538', 'Flösserbrücke', '1986', 'Frankfurt (HE)', 'Germany', 'in use']
# ['1539', 'Flutbrücke I der Ortsumgehung Bernburg', '2014', 'Bernburg (Saale) (ST)', 'Germany', 'in use']
# ['1540', 'Flutbrücke II der Ortsumgehung Bernburg', '2013', 'Bernburg (Saale) (ST)', 'Germany', 'in use']
# ['1541', 'Flutbrücke III der Ortsumgehung Bernburg', '2014', 'Bernburg (Saale) (ST)', 'Germany', 'in use']
# ['1542', 'Flutgrabenbrücke Wernshausen', '2000', 'Schmalkalden (TH)', 'Germany', 'in use']
# ['1543', 'Flutmuldenbrücke Meppen-Versen', '2021', 'Meppen (NI)', 'Germany', 'under construction']
# ['1544', 'Fnjóskárbrú', '1908', 'Þingeyjarsveit', 'Iceland', 'in use']
# ['1545', 'Fölkenbach Footbridge', '1974', '- Echternach', 'Luxembourg', 'in use']
# ['1546', 'Fontainebleau Aqueduct', '1875', 'Fontainebleau (77)', 'France', 'in use']
# ['1547', 'Fontejau Bridge', '', 'Girona', 'Spain', 'in use']
# ['1548', 'Fontenoy-sur-Moselle Bridge', '', 'Fontenoy-sur-Moselle (54)', 'France', 'in use']
# ['1549', 'Footbridge across Rålambshovsleden', '', 'Stockholm', 'Sweden', 'in use']
# ['1550', 'Footbridge across the B33', '', 'Konstanz (BW)', 'Germany', 'in use']
# ['1551', 'Footbridge across the Hahnenbach', '', 'Gladbeck (NRW)', 'Germany', 'in use']
# ['1552', 'Footbridge in the Charlottenburg Castle Gardens', '2007', 'Berlin (BE)', 'Germany', 'in use']
# ['1553', 'Footbridge over A-8', '', 'Bilbao', 'Spain', 'in use']
# ['1554', 'Footbridge over Ballatoni Auzoa', '', 'Portugalete', 'Spain', 'in use']
# ['1555', 'Footbridge over Hringbraut at Landspitali', '', 'Reykjavik', 'Iceland', 'in use']
# ['1556', 'Footbridge over Hringbraut at Njardargata', '', 'Reykjavik', 'Iceland', 'in use']
# ['1557', 'Foothill Boulevard Pacoima Wash Bridge', '1923', 'Los Angeles (CA)', 'USA', 'in use']
# ['1558', 'Fornaci Viaduct', '1968', 'Lugano (TI)', 'Switzerland', 'in use']
# ['1559', 'Fornello Viaduct', '', 'Verghereto (ER)', 'Italy', 'demolished']
# ['1560', 'Forstwerderbrücke', '1928', 'Halle/Saale (ST)', 'Germany', 'in use']
# ['1561', 'Fort Edmonton Footbridge', '2010', 'Edmonton (AB)', 'Canada', 'in use']
# ['1562', 'Fort Morgan Bridge', '1923', 'Fort Morgan (CO)', 'USA', 'in use']
# ['1563', 'Forte da Casa Footbridge', '2014', 'Vila Franca da Xira', 'Portugal', 'in use']
# ['1564', 'Fossa Viaduct', '1996', 'Sarsina (ER)', 'Italy', 'in use']
# ['1565', 'Fosseland Bridge', '', 'Agder', 'Norway', 'in use']
# ['1566', 'Fosso Valbiano Viaduct', '1996', 'Sarsina (ER)', 'Italy', 'in use']
# ['1567', 'Fournens Viaduct', '', 'Lozère (48) (48)', 'France', 'project phase']
# ['1568', 'Fourth Dezful Bridge', '2008', 'Dezful', 'Iran', 'in use']
# ['1569', 'Fourth Mosul Bridge', '1981', 'Mosul', 'Iraq', 'destroyed']
# ['1570', 'Fourth Ring Road Ebro River Bridge', '2008', 'Zaragoza', 'Spain', 'in use']
# ['1571', 'Fourth Street Bridge', '1930', 'Los Angeles (CA)', 'USA', 'in use']
# ['1572', 'Fourth Street Bridge', '1928', 'Los Angeles (CA)', 'USA', 'in use']
# ['1573', 'Foyle Bridge', '1984', 'Derry (GB-NIR)', 'United Kingdom', 'in use']
# ['1574', 'Foz do Sousa Bridge', '1952', 'Foz do Sousa', 'Portugal', 'in use']
# ['1575', 'Fradinina Bridge', '', 'Split-Dalmatia', 'Croatia', 'in use']
# ['1576', 'Fraga Bridge', '1943', 'Fraga', 'Spain', 'in use']
# ['1577', 'Francardo Bridge', '', 'Omessa (2B)', 'France', 'in use']
# ['1578', 'Franchetti Bridge', '1928', 'Bry-sur-Marne (94)', 'France', 'in use']
# ['1579', 'Francin Bridge', '', 'Francin (73)', 'France', 'in use']
# ['1580', 'Francis Scott Key Bridge', '1923', 'Washington', 'USA', 'in use']
# ['1581', 'François Mitterand Bridge', '1993', '- Bègles (33)', 'France', 'in use']
# ['1582', 'Franconia Bridge', '1994', 'Coburg (BY)', 'Germany', 'in use']
# ['1583', 'Franjo Tudjman Bridge', '2002', 'Dubrovnik', 'Croatia', 'in use']
# ['1584', 'Frankenberg Cycle Bridge', '', 'Frankenberg (SN)', 'Germany', 'in use']
# ['1585', 'Frankfurt Motorway Bridge', '1957', 'Frankfurt on the Oder (BB)', 'Germany', 'in use']
# ['1586', 'Frankfurt Motorway Bridge', '1997', 'Frankfurt on the Oder (BB)', 'Germany', 'in use']
# ['1587', 'Franklin Avenue Bridge', '1925', 'Los Angeles (CA)', 'USA', 'in use']
# ['1588', 'Fraterstraat Suspension Bridge', '', 'Merelbeke', 'Belgium', 'in use']
# ['1589', 'Frauenwald Viaduct', '1986', 'Kraichtal (BW)', 'Germany', 'in use']
# ['1590', 'Freai Bridge', '1986', 'Japan', 'Japan', 'in use']
# ['1591', 'Frébuge Viaduct', '1988', 'Saint-Germain-de-Joux (1)', 'France', 'in use']
# ['1592', 'Fred G. Redmon Bridge', '1971', 'Yakima County (WA)', 'USA', 'in use']
# ['1593', 'Fred Hartman Bridge', '1995', 'Baytown (TX)', 'USA', 'in use']
# ['1594', 'Fredhäll Bridge', '', 'Stockholm', 'Sweden', 'in use']
# ['1595', 'Frednes Bridge', '1995', 'Porsgrunn', 'Norway', 'in use']
# ['1596', 'Fredriksdalsbron', '2002', 'Stockholm', 'Sweden', 'in use']
# ['1597', "Freeman's Crossing Bridge", '1921', 'North San Juan (CA)', 'USA', 'demolished']
# ['1598', 'Freeport Bridge', '', 'Kitchener (ON)', 'Canada', 'in use']
# ['1599', 'Freiberger Mulde Bridge', '1999', 'Leisnig (SN)', 'Germany', 'in use']
# ['1600', 'Freiburger Strasse Bridge', '1967', 'Emmendingen (BW)', 'Germany', 'in use']
# ['1601', 'Freiwalde Overpass', '1993', 'Bersteland (BB)', 'Germany', 'in use']
# ['1602', 'Fremont Avenue Bridge', '1911', 'Los Altos (CA)', 'USA', 'in use']
# ['1603', 'French Creek Viaduct', '', 'Glenwood Canyon (CO)', 'USA', 'in use']
# ['1604', 'Freudenauer Hafenbrücke', '1958', 'Vienna', 'Austria', 'in use']
# ['1605', 'Friars Bridge', '1987', 'Inverness (GB-SCT)', 'United Kingdom', 'in use']
# ['1606', 'Frías Bridge', '1927', 'Frías', 'Spain', 'in use']
# ['1607', 'Fridolinsbrücke', '1979', '- Bad Säckingen (BW)', 'Germany', 'in use']
# ['1608', 'Frieda Bridge', '', 'Meinhard (HE)', 'Germany', 'in use']
# ...
# ['5778', 'West Golf Cart Bridge', '', 'Rancho Santa Fe (CA)', 'USA', 'in use']
# ['5779', 'West Kowloon North Expressway Footbridge D', '1997', 'Hong Kong', 'China', 'in use']
# ['5780', 'West LaSalle Drive Underpass', '', 'Chicago (IL)', 'USA', 'in use']
# ['5781', 'West Link Bridge', '1990', 'Dublin', 'Ireland', 'in use']
# ['5782', 'West Link Bridge', '2003', 'Dublin', 'Ireland', 'in use']
# ['5783', 'West Sixth Street Bridge', '1920', 'The Dalles (OR)', 'USA', 'in use']
# ['5784', 'West Trenton Railroad Bridge', '1913', 'Ewing (NJ)', 'USA', 'in use']
# ['5785', 'West Verdi Bridge', '1939', 'Verdi (NV)', 'USA', 'in use']
# ['5786', 'Westerlo N19 Overfly Bridge', '', 'Westerlo', 'Belgium', 'in use']
# ['5787', 'Western Avenue Bridge', '1924', '- Boston (MA)', 'USA', 'in use']
# ['5788', 'Western Bridge over the Canal E.D.F.', '', 'Saint-Paul-lès-Durance (13)', 'France', 'in use']
# ['5789', 'Western Hills Viaduct', '1932', 'Cincinnati (OH)', 'USA', 'in use']
# ['5790', 'Westewitz Bridge', '', 'Großweitzschen (SN)', 'Germany', 'in use']
# ['5791', 'Westfield Pill Bridge', '', 'Pembrokeshire (GB-WLS)', 'United Kingdom', 'in use']
# ['5792', 'Westhofen Bridge', '1976', '- Schwerte (NRW)', 'Germany', 'in use']
# ['5793', 'Westpark Footbridge', '1999', 'Bochum (NRW)', 'Germany', 'in use']
# ['5794', 'Westtangente Bridge at Kelheim', '1988', 'Kelheim (BY)', 'Germany', 'in use']
# ['5795', 'Westway Viaduct', '1970', '- London (GB-ENG)', 'United Kingdom', 'in use']
# ['5796', 'Weteritz Bridge', '1995', 'Gardelegen (ST)', 'Germany', 'in use']
# ['5797', 'Wetteren Footbridge', '1957', 'Wetteren', 'Belgium', 'demolished']
# ['5798', 'Wettersbach Viaduct', '1993', 'Karlsruhe (BW)', 'Germany', 'in use']
# ['5799', 'Weyermannshaus Viaduct', '1977', 'Berne (BE)', 'Switzerland', 'in use']
# ['5800', 'Weygand Bridge', '1947', 'Sassandra', 'Côte d', 'in use']
# ['5801', 'Whangamomona River Bridge', '1937', 'Manawatu-Wanganui', 'New Zealand', 'in use']
# ['5802', 'Whanganui City Bridge', '', 'Whanganui', 'New Zealand', 'in use']
# ['5803', 'Whilamut Passage Bridge', '2013', 'Eugene (OR)', 'USA', 'in use']
# ['5804', 'White Elster Valley Bridge', '1993', 'Weischlitz (SN)', 'Germany', 'in use']
# ['5805', 'White Elster Viaduct', '2000', 'Gera (TH)', 'Germany', 'in use']
# ['5806', 'Whites Creek Aqueduct', '1896', 'Sydney (NSW)', 'Australia', 'in use']
# ['5807', 'Wied Viaduct', '1999', 'Neustadt (Wied) (RP)', 'Germany', 'in use']
# ['5808', 'Wied Viaduct', '', 'Neustadt (Wied) (RP)', 'Germany', 'in use']
# ['5809', 'Wierdenschebrug', '1951', 'Almelo', 'Netherlands', 'in use']
# ['5810', 'Wiese Viaduct', '1983', 'Lörrach (BW)', 'Germany', 'in use']
# ['5811', 'Wiese Viaduct', '1980', 'Basel (BS)', 'Switzerland', 'in use']
# ['5812', 'Wiesebrücke Kleinhüningerstrasse', '', 'Basel (BS)', 'Switzerland', 'in use']
# ['5813', 'Wiesedamm Bridge', '', 'Basel (BS)', 'Switzerland', 'in use']
# ['5814', 'Wiesenbrücke', '', 'Jena (TH)', 'Germany', 'in use']
# ['5815', 'Wiesenbrücke', '1912', 'Schopfheim (BW)', 'Germany', 'in use']
# ['5816', 'Wiesenbrücke bei der Kastler Mühle', '1909', 'Fröhnd (BW)', 'Germany', 'in use']
# ['5817', 'Wiesental Viaduct', '2004', 'Suhl (TH)', 'Germany', 'in use']
# ['5818', 'Wieslauf Viaduct', '1995', 'Schorndorf (BW)', 'Germany', 'in use']
# ['5819', 'Wijnegem Lock Bridge', '', 'Wijnegem', 'Belgium', 'in use']
# ['5820', 'Wil-Cox Bridge', '1922', 'Davidson County (NC)', 'USA', 'in use']
# ['5821', 'Wild Gera Viaduct', '2000', 'Ilmenau (TH)', 'Germany', 'in use']
# ['5822', 'Wildbichler Brücke', '1969', 'Kufstein (TIR)', 'Austria', 'in use']
# ['5823', 'Wildbrücke Völkermarkt', '2010', 'Völkermarkt (KTN)', 'Austria', 'in use']
# ['5824', 'Wildshausener Strasse Bridge', '1990', 'Arnsberg (NRW)', 'Germany', 'in use']
# ['5825', 'Wilhelm Heinrich Bridge', '1961', 'Saarbrücken (SL)', 'Germany', 'in use']
# ['5826', 'Wilhelm Spindler Bridge', '2002', 'Berlin (BE)', 'Germany', 'in use']
# ['5827', 'Wilhelmasteg', '1977', 'Stuttgart (BW)', 'Germany', 'demolished']
# ['5828', 'Wilhelmssteg', '1898', 'Erfurt (TH)', 'Germany', 'in use']
# ['5829', 'Wilhelmstraße Footbridge', '1961', 'Wetter (Ruhr) (NRW)', 'Germany', 'in use']
# ['5830', 'Willenscharen Bridge', '1990', 'Willenscharen (SH)', 'Germany', 'in use']
# ['5831', 'Willey Road Bridge', '1931', 'Crosby Township (OH)', 'USA', 'in use']
# ['5832', 'William Cannon Bridge', '2001', 'Austin (TX)', 'USA', 'in use']
# ['5833', 'William Cullen Bryant Bridge', '2012', 'Roslyn (NY)', 'USA', 'in use']
# ['5834', 'William Duby Bridge', '1925', 'Umatilla County (OR)', 'USA', 'demolished']
# ['5835', 'William Howard Taft Bridge', '1907', 'Washington', 'USA', 'in use']
# ['5836', 'William Natcher Bridge', '2002', 'Owensboro (KY)', 'USA', 'in use']
# ['5837', 'Willy Brandt Bridge', '1995', 'Nantes (44)', 'France', 'in use']
# ['5838', 'Willy Brandt Street Pedestrian Bridge', '1989', 'Stuttgart (BW)', 'Germany', 'in use']
# ['5839', 'Wilrijk Viaduct', '1970', 'Antwerp', 'Belgium', 'in use']
# ['5840', 'Wilson River Bridge', '1931', 'Tillamook (OR)', 'USA', 'in use']
# ['5841', 'Winchester Bridge', '1924', 'Douglas County (OR)', 'USA', 'in use']
# ['5842', 'Windelbach Viaduct', '1969', 'Herborn (HE)', 'Germany', 'under demolition']
# ['5843', 'Windsor Road Bridge', '2019', 'Rouse Hill (NSW)', 'Australia', 'under construction']
# ['5844', 'Windward Viaducts', '1993', 'Oahu Island (HI)', 'USA', 'in use']
# ['5845', 'Winkelbrücke', '', 'Klosters-Serneus (GR)', 'Switzerland', 'in use']
# ['5846', 'Winnenden B14 Bridge', '2006', 'Winnenden (BW)', 'Germany', 'in use']
# ['5847', 'Wipfratal Viaduct', '', 'Wipfratal (TH)', 'Germany', 'in use']
# ['5848', 'Wipper Viaduct (A 38)', '', '- Werther (TH)', 'Germany', 'in use']
# ['5849', 'Wirrbach Viaduct', '2003', 'Geschwenda (TH)', 'Germany', 'in use']
# ['5850', 'Wirtschaftswegüberführung über Strecke 77', '', 'Welver (NRW)', 'Germany', 'never used']
# ['5851', 'Wiscasset Bridge', '1981', 'Wiscasset (ME)', 'USA', 'in use']
# ['5852', 'Wisconsin Avenue Viaduct', '1993', 'Milwaukee (WI)', 'USA', 'in use']
# ['5853', 'Wisentabrücke Schleiz', '2001', 'Schleiz (TH)', 'Germany', 'in use']
# ['5854', 'Witten Viaduct', '1916', 'Witten (NRW)', 'Germany', 'in use']
# ['5855', 'Witten-Bommern Bridge', '1936', 'Witten (NRW)', 'Germany', 'demolished']
# ['5856', 'Wohlrosetalbrücke', '', 'Gehren (TH)', 'Germany', 'in use']
# ['5857', 'Woippy Viaduct', '1975', 'Maizières-lès-Metz (57)', 'France', 'in use']
# ['5858', 'Wolcott Bridge', '1910', 'Wolcott (CO)', 'USA', 'in use']
# ['5859', 'Wölkau Bridge', '', 'Heidenau (SN)', 'Germany', 'in use']
# ['5860', 'Wommen Viaduct', '1993', 'Herleshausen (HE)', 'Germany', 'in use']
# ['5861', 'Wonhyo Grand Bridge', '1981', 'Seoul', 'South Korea', 'in use']
# ['5862', 'Woodin Avenue Bridge', '', 'Chelan (WA)', 'USA', 'in use']
# ['5863', 'Woong-Jin Second Bridge', '2004', 'Yanggu County', 'South Korea', 'in use']
# ['5864', 'Wormeldingen Bridge', '1964', 'Wormeldange', 'Luxembourg', 'in use']
# ['5865', 'Wörnitz Bridge', '1988', 'Dinkelsbühl (BY)', 'Germany', 'in use']
# ['5866', 'Wörnitz Flood Bridge', '1988', 'Dinkelsbühl (BY)', 'Germany', 'in use']
# ['5867', 'Woronora Bridge', '2001', 'Menai (NSW)', 'Australia', 'in use']
# ['5868', 'Wörsbachtalbrücke', '2001', 'Brechen (HE)', 'Germany', 'in use']
# ['5869', 'Worsham Street Bridge', '1928', 'Danville (VA)', 'USA', 'demolished']
# ['5870', 'Wörth Bridge', '1979', 'Wörth an der Donau (BY)', 'Germany', 'in use']
# ['5871', 'Wouri Bridge', '1954', 'Douala', 'Cameroon', 'in use']
# ['5872', 'Wrightstown Fox River Bridge', '2015', 'Wrightstown (WI)', 'USA', 'in use']
# ['5873', 'Wu Jiang Viaduct', '2008', 'Guizhou', 'China', 'in use']
# ['5874', 'Wujiang River Bridge', '2009', 'Chongqing', 'China', 'in use']
# ['5875', 'Wulong River Bridge', '1971', 'Fuzhou', 'China', 'in use']
# ['5876', 'Wulong River Railway Bridge', '', 'Fuzhou', 'China', 'in use']
# ['5877', 'Wümbachtalbrücke', '2005', '- Wolfsberg (TH)', 'Germany', 'in use']
# ['5878', 'Wünsch Bridge', '1896', 'Budapest', 'Hungary', 'in use']
# ['5879', 'Wupper-Talbrücke Oehde', '2001', 'Wuppertal (NRW)', 'Germany', 'in use']
# ['5880', 'Würenlos Limmat River Bridge (A 1)', '1970', 'Würenlos (AG)', 'Switzerland', 'in use']
# ['5881', 'Würtembergle Bridge', '1989', 'Radolfzell am Bodensee (BW)', 'Germany', 'in use']
# ['5882', 'Wuxi Bridge', '2001', 'Guizhou', 'China', 'in use']
# ['5883', 'Wuye Bridge', '', 'Abuja', 'Nigeria', 'in use']
# ['5884', 'Wuzeigou Bridge', '2010', 'Guizhou', 'China', 'in use']
# ['5885', 'Wykroty Overpass', '2008', 'Wykroty (DS)', 'Poland', 'in use']
# ['5886', 'Wysswasser Viaduct', '', 'Fiesch (VS)', 'Switzerland', 'in use']
# ['5887', 'Xiangjiang Railway Bridge', '', 'China', 'China', 'in use']
# ['5888', 'Xiangjiaomen Bridge', '2003', 'Zhoushan', 'China', 'in use']
# ['5889', 'Xiangtan Bridge', '1961', 'Xiangtan', 'China', 'in use']
# ['5890', 'Xianshen River Bridge', '2009', 'Jincheng', 'China', 'in use']
# ['5891', 'Xiaoguanshuiku Bridge', '2003', 'Guiyang', 'China', 'in use']
# ['5892', 'Xiaonanmen Bridge', '1990', 'Yibin', 'China', 'in use']
# ['5893', 'Xiaoxihu Yellow River Bridge', '2003', 'China', 'China', 'in use']
# ['5894', 'Xiaoyudong Bridge', '1999', 'Pengzhou', 'China', 'collapsed']
# ['5895', 'Xiasha Bridge', '2002', 'Hangzhou', 'China', 'in use']
# ['5896', 'Xihuahai Bridge', '2009', 'Guangdong', 'China', 'in use']
# ['5897', 'Xincheng Bridge', '1959', 'Lanzhou', 'China', 'in use']
# ['5898', 'Xingduicha Bridge', '2007', 'Fujian', 'China', 'in use']
# ['5899', 'XinWei Bridge', '', 'Kaohsiung', 'Taiwan', 'in use']
# ['5900', 'Xinwu Bridge', '1975', 'Shanghai', 'China', 'in use']
# ['5901', 'Xixi Bridge', '2001', 'Guizhou', 'China', 'in use']
# ['5902', 'Xu-Gou Bridge', '2001', 'Luoyang', 'China', 'in use']
# ['5903', 'Yabegawa River Bridge', '2009', 'Yanagawa', 'Japan', 'in use']
# ['5904', 'Yamuna Bridge', '', 'Kalpi', 'India', 'in use']
# ['5905', 'Yamuna Railway Bridge', '2000', 'Delhi', 'India', 'in use']
# ['5906', "Yan'an Elevated Road", '', 'Shanghai', 'China', 'in use']
# ['5907', 'Yanjinhe River Bridge', '2009', 'Renhuai', 'China', 'in use']
# ['5908', 'Yanjinhe River Bridge', '1995', 'Renhuai', 'China', 'in use']
# ['5909', 'Yanjinhe River Bridge', '2007', 'Renhuai', 'China', 'in use']
# ['5910', 'Yanokuchi Bridge', '2005', 'Inagi', 'Japan', 'in use']
# ['5911', 'Yanxigou Bridge', '2009', 'Chongqing', 'China', 'in use']
# ['5912', 'Yaro Bridge', '2016', 'South Gyeongsang', 'South Korea', 'in use']
# ['5913', 'Yarumo Blanco Viaduct', '2021', 'Quindío', 'Colombia', 'in use']
# ['5914', 'Yashiro Bridge', '1996', 'Chikuma', 'Japan', 'in use']
# ['5915', 'Ybbsbrücke BN 1.44', '', 'Amstetten (NOE)', 'Austria', 'in use']
# ['5916', 'Ybbsbrücke BN 1.45', '', 'Amstetten (NOE)', 'Austria', 'in use']
# ['5917', 'Yee Wo Street Footbridge', '', 'Hong Kong', 'China', 'in use']
# ['5918', 'Yen Lenh Bridge', '2004', 'Hà Nam', 'Vietnam', 'in use']
# ['5919', 'Yesan River Bridge', '2009', 'Hubei', 'China', 'in use']
# ['5920', 'Yesanhe River Bridge', '1977', 'Hubei', 'China', 'in use']
# ['5921', 'Yibin Bridge', '1973', 'Yibin', 'China', 'completed']
# ['5922', 'Yigal Yadin Bridge', '2002', 'Jerusalem', 'Israel', 'in use']
# ['5923', 'Yiling Yangtze River Bridge', '2001', 'Yichang', 'China', 'in use']
# ['5924', 'Yongbao Bridge', '1971', 'Baoshan', 'China', 'in use']
# ['5925', 'Yongjiang Bridge', '1996', 'Yongning', 'China', 'in use']
# ['5926', 'Yongning Yellow River Highway Bridge', '2016', 'Ningxia', 'China', 'under construction']
# ['5927', 'Yoshiigawa Bridge', '1971', 'Okayama', 'Japan', 'in use']
# ['5928', 'Yuanze Bridge', '1991', 'Wuhe', 'China', 'in use']
# ['5929', 'Yume Tsuribashi Bridge', '1996', 'Sera', 'Japan', 'in use']
# ['5930', 'Yumekake Bridge', '2010', 'Gojo', 'Japan', 'in use']
# ['5931', 'Yunyang Bridge', '1990', 'Danyang', 'China', 'in use']
# ['5932', 'Yunyang Bridge', '1975', 'Yunyang', 'China', 'completed']
# ['5933', 'Yusufiya Bridge', '1983', 'Yusufiya', 'Iraq', 'in use']
# ['5934', 'Z Bridge', '2017', 'Konstanz (BW)', 'Germany', 'in use']
# ['5935', 'Zabeljo Footbridge', '2006', 'Podgorica', 'Montenegro', 'in use']
# ['5936', 'Zaepfel Bridge', '2007', 'Strasbourg (67)', 'France', 'in use']
# ['5937', 'Zaepfel Bridge', '', 'Strasbourg (67)', 'France', 'demolished']
# ['5938', 'Zahme Gera Viaduct', '2002', 'Ilmenau (TH)', 'Germany', 'in use']
# ['5939', 'Zaligebrug', '2016', 'Nijmegen', 'Netherlands', 'in use']
# ['5940', 'Zanaglia Viaduct', '1977', 'Alessandria (PM)', 'Italy', 'in use']
# ['5941', 'Zarcico Aqueduct', '', 'Totana', 'Spain', 'in use']
# ['5942', 'Zarzuela Junction Footbridge', '1996', 'Madrid', 'Spain', 'in use']
# ['5943', 'Zarzuela Junction Viaducts', '1999', 'Madrid', 'Spain', 'in use']
# ['5944', 'Ždírnické Creek Bridge', '2005', 'Ústí nad Labem', 'Czechia', 'in use']
# ['5945', 'Zealand Bridge', '1965', 'Zierikzee', 'Netherlands', 'in use']
# ['5946', 'Zeceve Drage Viaduct', '', 'Vrbovsko', 'Croatia', 'under construction']
# ['5947', 'Zeeburg Bridge', '1990', 'Amsterdam', 'Netherlands', 'in use']
# ['5948', 'Zeitlofs Viaduct', '1983', 'Zeitlofs (BY)', 'Germany', 'in use']
# ['5949', 'Zeller Brücke', '1995', 'Zell am Main (BY)', 'Germany', 'in use']
# ['5950', 'Zemstsesteenweg Rail Overpass', '2012', 'Zemst', 'Belgium', 'in use']
# ['5951', 'Zengda Bridge', '1981', 'Jinchuan', 'China', 'in use']
# ['5952', 'Zenneckbrücke', '', '- Munich (BY)', 'Germany', 'in use']
# ['5953', 'Zenntalbrücke', '1991', 'Langenzenn (BY)', 'Germany', 'in use']
# ['5954', 'Zeppelinbrücke', '', 'Leipzig (SN)', 'Germany', 'in use']
# ['5955', 'Zeri Viaduct', '1975', 'Zeri (TC)', 'Italy', 'in use']
# ['5956', 'Žeželjev most', '1961', 'Novi Sad', 'Serbia', 'destroyed']
# ['5957', 'Zêzere River Bridge', '1995', '- Pedrógão Grande', 'Portugal', 'in use']
# ['5958', 'Zhangzhou Zhanbei Bridge', '2001', 'Zhangzhou', 'China', 'in use']
# ['5959', 'Zhanjiang Bay Bridge', '2007', 'Zhanjiang', 'China', 'in use']
# ['5960', 'Zhaquhe Bridge', '1977', 'Nanqian', 'China', 'in use']
# ['5961', 'Zhongxian Bridge', '2009', 'Chongqing', 'China', 'in use']
# ['5962', 'Zhongxiao Bridge', '1982', 'Taipei', 'Taiwan', 'in use']
# ['5963', 'Zhuchanghe River Bridge', '2008', 'Guizhou', 'China', 'in use']
# ['5964', 'Ziegeleibach Bridge', '2015', 'Neukirchen (SN)', 'Germany', 'in use']
# ['5965', 'Ziegelhausen Bridge', '1954', 'Heidelberg (BW)', 'Germany', 'in use']
# ['5966', 'Ziepniekkalna Elevated Road Bridge', '2013', 'Riga', 'Latvia', 'in use']
# ['5967', 'Zigeunergraben-Talbrücke', '', 'Oberderdingen (BW)', 'Germany', 'in use']
# ['5968', 'Ziggenbach Bridge', '1924', 'Innerthal (SZ)', 'Switzerland', 'in use']
# ['5969', 'Zijpse Poort Bridge', '', 'Arnhem', 'Netherlands', 'in use']
# ['5970', 'Zilwaukee Bridge', '', 'Zilwaukee (MI)', 'USA', 'in use']
# ['5971', 'Zingone Bridge', '1950', 'Forlì-Cesena (ER)', 'Italy', 'in use']
# ['5972', 'Zinola Viaduct', '1971', 'Savona (LG)', 'Italy', 'in use']
# ['5973', 'Zipfelbach Viaduct', '2006', 'Winnenden (BW)', 'Germany', 'in use']
# ['5974', 'Zmajski most', '1901', 'Ljubljana', 'Slovenia', 'in use']
# ['5975', 'Zonnebeke Overpass', '', 'Zonnebeke', 'Belgium', 'in use']
# ['5976', 'Zoobrücke', '1966', 'Cologne (NRW)', 'Germany', 'in use']
# ['5977', 'Zorrotza Footbridge', '', 'Bilbao', 'Spain', 'in use']
# ['5978', 'Zschauke Viaduct', '2003', 'Dresden (SN)', 'Germany', 'in use']
# ['5979', 'Zschonergrund Viaduct', '2001', 'Dresden (SN)', 'Germany', 'in use']
# ['5980', 'Zschopau Viaduct', '1996', 'Zschopau (SN)', 'Germany', 'in use']
# ['5981', 'Zuari Bridge', '', 'Tiswadi', 'India', 'in use']
# ['5982', 'Żukci Bridge', '', 'Možđenec', 'Croatia', 'in use']
# ['5983', 'Zuoz Bridge', '1901', 'Zuoz (GR)', 'Switzerland', 'in use']
# ['5984', 'Zürcherstrasse Motorway Overpass', '1971', 'Stein (AG)', 'Switzerland', 'in use']
# ['5985', 'Zutendaal Bridge', '', 'Zutendaal', 'Belgium', 'demolished']
# ['5986', 'Zutphen Bridge', '1976', 'Zutphen', 'Netherlands', 'in use']
# ['5987', 'Zutphen Footbridge', '', 'Zutphen', 'Netherlands', 'in use']
# ['5988', 'Zverev Bridge', '1930', 'Moscow', 'Russia', 'in use']
# ['5989', 'Zwaaikom Bridge', '2015', 'Eindhoven', 'Netherlands', 'in use']
# ['5990', 'Zwaantjesbrug', '', 'Wielsbeke', 'Belgium', 'in use']
# ['5991', 'Zwierzyniecki Bridge', '2001', 'Cracow (MA)', 'Poland', 'in use']

# %%
url = 'https://structurae.net/en/structures/bridges/metal-bridges/list'

#service = Service("/usr/bin/chromedriver")
#service = Service("/usr/lib/chromium-browser/chromedriver")

options = Options()
options.add_argument("--headless")
#options.headless = True
options.add_argument("--no-sandbox")
options.add_argument('--disable-dev-shm-usage')

#driver = webdriver.Chrome(service=service, options=options)
driver = webdriver.Chrome(service = Service("/usr/bin/chromedriver"), options = options)

# Load the website
driver.get(url)

# Wait for the table to load (optional)
# You may need to adjust the timeout depending on your internet speed and computer performance
driver.implicitly_wait(10)

# Get number of pages for table
num_pages = int(driver.find_element(By.CLASS_NAME, 'pageLinksPageNav').find_elements(By.TAG_NAME, 'a')[-1].get_attribute("data-page"))
print(num_pages)

# Extract the headers
table = driver.find_element(By.CLASS_NAME, 'mobile-scroll-table')
headers = [header.text.strip() for header in table.find_elements(By.TAG_NAME, 'th')]

print(headers)

rows = []

for i in range(0, num_pages * 100, 100):
    url = 'https://structurae.net/en/structures/bridges/metal-bridges/list?min={}'.format(i)
    #driver = webdriver.Chrome(service = Service("/usr/bin/chromedriver"), options = options)
    driver.get(url)
    driver.implicitly_wait(10)

    # Find the table element
    table = driver.find_element(By.CLASS_NAME, 'mobile-scroll-table')

    # Extract the rows
    for row in table.find_elements(By.TAG_NAME, 'tr'):
        i = 0
        row_data = []
        for cell in row.find_elements(By.TAG_NAME, 'td'):
            if(i == 4):
                img = cell.find_element(By.TAG_NAME, 'img')
                item = img.get_attribute("alt")#.text.strip()
                row_data.append(item)
            else:
                item = cell.text.strip()
                row_data.append(item)
            i += 1
        #cells = [cell.text.strip() for cell in row.find_elements(By.TAG_NAME, 'td')]
        if row_data:
            rows.append(row_data)

    # Close the browser
    #driver.quit()

driver.quit()

# Print the headers and rows
for row in rows:
    print(row)

#Append data to csv
df2 = pd.DataFrame(rows, columns = headers)
df2.to_csv('/usr/bin/bridges.csv', mode='a', index = False, header = False, encoding = 'utf-8-sig')
# Out:
# Streaming output truncated to the last 5000 lines.
# ['2952', 'I-82 Yakima River Bridge', '1960', 'Yakima (WA)', 'USA', 'in use']
# ['2953', 'I-87 Walkill River Bridge', '1954', 'Rosendale (NY)', 'USA', 'in use']
# ['2954', 'I. B. Perrine Bridge', '1927', 'Twin Falls (ID)', 'USA', 'demolished']
# ['2955', 'I. B. Perrine Bridge', '1976', 'Twin Falls (ID)', 'USA', 'in use']
# ['2956', 'IDEO School Footbridge', '2018', 'Madrid', 'Spain', 'in use']
# ['2957', 'Ignacy Moscicki Bridge', '1934', 'Pulawy (LU)', 'Poland', 'in use']
# ['2958', 'Ignatz Bubis Bridge', '1878', 'Frankfurt (HE)', 'Germany', 'in use']
# ['2959', 'Igollo de Camargo Footbridge', '2010', 'Camargo', 'Spain', 'in use']
# ['2960', 'Ihmebrücke Ricklingen', '', 'Hanover (NI)', 'Germany', 'in use']
# ['2961', 'IJmuiden Swing Bridge', '1956', 'Velsen', 'Netherlands', 'in use']
# ['2962', 'Ijsselkanaal Footbridge', '1964', 'Zwolle', 'Netherlands', 'in use']
# ['2963', 'IJsselkanaal Railroad Bridge', '1964', 'Zwolle', 'Netherlands', 'in use']
# ['2964', 'IJzerlaan Rail Bridge', '2003', 'Antwerp', 'Belgium', 'in use']
# ['2965', 'IJzerlaan Rail Bridges', '2013', 'Antwerp', 'Belgium', 'in use']
# ['2966', 'IKEA Bridge', '', 'Dortmund (NRW)', 'Germany', 'in use']
# ['2967', 'Ikitsuki Bridge', '1991', 'Hirado', 'Japan', 'in use']
# ['2968', 'Ikoi Bridge', '1956', 'Sapporo', 'Japan', 'in use']
# ['2969', 'Ikuchi Bridge', '1991', 'Ikuchi', 'Japan', 'in use']
# ['2970', 'Ile Falcon Footbridge', '1998', 'Sierre (VS)', 'Switzerland', 'in use']
# ['2971', 'Ill River Railroad Bridge', '', 'Strasbourg (67)', 'France', 'in use']
# ['2972', 'Iller Footbridge', '2006', 'Immenstadt im Allgäu (BY)', 'Germany', 'in use']
# ['2973', 'Illinois Central Terminal Rail Bridge', '1893', 'Omaha (NE)', 'USA', 'in use']
# ['2974', 'Illon Bridge', '2015', 'Sembrancher (VS)', 'Switzerland', 'in use']
# ['2975', 'Imabeppu River Bridge', '2001', 'Japan', 'Japan', 'in use']
# ['2976', 'Imari Bay Bridge', '2003', 'Imari', 'Japan', 'in use']
# ['2977', 'Imbaba Bridge', '1924', 'Cairo', 'Egypt', 'in use']
# ['2978', 'Imola Footbridge', '', 'Imola (ER)', 'Italy', 'in use']
# ['2979', 'Inami Frog Bridge', '', 'Inami', 'Japan', 'in use']
# ['2980', 'Inari Bridge', '', 'Hiroshima', 'Japan', 'in use']
# ['2981', 'Incheon Bridge', '2009', 'Incheon', 'South Korea', 'in use']
# ['2982', 'Incisa Railway Bridge', '', '- Reggello (TC)', 'Italy', 'in use']
# ['2983', 'Independence Bridge', '1976', 'Bay City (MI)', 'USA', 'in use']
# ['2984', 'India Point Railroad Bridge', '1903', 'Providence (RI)', 'USA', 'demolished']
# ['2985', 'Indian Ocean, Bridge of the', '', 'Lingang', 'China', 'in use']
# ['2986', 'Indian River Inlet Bridge', '1965', 'Bethany Beach (DE)', 'USA', 'in use']
# ['2987', 'Indiana Avenue Bridge', '1915', 'Chicago (IL)', 'USA', 'in use']
# ['2988', 'Industrial Flats Lift Bridge', '1953', 'Cleveland (OH)', 'USA', 'in use']
# ['2989', 'Industriehaven Pipeline Bridge', '', 'Utrecht', 'Netherlands', 'in use']
# ['2990', 'Industriehavenbrug', '1920', 'Utrecht', 'Netherlands', 'in use']
# ['2991', 'Infiernillo ll Bridge', '2003', 'Michoacán de Ocampo (MICH)', 'Mexico', 'in use']
# ['2992', 'Infinity Bridge', '2009', 'Stockton-on-Tees (GB-ENG)', 'United Kingdom', 'in use']
# ['2993', 'Infirmary Bridge', '1882', 'Inverness (GB-SCT)', 'United Kingdom', 'in use']
# ['2994', 'Ingersoll Street Bridge', '1911', 'Albion (NY)', 'USA', 'in use']
# ['2995', 'Ingolstadt Rail Bridge', '1869', 'Ingolstadt (BY)', 'Germany', 'in use']
# ['2996', 'Ingrandes-sur-Loire Bridge', '1922', 'Ingrandes (49)', 'France', 'in use']
# ['2997', 'Ingulsky Bridge', '1980', 'Mykolaiv', 'Ukraine', 'in use']
# ['2998', 'Innbrücke Königswart', '1875', 'Soyen (BY)', 'Germany', 'partially demolished']
# ['2999', 'Innbrücke Königswart', '1994', 'Soyen (BY)', 'Germany', 'in use']
# ['3000', 'Innbrücke Landeck', '1884', 'Landeck (TIR)', 'Austria', 'demolished']
# ['3001', 'Innbrücke Landeck', '1904', 'Landeck (TIR)', 'Austria', 'demolished']
# ['3002', 'Inner Harbour Footbridge', '2016', 'Copenhagen', 'Denmark', 'in use']
# ['3003', 'Innerbelt Bridge', '1959', 'Cleveland (OH)', 'USA', 'demolished']
# ['3004', 'Innerstebrücke', '1925', 'Sarstedt (NI)', 'Germany', 'in use']
# ['3005', 'Innoshima Bridge', '1983', 'Innoshima', 'Japan', 'in use']
# ['3006', 'Innsbrucker Platz Railroad Bridge', '1979', 'Berlin (BE)', 'Germany', 'in use']
# ['3007', 'Innsteg Passau', '1916', 'Passau (BY)', 'Germany', 'in use']
# ['3008', 'Inselbrücke', '2017', 'Riedlingen (BW)', 'Germany', 'in use']
# ['3009', 'Inselbrücke', '2000', 'Potsdam (BB)', 'Germany', 'in use']
# ['3010', 'Institute Street Footbridge', '2002', 'Kyiv', 'Ukraine', 'in use']
# ['3011', 'Interlaken Railroad Bridge', '', 'Interlaken (BE)', 'Switzerland', 'in use']
# ['3012', 'International Railway Bridge', '1873', '- Fort Erie (ON)', 'Canada', 'in use']
# ['3013', 'Interstate 24 Bridge', '1973', 'Paducah (KY)', 'USA', 'in use']
# ['3014', 'Interstate 24 Tennessee River Bridge', '', '- Gilbertsville (KY)', 'USA', 'in use']
# ['3015', 'Interstate Highway Bridge', '1939', 'Clarkston (WA)', 'USA', 'in use']
# ['3016', 'Inunaki Bridge', '1982', 'Miyawaka', 'Japan', 'in use']
# ['3017', 'Inverythan Bridge', '', 'Inverythan (GB-SCT)', 'United Kingdom', 'collapsed']
# ['3018', 'Inwilerstrasse Footbridge', '', 'Baar (ZG)', 'Switzerland', 'in use']
# ['3019', 'Inzigkofen Footbridge', '2019', 'Inzigkofen (BW)', 'Germany', 'in use']
# ['3020', 'Iohjima Bridge', '2011', 'Nagasaki', 'Japan', 'in use']
# ['3021', 'Iowa-Illinois Memorial Bridge', '1959', 'Moline (IL)', 'USA', 'to be demolished']
# ['3022', 'Iowa-Illinois Memorial Bridge', '1934', 'Moline (IL)', 'USA', 'to be demolished']
# ['3023', 'IPRC Demonstration Bridge Footbridge', '2018', 'Kigali', 'Rwanda', 'in use']
# ['3024', 'Iregua River Footbridge', '', 'Logroño', 'Spain', 'in use']
# ['3025', 'Iregua River Rail Bridge', '', 'Logroño', 'Spain', 'in use']
# ['3026', 'Irene Hixon Whitney Bridge', '1988', 'Minneapolis (MN)', 'USA', 'in use']
# ['3027', 'Iron Bridge', '', 'Chiang Mai', 'Thailand', 'in use']
# ['3028', 'Iron Bridge', '1779', 'Ironbridge (GB-ENG)', 'United Kingdom', 'in use']
# ['3029', 'Iron Bridge', '1844', 'Hanover (NI)', 'Germany', 'in use']
# ['3030', 'Iron Bridge', '1942', 'Perugia (UM)', 'Italy', 'in use']
# ['3031', 'Iron Bridge (Cragside House)', '1875', 'Rothbury (GB-ENG)', 'United Kingdom', 'in use']
# ['3032', 'Iron Cove Bridge', '1955', 'Drummoyne (NSW)', 'Australia', 'in use']
# ['3033', 'Iron Suspension Bridge', '', 'Zelzate', 'Belgium', 'out of service']
# ['3034', 'Ironbridge "A" Road Bridge', '1932', 'Coalbrookdale (GB-ENG)', 'United Kingdom', 'disused']
# ['3035', 'Ironton-Russell Bridge', '1922', '- Russell (KY)', 'USA', 'demolished']
# ['3036', 'Ironworkers Memorial Second Narrows Crossing', '1960', 'Vancouver (BC)', 'Canada', 'in use']
# ['3037', 'Irrawaddy Bridge', '2008', 'Mandalay', 'Myanmar', 'in use']
# ['3038', 'Irún Footbridge', '', 'Irún', 'Spain', 'in use']
# ['3039', 'Irvin S. Cobb Bridge', '1929', 'Paducah (KY)', 'USA', 'in use']
# ['3040', 'Isabellalaan Bascule Bridge', '', 'Zeebrugge', 'Belgium', 'in use']
# ['3041', 'Isaiah David Hart Bridge', '1967', 'Jacksonville (FL)', 'USA', 'in use']
# ['3042', 'Isar Bridge', '1857', 'Pullach im Isartal (BY)', 'Germany', 'demolished']
# ['3043', 'Isenlaufbrücke', '2003', 'Bremgarten (AG)', 'Switzerland', 'in use']
# ['3044', 'Iseo Station Footbridge', '', 'Iseo (LM)', 'Italy', 'in use']
# ['3045', 'Ishikari Bridge', '1972', 'Ishikari', 'Japan', 'in use']
# ['3046', 'Ishiyama Bridge', '1979', 'Sapporo', 'Japan', 'in use']
# ['3047', 'Ishiyama Great Bridge', '1977', 'Sapporo', 'Japan', 'in use']
# ['3048', 'Isleton Bridge', '1923', 'Isleton (CA)', 'USA', 'in use']
# ['3049', 'Islington Place Footbridge', '', 'Birmingham (GB-ENG)', 'United Kingdom', 'in use']
# ['3050', 'Isoisänsilta', '2016', 'Helsinki', 'Finland', 'in use']
# ['3051', 'Isorno Rail Viaduct', '1923', '- Cavigliano (TI)', 'Switzerland', 'in use']
# ['3052', 'Isozaki Atea Bridge', '', 'Bilbao', 'Spain', 'in use']
# ['3053', 'Israel LaFleur Bridge', '1962', 'Lake Charles (LA)', 'USA', 'in use']
# ['3054', 'Isthmia Bridge', '', 'Isthmia', 'Greece', 'in use']
# ['3055', 'István Türr Bridge', '1950', 'Baja', 'Hungary', 'in use']
# ['3056', 'Italia 61 Footbridge', '1961', 'Turin (PM)', 'Italy', 'in use']
# ['3057', 'Italian Bridge', '1955', 'Saint Petersburg', 'Russia', 'in use']
# ['3058', 'Italian Bridge', '2020', 'Chur (GR)', 'Switzerland', 'in use']
# ['3059', 'Itford Farm Bridle Bridge', '2007', 'East Sussex (GB-ENG)', 'United Kingdom', 'in use']
# ['3060', 'Itzehoe Railroad Bridge', '', 'Itzehoe (SH)', 'Germany', 'in use']
# ['3061', 'Itztalbrücke', '2005', 'Rödental (BY)', 'Germany', 'in use']
# ['3062', 'IUT Footbridge', '', 'Chalon-sur-Saône (71)', 'France', 'in use']
# ['3063', 'Ivry Bridge', '1957', 'Ivry-sur-Seine (94)', 'France', 'in use']
# ['3064', 'Iwakurojima Bridge', '1988', 'Kojima', 'Japan', 'in use']
# ['3065', 'Izbor Bridge', '', 'El Pinar', 'Spain', 'in use']
# ['3066', 'Izumiotsu Bridge', '1976', 'Izumiotsu', 'Japan', 'in use']
# ['3067', 'J.C. Van Horne Bridge', '1961', 'Campbellton (NB)', 'Canada', 'in use']
# ['3068', 'Jaagpad Footbridge', '2010', 'Rotselaar', 'Belgium', 'in use']
# ['3069', 'Jablunkov I/11 Road Bridge', '2008', 'Jablunkov', 'Czechia', 'in use']
# ['3070', 'Jack S. Kenyon Memorial Footbridge', '2009', 'Honduras', 'Honduras', 'in use']
# ['3071', 'Jackson Boulevard Bridge', '1916', 'Chicago (IL)', 'USA', 'in use']
# ['3072', 'Jackson Park Lagoon Bridge', '1891', 'Chicago (IL)', 'USA', 'in use']
# ['3073', 'Jackson Street Bridge', '1903', '- Harrison (NJ)', 'USA', 'in use']
# ['3074', 'Jackson Street Bridge', '1932', 'Joliet (IL)', 'USA', 'in use']
# ['3075', 'Jacobs Ladder Bridge', '2012', 'Auckland', 'New Zealand', 'in use']
# ['3076', 'Jacques Cartier Bridge', '1930', 'Montreal (QC)', 'Canada', 'in use']
# ['3077', 'Jacques Chaban-Delmas Bridge', '2013', 'Bordeaux (33)', 'France', 'in use']
# ['3078', 'Jägerstiegbrücke', '2018', 'Stadtroda (TH)', 'Germany', 'in use']
# ['3079', 'James Joyce Bridge', '2003', 'Dublin', 'Ireland', 'in use']
# ['3080', 'James River Bridge', '1983', 'Newport News (VA)', 'USA', 'in use']
# ['3081', 'James Thomson Bridge', '2005', 'Hawick (GB-SCT)', 'United Kingdom', 'in use']
# ['3082', 'Jamestown Bridge', '1940', 'Jamestown (RI)', 'USA', 'demolished']
# ['3083', 'Jan Schaefer Bridge', '2001', 'Amsterdam', 'Netherlands', 'in use']
# ['3084', 'Jane Coston Bridge', '2004', 'Cambridge (GB-ENG)', 'United Kingdom', 'in use']
# ['3085', 'Jangsa Bridge', '1993', 'Jangsa', 'Bhutan', 'in use']
# ['3086', 'Janice Peaslee Bridge', '1893', 'Stratford (NH)', 'USA', 'in use']
# ['3087', 'Jann Berghaus Bridge', '1950', 'Leer (Ostfriesland) (NI)', 'Germany', 'demolished']
# ['3088', 'Jann Berghaus Bridge', '1991', 'Leer (Ostfriesland) (NI)', 'Germany', 'in use']
# ['3089', 'Jannowitz Bridge', '1954', 'Berlin (BE)', 'Germany', 'in use']
# ['3090', 'Japan Bridge', '1993', 'Paris-La Défense (92)', 'France', 'in use']
# ['3091', 'Jardin Rancho Footbridge', '2012', 'Punata', 'Bolivia', 'in use']
# ['3092', 'Jarmen Bridge', '1967', 'Jarmen (MV)', 'Germany', 'demolished']
# ['3093', 'Jastorf Canal Bridge', '', 'Bad Bevensen (NI)', 'Germany', 'in use']
# ['3094', 'Jaulgonne Bridge', '1948', 'Jaulgonne (2)', 'France', 'in use']
# ['3095', 'Javadieh Bridge', '2010', 'Tehran', 'Iran', 'in use']
# ['3096', 'Jaworzno Footbridge', '', 'Jaworzno (SL)', 'Poland', 'project']
# ['3097', 'Jægersborg Station Footbridge', '2013', 'Gentofte', 'Denmark', 'in use']
# ['3098', 'Jean Ferrat Footbridge', '', '- Trélissac (24)', 'France', 'in use']
# ['3099', 'Jean Jaurès Bridge', '1964', 'Elbeuf (76)', 'France', 'in use']
# ['3100', 'Jefferson Barracks Bridge', '1983', '- Columbia (IL)', 'USA', 'in use']
# ['3101', 'Jefferson Barracks Bridge', '1992', '', 'USA', 'in use']
# ['3102', 'Jefferson City Bridge', '1955', 'Jefferson City (MO)', 'USA', 'in use']
# ['3103', 'Jemseg River Bridge', '2001', 'Jemseg (NB)', 'Canada', 'in use']
# ['3104', 'Jemseg River Bridge', '1960', 'Jemseg (NB)', 'Canada', 'in use']
# ['3105', 'Jendouba Bridge', '1927', 'Jendouba', 'Tunisia', 'out of service']
# ['3106', 'Jennings Randolph Bridge', '1977', '- Chester (WV)', 'USA', 'in use']
# ['3107', 'Jermuk Bridge', '1972', 'Jermuk', 'Armenia', 'in use']
# ['3108', 'Jerusalem Bridge', '2011', 'Oslo', 'Norway', 'in use']
# ['3109', 'Jerusalem Bridge', '1996', 'Magdeburg (ST)', 'Germany', 'in use']
# ['3110', 'Jerusalembrücke (Südbrücke)', '1952', 'Magdeburg (ST)', 'Germany', 'in use']
# ['3111', 'Jesolo Footbridge', '', 'Jesolo (VN)', 'Italy', 'in use']
# ['3112', 'Jesus Lock Footbridge', '1892', 'Cambridge (GB-ENG)', 'United Kingdom', 'in use']
# ['3113', 'Jiajiang Bridge', '2009', 'Nanjing', 'China', 'in use']
# ['3114', 'Jiak Kim Bridge', '', 'Singapore', 'Singapore', 'in use']
# ['3115', "Jiande Bridge over Xin'anjiang", '', 'Jiande', 'China', 'in use']
# ['3116', 'Jiangdong Bridge', '2008', 'Hangzhou', 'China', 'in use']
# ['3117', 'Jianghan Bridge', '1988', 'Wuhan', 'China', 'in use']
# ['3118', 'Jiangmen Donghua Bridge', '', 'Jiangmen', 'China', 'in use']
# ['3119', 'Jiangyin Yangtze River Bridge', '1997', 'Jiangyin', 'China', 'in use']
# ['3120', 'Jiaxian Bridge', '2010', 'Kaohsiung', 'Taiwan', 'in use']
# ['3121', 'Jicaro Footbridge', '2013', 'Esquipulas', 'Nicaragua', 'in use']
# ['3122', 'Jiefang Bridge', '1996', 'Fuzhou', 'China', 'in use']
# ['3123', 'Jiefang Bridge', '1927', 'Tianjin', 'China', 'in use']
# ['3124', 'Jifen Bridge', '', 'Taiyuan', 'China', 'in use']
# ['3125', 'Jim Stynes Bridge', '2014', 'Melbourne (VIC)', 'Australia', 'in use']
# ['3126', "Jin'an Bridge", '2020', 'Lijiang', 'China', 'in use']
# ['3127', 'Jinan High-Speed Rail Yellow River Bridge', '2017', 'Jinan', 'China', 'in use']
# ['3128', 'Jìnbù Bridge', '2008', 'Tianjin', 'China', 'in use']
# ['3129', 'Jindo Bridge', '1984', 'Jindo', 'South Korea', 'in use']
# ['3130', 'Jindo Bridge', '2004', 'Jindo', 'South Korea', 'in use']
# ['3131', 'Jinfu Bridge', '2007', 'Tianjin', 'China', 'in use']
# ['3132', 'Jingang Bridge', '1996', 'Tianjin', 'China', 'in use']
# ['3133', 'Jingmei Bridge', '2010', 'Taipei', 'Taiwan', 'in use']
# ['3134', 'Jingshan Suspension Bridge', '', 'Taipei', 'Taiwan', 'in use']
# ['3135', 'Jinja Bridge', '1926', '- Njeru', 'Uganda', 'in use']
# ['3136', 'Jinshajiang Jindong Bridge', '2018', 'Sichuan', 'China', 'in use']
# ['3137', 'Jintang Bridge', '1991', 'Tianjin', 'China', 'in use']
# ['3138', 'Jip Golsteijnbrug', '2013', 'Amsterdam', 'Netherlands', 'in use']
# ['3139', 'Jiujiang Yangtze River Bridge', '1992', 'Jiujiang', 'China', 'in use']
# ['3140', 'Joachim Tiburtius Bridge', '1993', 'Berlin (BE)', 'Germany', 'in use']
# ['3141', 'Joan Camps Footbridge', '2007', 'Granollers', 'Spain', 'in use']
# ['3142', 'Jocote Arriba Footbridge', '2015', 'Condega', 'Nicaragua', 'in use']
# ['3143', 'Jōgakura Bridge', '1995', 'Aomori', 'Japan', 'in use']
# ['3144', 'Johann Wild Street Footbridge', '', 'Nuremberg (BY)', 'Germany', 'in use']
# ['3145', 'John A. Blatnik Bridge', '1961', 'Duluth (MN)', 'USA', 'in use']
# ['3146', 'John A. Roebling Suspension Bridge', '1867', 'Cincinnati (OH)', 'USA', 'in use']
# ['3147', 'John Coffee Memorial Bridge', '', 'Colbert County (AL)', 'USA', 'in use']
# ['3148', 'John Day River Bridge', '1975', 'Wasco County (OR)', 'USA', 'in use']
# ['3149', 'John E. Cox Memorial Bridge', '', 'Lowell (MA)', 'USA', 'in use']
# ['3150', 'John E. Mathews Bridge', '1953', 'Jacksonville (FL)', 'USA', 'in use']
# ['3151', 'John F. Kennedy Boulevard Bridge', '1959', 'Philadelphia (PA)', 'USA', 'in use']
# ['3152', 'John F. Kennedy Memorial Bridge', '1963', 'Louisville (KY)', 'USA', 'in use']
# ['3153', 'John Frostbrug', '1935', 'Arnhem', 'Netherlands', 'in use']
# ['3154', 'John Greenleaf Whittier Bridge', '1951', '- Amesbury (MA)', 'USA', 'demolished']
# ['3155', 'John McLoughlin Memorial Bridge', '1933', 'Oregon City (OR)', 'USA', 'in use']
# ['3156', 'John P. Grace Memorial Bridge', '1929', 'Charleston (SC)', 'USA', 'demolished']
# ['3157', 'John Philip Sousa Bridge', '1940', 'Washington', 'USA', 'in use']
# ['3158', 'John S. Thompson Bridge', '1929', 'Grave', 'Netherlands', 'in use']
# ['3159', 'John Seigenthaler Pedestrian Bridge', '1909', 'Nashville (TN)', 'USA', 'in use']
# ['3160', 'John T. Alsop Bridge', '1941', 'Jacksonville (FL)', 'USA', 'in use']
# ['3161', 'John T. Cunningham Memorial Bridge', '1925', 'Clarksville (TN)', 'USA', 'demolished']
# ['3162', 'John T. Meyers Pedestrian Bridge', '', '- West Lafayette (IN)', 'USA', 'in use']
# ['3163', 'Johnson Street Bridge', '1924', 'Victoria (BC)', 'Canada', 'demolished']
# ['3164', 'Johnson Street Bridge', '2018', 'Victoria (BC)', 'Canada', 'in use']
# ['3165', 'Jökulsárlón Bridge', '', 'Höfn', 'Iceland', 'in use']
# ['3166', 'Joliet Railroad Lift Bridge', '', 'Joliet (IL)', 'USA', 'out of service']
# ['3167', 'Jonathon Hulton Bridge', '1908', 'Harmar (PA)', 'USA', 'in use']
# ['3168', 'Jonchères Bridge', '', 'Rauret (43)', 'France', 'in use']
# ['3169', 'Jonckheerebrug', '2017', 'Bruges', 'Belgium', 'in use']
# ['3170', 'Jones Bridge', '1945', 'Manila', 'Philippines', 'in use']
# ['3171', 'Jonquières Swing Bridge', '1962', 'Martigues (13)', 'France', 'demolished']
# ['3172', 'Jorge Manrique Footbridge', '1998', 'Murcia', 'Spain', 'in use']
# ['3173', 'Jorge-Biurdana Footbridge', '2009', 'Pamplona', 'Spain', 'in use']
# ['3174', 'Jorogeta Footbridge', '2004', 'Ethiopia', 'Ethiopia', 'in use']
# ['3175', 'Jorquenay Swing Bridge', '', 'Humes-Jorquenay (52)', 'France', 'demolished']
# ['3176', 'José León de Carranza Bridge', '1969', 'Cádiz', 'Spain', 'in use']
# ['3177', 'Jose P. Rizal Bridge', '1911', 'Seattle (WA)', 'USA', 'in use']
# ['3178', 'Joseph Le Brix Bridge', '1969', 'Bono (56)', 'France', 'in use']
# ['3179', 'Joso High Bridge', '1912', '- Franklin County (WA)', 'USA', 'in use']
# ['3180', 'Joto Bridge', '', 'Kofu', 'Japan', 'in use']
# ['3181', 'Józef Piłsudski Bridge', '1933', 'Cracow (MA)', 'Poland', 'in use']
# ['3182', 'Józef Piłsudski Bridge', '1934', 'Torun (KP)', 'Poland', 'in use']
# ['3183', 'Juan Pablo Duarte Bridge', '1955', 'Santo Domingo', 'Dominican Republic', 'in use']
# ['3184', 'Jubilee Bridge', '2006', 'Yaroslavl', 'Russia', 'in use']
# ['3185', 'Jubilee Bridge (India)', '1886', '- Bandel', 'India', 'in use']
# ['3186', 'Júcar River Bridge', '1998', 'Alzira', 'Spain', 'in use']
# ['3187', 'Jucuapa Occidental Footbridge', '2012', 'Matagalpa', 'Nicaragua', 'in use']
# ['3188', 'Judge William Seeber Bridge', '1957', 'New Orleans (LA)', 'USA', 'in use']
# ['3189', 'Judsonia Bridge', '1924', 'Judsonia (AR)', 'USA', 'in use']
# ['3190', 'Julia Butler Hansen Bridge', '1939', 'Cathlamet (WA)', 'USA', 'in use']
# ['3191', 'Julianabrug', '1970', 'Vianen', 'Netherlands', 'in use']
# ['3192', 'Julianakanaal Bridge', '1965', 'Echt-Susteren', 'Netherlands', 'in use']
# ['3193', 'Jülicher Straße Bridge', '1963', 'Düsseldorf (NRW)', 'Germany', 'in use']
# ['3194', 'Julien Dubuque Bridge', '1943', 'Dubuque (IA)', 'USA', 'in use']
# ['3195', 'Juliusturmbrücke', '', 'Berlin (BE)', 'Germany', 'in use']
# ['3196', 'Julsrud E-6 Motorway Bridge', '', 'Minnesund', 'Norway', 'in use']
# ['3197', 'Juneau-Douglas Bridge', '1935', 'Juneau (AK)', 'USA', 'demolished']
# ['3198', 'Jungbuschbrücke', '1957', 'Mannheim (BW)', 'Germany', 'in use']
# ['3199', 'Jungbuschbrücke', '1908', 'Mannheim (BW)', 'Germany', 'destroyed']
# ['3200', 'Jungfernbrücke', '', 'Hamburg (HH)', 'Germany', 'in use']
# ['3201', 'Jungfernheide Rail Bridge', '', '', 'Germany', 'in use']
# ['3202', 'Junicho Lagune Footbridge', '', 'Himi', 'Japan', 'in use']
# ['3203', 'Jurançon Pipeline Bridge', '', '- Jurançon (64)', 'France', 'in use']
# ['3204', 'Jurug Bridge', '1977', 'Surakarta', 'Indonesia', 'in use']
# ['3205', 'Juscelino Kubitschek Bridge', '2002', 'Brasilia', 'Brazil', 'in use']
# ['3206', 'Justice Harlan Fiske Stone Bridge', '1937', 'Brattleboro (VT)', 'USA', 'out of service']
# ['3207', 'Jutphaasebrug', '1936', 'Utrecht', 'Netherlands', 'in use']
# ['3208', 'K 3n Road Bridge of the Lichtenbroich Bypass', '2002', 'Düsseldorf (NRW)', 'Germany', 'in use']
# ['3209', "Kaayman's River Bridge", '', 'Western Cape', 'South Africa', 'in use']
# ['3210', 'Kabashima Bridge', '1986', 'Nagasaki', 'Japan', 'in use']
# ['3211', 'Kabere Footbridge', '2019', 'Nyaruguru', 'Rwanda', 'in use']
# ['3212', 'Kabutimbo Footbridge', '2021', 'Gakenke', 'Rwanda', 'in use']
# ['3213', 'Kachidoki Bridge', '1940', 'Tokyo', 'Japan', 'in use']
# ['3214', 'Kadoelen Bridge', '2012', 'Amsterdam', 'Netherlands', 'in use']
# ['3215', 'Kafue Road Bridge', '1993', 'Kafue', 'Zambia', 'in use']
# ['3216', 'Kagami Bridge', '', 'Kami', 'Japan', 'in use']
# ['3217', 'Kagamigawa Pipeline Bridge', '1979', 'Kochi', 'Japan', 'in use']
# ['3218', 'Kagarama Footbridge', '2018', 'Nyamasheke', 'Rwanda', 'in use']
# ['3219', 'Kagarama Footbridge', '2022', 'Karongi', 'Rwanda', 'in use']
# ['3220', 'Kagogo Footbridge', '2020', 'Rutsiro', 'Rwanda', 'in use']
# ['3221', 'Kaibab Trail Suspension Bridge', '1928', 'Grand Canyon Village (AZ)', 'USA', 'in use']
# ['3222', 'Kaiser Springs Bridge', '1951', 'Wikieup (AZ)', 'USA', 'in use']
# ['3223', 'Kaiser Wilhelm Bridge', '1907', 'Wilhelmshaven (NI)', 'Germany', 'in use']
# ['3224', 'Kaiserin-Elisabeth-Brücke', '1861', 'Passau (BY)', 'Germany', 'destroyed']
# ['3225', 'Kaiserin-Elisabeth-Brücke', '1938', 'Passau (BY)', 'Germany', 'in use']
# ['3226', 'Kaiserin-Elisabeth-Brücke', '', 'Passau (BY)', 'Germany', 'in use']
# ['3227', 'Kaiserlei Bridge', '1964', 'Frankfurt (HE)', 'Germany', 'in use']
# ['3228', 'Kaisermühlenbrücke', '1993', 'Vienna', 'Austria', 'in use']
# ['3229', 'Kaisersteg', '1898', 'Berlin (BE)', 'Germany', 'destroyed']
# ['3230', 'Kaisersteg', '2007', '', 'Germany', 'in use']
# ['3231', 'Kaiserstuhl Bridge', '', 'Kaiserstuhl (AG)', 'Switzerland', 'in use']
# ['3232', 'Kaita Bridge', '1990', 'Hiroshima', 'Japan', 'in use']
# ['3233', 'Kaitainen Bridge', '1982', 'Taivassalo', 'Finland', 'in use']
# ['3234', 'Kaizu Bridge', '', 'Toyama', 'Japan', 'in use']
# ['3235', 'Kalaritikos Bridge', '', 'Kalarites', 'Greece', 'in use']
# ['3236', 'Kalikuto Bridge', '2018', 'Sambongsari', 'Indonesia', 'in use']
# ['3237', 'Kalkenvaart Bridge', '', 'Laarne', 'Belgium', 'in use']
# ['3238', 'Kallithea Aqueduct', '', 'Kallithea', 'Greece', 'in use']
# ['3239', 'Kalmius River Bridge', '', 'Donetsk', 'Ukraine', 'in use']
# ['3240', 'Kalpaka Bridge', '1906', 'Liepaja', 'Latvia', 'in use']
# ['3241', 'Kama Footbridge', '2017', 'Mbale', 'Uganda', 'in use']
# ['3242', 'Kama River Bridge', '', 'Perm', 'Russia', 'in use']
# ['3243', 'Kamagari Bridge', '1979', 'Hiroshima', 'Japan', 'in use']
# ['3244', 'Kamajanga Footbridge', '2013', 'Nyabihu', 'Rwanda', 'in use']
# ['3245', 'Kamasiga Kibrira Footbridge', '2012', 'Ngororero', 'Rwanda', 'in use']
# ['3246', 'Kamatsira Footbridge', '2022', 'Nyamasheke', 'Rwanda', 'in use']
# ['3247', 'Kami Shiroishi Bridge', '1971', 'Sapporo', 'Japan', 'in use']
# ['3248', 'Kamiro Footbridge', '2022', 'Nyabihu', 'Rwanda', 'in use']
# ['3249', 'Kamisho Bridge', '1974', 'Kamisho', 'Japan', 'in use']
# ['3250', 'Kamloops Pedestrian Bridge', '', 'Kamloops (BC)', 'Canada', 'in use']
# ['3251', 'Kamome Bridge', '1975', 'Osaka', 'Japan', 'in use']
# ['3252', 'Kamoro Bridge', '1930', 'Boeny', 'Madagascar', 'in use']
# ['3253', 'Kampmanstrasse Footbridge', '2007', 'Karlsruhe (BW)', 'Germany', 'in use']
# ['3254', 'Kamro Khola Footbridge', '2002', 'Nepal', 'Nepal', 'in use']
# ['3255', 'Kanai Footbridge', '', 'Machida', 'Japan', 'in use']
# ['3256', 'Kanalbrücke Breite Straße', '', 'Eberswalde (BB)', 'Germany', 'in use']
# ['3257', 'Kanalbrücke Britzer Straße', '', 'Eberswalde (BB)', 'Germany', 'in use']
# ['3258', 'Kanavinsky Bridge', '1933', 'Nizhny Novgorod', 'Russia', 'in use']
# ['3259', 'Kanjin Bridge', '2002', 'Taoyuan', 'Taiwan', 'in use']
# ['3260', 'Kanjo Kita Bridge', '1977', 'Sapporo', 'Japan', 'in use']
# ['3261', 'Kanmon Bridge', '1973', 'Kitakyushu', 'Japan', 'in use']
# ['3262', 'Kanne Suspension Bridge', '2005', 'Kanne', 'Belgium', 'in use']
# ['3263', 'Kannengießerbrücke', '', 'Hamburg (HH)', 'Germany', 'in use']
# ['3264', 'Kannengießerortbrücke', '', 'Hamburg (HH)', 'Germany', 'in use']
# ['3265', 'Kanserege Footbridge', '2021', 'Nyamagabe', 'Rwanda', 'in use']
# ['3266', 'Kantemirovsky most', '1982', 'Saint Petersburg', 'Russia', 'in use']
# ['3267', 'Kantstraße Railroad Overpass', '', 'Berlin (BE)', 'Germany', 'in use']
# ['3268', 'Kanyarira Footbridge', '2016', 'Muhanga', 'Rwanda', 'in use']
# ['3269', 'Kao-Ping Hsi Bridge', '1999', 'Kaohsiung', 'Taiwan', 'in use']
# ['3270', 'Kapeenniemi Bridge', '', 'Äänekoski', 'Finland', 'in use']
# ['3271', 'Kapfbrücke', '1995', 'Feldkirch (VBG)', 'Austria', 'in use']
# ['3272', 'Kapkwomboloi Footbridge', '2019', 'Kapchorwa', 'Uganda', 'in use']
# ['3273', 'Karama Footbridge', '2021', 'Muhanga', 'Rwanda', 'in use']
# ['3274', 'Karambi Footbridge', '2019', 'Huye', 'Rwanda', 'in use']
# ['3275', 'Karangarua River Bridge', '1939', 'West Coast', 'New Zealand', 'in use']
# ['3276', 'Karehe Footbridge', '2018', 'Ngororero', 'Rwanda', 'in use']
# ['3277', 'Kariki Bridge', '1980', 'Sapporo', 'Japan', 'in use']
# ['3278', 'Karl-Branner-Brücke', '2000', 'Kassel (HE)', 'Germany', 'in use']
# ['3279', 'Karl-Broel-Strasse Rail Overpass', '', 'Bad Honnef (NRW)', 'Germany', 'in use']
# ['3280', 'Karlsruhe Friendship Bridge', '2015', 'Nottingham (GB-ENG)', 'United Kingdom', 'in use']
# ['3281', 'Karlštejn Bridge', '', 'Karlštejn', 'Czechia', 'in use']
# ['3282', 'Karmsund Bridge', '1955', 'Haugesund', 'Norway', 'in use']
# ['3283', 'Karnali River Bridge', '1993', 'Chisapani Camp', 'Nepal', 'in use']
# ['3284', 'Karnin Bridge', '1933', 'Karnin (MV)', 'Germany', 'destroyed']
# ['3285', 'Karolin Pipeline Bridge', '', 'Poznań (WP)', 'Poland', 'in use']
# ['3286', 'Karolinenbrücke', '1939', 'Salzburg (SBG)', 'Austria', 'in use']
# ['3287', 'Karowa Bridge', '2024', 'Warsaw (MZ)', 'Poland', 'project phase']
# ['3288', 'Karstadt Footbridge', '2002', 'Dortmund (NRW)', 'Germany', 'in use']
# ['3289', 'Karviná I/59 Road Bridge', '2011', 'Karviná', 'Czechia', 'in use']
# ['3290', 'Kasai Bridge', '1963', '- Tokyo', 'Japan', 'in use']
# ['3291', 'Kasai Nagisa Bridge', '1992', 'Tokyo', 'Japan', 'in use']
# ['3292', 'Kashii Line Bridge over Route 495', '', 'Fukuoka', 'Japan', 'in use']
# ['3293', 'Katashinagawa Bridge', '1985', 'Gunma', 'Japan', 'in use']
# ['3294', 'Katehaki Bridge', '2004', 'Athens', 'Greece', 'in use']
# ['3295', 'Katelijnepoortbrug', '', 'Bruges', 'Belgium', 'in use']
# ['3296', 'Katharinenbrücke', '2002', 'Grossenhain (SN)', 'Germany', 'in use']
# ['3297', 'Kathmandu Suspension Bridge', '', 'Kathmandu', 'Nepal', 'in use']
# ['3298', 'Kativik Government Bridge', '', 'Quebec (QC)', 'Canada', 'in use']
# ['3299', 'Katowice Rail Overpass', '', 'Katowice (SL)', 'Poland', 'in use']
# ['3300', 'Katowice-Murckowska Junction A4 Overpasses', '2009', 'Katowice (SL)', 'Poland', 'in use']
# ['3301', 'Katsuse Bridge', '2006', 'Sagamihara', 'Japan', 'in use']
# ['3302', 'Katsushika Harp Bridge', '1986', 'Tokyo', 'Japan', 'in use']
# ['3303', 'Kattendijk Bridge', '2011', 'Antwerp', 'Belgium', 'in use']
# ['3304', 'Kattwyk Bridge', '2020', '- Hamburg (HH)', 'Germany', 'in use']
# ['3305', 'Kattwyk Bridge', '1973', '- Hamburg (HH)', 'Germany', 'in use']
# ['3306', 'Katzengrabensteg', '2001', 'Berlin (BE)', 'Germany', 'in use']
# ['3307', 'Kaubach Bridge', '1886', 'Gonten (AI)', 'Switzerland', 'demolished']
# ['3308', 'Kavumbu Footbridge', '2022', 'Nyabihu', 'Rwanda', 'in use']
# ['3309', 'Kawabata Footbridge', '', 'Kashiwara', 'Japan', 'in use']
# ['3310', 'Kawarau Gorge Suspension Bridge', '1880', 'Kawarau Gorge', 'New Zealand', 'in use']
# ['3311', 'Kawasaki Footbridge', '1978', 'Osaka', 'Japan', 'in use']
# ['3312', 'Kawazu Bridge', '1991', 'Yoshino', 'Japan', 'in use']
# ['3313', 'Kawuswo Footbridge', '2019', 'Bukwa', 'Uganda', 'in use']
# ['3314', 'Kayarani Footbridge', '2018', 'Chapare', 'Bolivia', 'in use']
# ['3315', 'Kazabe Footbridge', '2018', 'Rubavu', 'Rwanda', 'in use']
# ['3316', 'Kazimierz-Ludwinów Footbridge', '2019', 'Cracow (MA)', 'Poland', 'project phase']
# ['3317', 'Kazo Footbridge', '2019', 'Rutsiro', 'Rwanda', 'in use']
# ['3318', 'Kazuń Nowy Bridge', '1952', 'Nowy Kazun (MZ)', 'Poland', 'in use']
# ['3319', 'Kedarnath Bridge', '1975', 'Farakka Barrage Township', 'India', 'in use']
# ['3320', 'Keddie Wye Trestle', '1912', 'Plumas County (CA)', 'USA', 'in use']
# ['3321', 'Kehrwiederspitzbrücke', '', 'Hamburg (HH)', 'Germany', 'in use']
# ['3322', 'Kehrwiedersteg', '', 'Hamburg (HH)', 'Germany', 'in use']
# ['3323', 'Keihin Bridge', '1971', 'Japan', 'Japan', 'in use']
# ['3324', 'Keitel Road Bridge', '1912', 'Orleans County (NY)', 'USA', 'in use']
# ['3325', 'Keleta Footbridge', '2006', 'Ethiopia', 'Ethiopia', 'in use']
# ['3326', 'Kelpen Railroad Bridge', '1922', 'Kelpen', 'Netherlands', 'in use']
# ['3327', 'Kenanaiqin Bridge', '', 'Taichung', 'Taiwan', 'in use']
# ['3328', 'Kendal Bridge', '2012', 'Stann Creek', 'Belize', 'in use']
# ['3329', 'Kendeda Canopy Walk', '2010', 'Atlanta (GA)', 'USA', 'in use']
# ['3330', 'Kenilworth Avenue Bridge', '1936', 'Glendale (CA)', 'USA', 'in use']
# ['3331', 'Kenmon Bridge', '1991', 'Kurobe', 'Japan', 'in use']
# ['3332', 'Kennedy Bridge', '1949', 'Bonn (NRW)', 'Germany', 'in use']
# ['3333', 'Kennedy Bridge', '', 'Grand Forks (ND)', 'USA', 'in use']
# ['3334', 'Kennedy Bridge', '1899', 'Bundaberg (QLD)', 'Australia', 'in use']
# ['3335', 'Kennedy Bridge and Geeste Barrier', '1961', 'Bremerhaven (HB)', 'Germany', 'in use']
# ['3336', 'Kenneth F. Burns Memorial Bridge', '2015', 'Worcester (MA)', 'USA', 'in use']
# ['3337', 'Kennington Railway Bridge', '1923', 'Kennington (GB-ENG)', 'United Kingdom', 'in use']
# ['3338', 'Kénogami Bridge', '1972', 'Saguenay (QC)', 'Canada', 'in use']
# ['3339', 'Kentucky & Indiana Terminal Railroad Bridge', '1912', 'Louisville (KY)', 'USA', 'in use']
# ['3340', 'Kentucky River Suspension Bridge', '1810', 'Frankfort (KY)', 'USA', 'demolished']
# ['3341', 'Kepler Bridge', '1881', 'Graz (STM)', 'Austria', 'demolished']
# ['3342', 'Kepler Bridge', '1963', 'Graz (STM)', 'Austria', 'in use']
# ['3343', 'Keppel Bay Bridge', '', 'Singapore', 'Singapore', 'in use']
# ['3344', 'Keranyo Footbridge', '2003', 'Ethiopia', 'Ethiopia', 'in use']
# ['3345', 'Kern Bridge', '1873', 'Mankato (MN)', 'USA', 'out of service']
# ['3346', 'Kern River Bridge', '1996', 'Bakersfield (CA)', 'USA', 'in use']
# ['3347', 'Kerstelenbach Viaduct', '1882', 'Silenen (UR)', 'Switzerland', 'partially demolished']
# ['3348', 'Keselstrasse Dam Footbridge', '', 'Kempten (Allgäu) (BY)', 'Germany', 'in use']
# ['3349', 'Kessock Bridge', '1982', 'Inverness (GB-SCT)', 'United Kingdom', 'in use']
# ['3350', 'Ketelbrug', '1912', 'Ghent', 'Belgium', 'in use']
# ['3351', 'Kettingbrug', '', 'Dokkum', 'Netherlands', 'in use']
# ['3352', 'Kettle Creek Bridge', '1929', 'Saint Thomas (ON)', 'Canada', 'in use']
# ['3353', 'Kettle Falls Rail Bridge', '1941', 'Kettle Falls (WA)', 'USA', 'in use']
# ['3354', 'Kettle Falls Road Bridge', '1941', 'Kettle Falls (WA)', 'USA', 'in use']
# ['3355', 'Kettwig Railroad Bridge', '', 'Essen (NRW)', 'Germany', 'in use']
# ['3356', 'Kew Railway Bridge', '1869', 'London (GB-ENG)', 'United Kingdom', 'in use']
# ['3357', 'Khanty-Mansiysk Irtysh River Bridge', '2004', 'Khanty-Mansiysk', 'Russia', 'in use']
# ['3358', 'Kharghar Skywalk', '2012', 'Navi Mumbai', 'India', 'in use']
# ['3359', 'Kharkiv Footbridge', '', 'Kharkiv', 'Ukraine', 'in use']
# ['3360', 'Kherson Railroad Bridge', '1954', 'Kherson', 'Ukraine', 'in use']
# ['3361', 'Khndzoresk Bridge', '', 'Khndzoresk', 'Armenia', 'in use']
# ['3362', 'Khrapovitskiy most', '1967', 'Saint Petersburg', 'Russia', 'in use']
# ['3363', 'Kibbelstegbrücke', '2002', 'Hamburg (HH)', 'Germany', 'in use']
# ['3364', 'Kibembe Footbridge', '2019', 'Sironko', 'Uganda', 'in use']
# ['3365', 'Kibiraro Footbridge', '2022', 'Nyamagabe', 'Rwanda', 'in use']
# ['3366', 'Kiciro Footbridge', '2020', 'Muhanga', 'Rwanda', 'in use']
# ['3367', 'Kiefersfelden Bridge', '1968', '- Kiefersfelden (BY)', 'Germany', 'in use']
# ['3368', 'Kiefholzbrücke', '1973', 'Berlin (BE)', 'Germany', 'in use']
# ['3369', 'Kiel Bridge', '1994', 'Berlin (BE)', 'Germany', 'in use']
# ['3370', 'Kiel Transporter Bridge', '1910', 'Kiel (SH)', 'Germany', 'demolished']
# ['3371', 'Kienlesberg Bridge', '2018', 'Ulm (BW)', 'Germany', 'in use']
# ['3372', 'Kiezmark Bridge', '1973', 'Kiezmark (PM)', 'Poland', 'in use']
# ['3373', 'Kiffward Railroad Bridge', '1977', 'Duisburg (NRW)', 'Germany', 'in use']
# ['3374', 'Kiffward Road Bridge', '1979', 'Duisburg (NRW)', 'Germany', 'in use']
# ['3375', 'Kigandi Footbridge', '2021', 'Nyamasheke', 'Rwanda', 'in use']
# ['3376', 'Kigohe Footbridge', '2016', 'Nyanza', 'Rwanda', 'in use']
# ['3377', 'Kihumuro B-kitomwire Footbridge', '2021', 'Kibaale', 'Uganda', 'in use']
# ['3378', 'Kikusui Footbridge', '1971', 'Sapporo', 'Japan', 'in use']
# ['3379', 'Kikuyu Footbridge', '2020', 'Bulambuli', 'Uganda', 'in use']
# ['3380', 'Kilgore Bridge', '1915', 'Kearney (NE)', 'USA', 'in use']
# ['3381', 'Kilianusbrücke', '', 'Mainhausen (HE)', 'Germany', 'in use']
# ['3382', 'Kilpisen silta', '', 'Jyväskylä', 'Finland', 'in use']
# ['3383', 'Kincardine Bridge', '1936', 'Kincardine (GB-SCT)', 'United Kingdom', 'in use']
# ['3384', 'King Alexander Bridge', '1934', 'Belgrade', 'Serbia', 'destroyed']
# ['3385', 'King Edward VII Bridge', '1906', 'Newcastle upon Tyne (GB-ENG)', 'United Kingdom', 'in use']
# ['3386', 'King Street Footbridge', '2000', 'Oldham (GB-ENG)', 'United Kingdom', 'in use']
# ['3387', "King's Bridge", '1864', 'Launceston (TAS)', 'Australia', 'in use']
# ['3388', "King's Bridge", '1933', 'Glasgow (GB-SCT)', 'United Kingdom', 'in use']
# ['3389', 'Kingery Highway S&S Bridge', '1934', 'Lemont (IL)', 'USA', 'in use']
# ['3390', 'Kingsferry Bridge', '1960', 'Isle of Sheppey (GB-ENG)', 'United Kingdom', 'in use']
# ['3391', 'Kingsland Bridge', '1883', 'Shrewsbury (GB-ENG)', 'United Kingdom', 'in use']
# ['3392', 'Kingston-Port Ewen Suspension Bridge', '1921', 'Kingston (NY)', 'USA', 'in use']
# ['3393', 'Kingston-Rhinecliff Bridge', '1957', 'East Kingston (NY)', 'USA', 'in use']
# ['3394', 'Kinzie Street Bridge', '1908', 'Chicago (IL)', 'USA', 'in use']
# ['3395', 'Kinzigbrücke am Stocktunnel', '1886', 'Schenkenzell (BW)', 'Germany', 'in use']
# ['3396', 'Kinzigbrücke Offenburg', '1858', 'Offenburg (BW)', 'Germany', 'demolished']
# ['3397', 'Kinzua Viaduct', '1882', 'Kushequa (PA)', 'USA', 'demolished']
# ['3398', 'Kinzua Viaduct', '1900', 'Kushequa (PA)', 'USA', 'collapsed']
# ['3399', 'Kippenbrug Brielle', '1909', 'Brielle', 'Netherlands', 'in use']
# ['3400', 'Kirchbichl Railroad Bridge', '1939', 'Kirchbichl (TIR)', 'Austria', 'in use']
# ['3401', 'Kirchenfeld Bridge', '1883', 'Berne (BE)', 'Switzerland', 'in use']
# ['3402', 'Kirjalansalmi Bridge', '1963', '- Kaarina', 'Finland', 'in use']
# ['3403', 'Kirkintilloch Footbridge', '2008', 'Kirkintilloch (GB-SCT)', 'United Kingdom', 'in use']
# ['3404', 'Kirklees Viaduct', '1973', 'Huddersfield (GB-ENG)', 'United Kingdom', 'in use']
# ['3405', 'Kirkton of Glenisla Footbridge', '1824', 'Kirkton of Glenisla (GB-SCT)', 'United Kingdom', 'in use']
# ['3406', 'Kirov Bridge', '2014', 'Samara', 'Russia', 'in use']
# ['3407', 'Kirumbi Footbridge', '2020', 'Rutsiro', 'Rwanda', 'in use']
# ['3408', 'Kiruri Footbridge', '2020', 'Rutsiro', 'Rwanda', 'in use']
# ['3409', 'Kishiwada Bridge', '1993', 'Kishiwada', 'Japan', 'in use']
# ['3410', 'Kiskatinaw River Bridge', '1978', 'Dawson Creek (BC)', 'Canada', 'in use']
# ['3411', 'Kiskatinaw River Bridge', '1942', 'Dawson Creek (BC)', 'Canada', 'in use']
# ['3412', 'Kiskopolku Bridge', '1981', 'Oulu', 'Finland', 'in use']
# ['3413', 'Kita 13-jo Bridge', '1976', 'Sapporo', 'Japan', 'in use']
# ['3414', 'Kita Asahikawa Bridge', '1991', 'Asahikawa', 'Japan', 'in use']
# ['3415', 'Kita Bisan-Seto Bridge', '1985', 'Sakaide', 'Japan', 'in use']
# ['3416', 'Kitachikumagawa Bridge', '1997', 'Nagano', 'Japan', 'in use']
# ['3417', 'Kitakyushu Airport Access Bridge', '2006', 'Kitakyushu', 'Japan', 'in use']
# ['3418', 'Kitanokawachi Bridge', '', 'Omura', 'Japan', 'in use']
# ['3419', 'Kitchener Railroad Bridge', '1932', 'Lyon (69)', 'France', 'in use']
# ['3420', 'Kitzloch Footbridge', '', 'Ischgl (TIR)', 'Austria', 'in use']
# ['3421', 'Kivomo Footbridge', '2019', 'Ngororero', 'Rwanda', 'in use']
# ['3422', 'Kivugiza Footbridge', '2020', 'Ngororero', 'Rwanda', 'in use']
# ['3423', 'Kiyosu Bridge', '1928', 'Tokyo', 'Japan', 'in use']
# ['3424', 'Kiyosuna Bridge', '2001', '', 'Japan', 'in use']
# ['3425', 'Kjellingstraumen Bridge', '1975', 'Kjelling', 'Norway', 'in use']
# ['3426', 'Kjerringvikstraumen Bridge', '1969', 'Ballangen', 'Norway', 'in use']
# ['3427', 'Klaffbron', '1953', 'Malmö', 'Sweden', 'in use']
# ['3428', 'Klappbrücke Estesperrwerk', '2000', 'Hamburg (HH)', 'Germany', 'in use']
# ['3429', 'Kledering Classification Yard Railroad Overfly Bridge', '2013', 'Vienna', 'Austria', 'in use']
# ['3430', 'Kleinbahnbrücke Bollstedt', '', 'Weinbergen (TH)', 'Germany', 'demolished']
# ['3431', 'Kleine Striegis Viaduct', '1945', 'Hainichen (SN)', 'Germany', 'destroyed']
# ['3432', 'Kleiner Burstah Footbridge', '', 'Hamburg (HH)', 'Germany', 'in use']
# ['3433', 'Kleinfeldsteg', '2014', 'Mannheim (BW)', 'Germany', 'in use']
# ['3434', 'Kleinmachow Lock Bridge', '2005', 'Kleinmachnow (BB)', 'Germany', 'in use']
# ['3435', 'Klennenhof Bridge', '', 'Duisburg (NRW)', 'Germany', 'in use']
# ['3436', 'Klienitzbrücke', '1900', 'Zehdenick (BB)', 'Germany', 'in use']
# ['3437', "Kline's Bridge", '1902', 'Allentown (PA)', 'USA', 'demolished']
# ['3438', 'Klingenberg Bridge', '1880', 'Klingenberg am Main (BY)', 'Germany', 'destroyed']
# ['3439', 'Klingenthal Railroad Bridge', '', 'Klingenthal (SN)', 'Germany', 'in use']
# ['3440', 'Kloosterbrug', '2001', 'Assen', 'Netherlands', 'in use']
# ['3441', 'Klosterner Brücke', '1954', 'Datteln (NRW)', 'Germany', 'in use']
# ['3442', 'Klosterstrasse Railroad Bridge', '', 'Berlin (BE)', 'Germany', 'in use']
# ['3443', 'Klughafen Footbridge', '', 'Lübeck (SH)', 'Germany', 'in use']
# ['3444', 'Knapps Narrows Bridge', '1998', 'Tilghman Island (MD)', 'USA', 'in use']
# ['3445', 'Knesebeckstrasse Rail Overpass', '1934', 'Berlin (BE)', 'Germany', 'in use']
# ['3446', 'Knibawa Bridge', '1950', 'Knibawa (PM)', 'Poland', 'in use']
# ['3447', "Knight's Key Bridge", '1912', 'Marathon (FL)', 'USA', 'out of service']
# ['3448', 'Knights Landing Bascule Bridge', '1933', '- Knights Landing (CA)', 'USA', 'in use']
# ['3449', 'Knik River Bridge', '', 'Anchorage (AK)', 'USA', 'in use']
# ['3450', 'Knippelsbro', '1937', 'Copenhagen', 'Denmark', 'in use']
# ['3451', 'Knokke Footbridge', '2007', 'Knokke-Heist', 'Belgium', 'in use']
# ['3452', 'Knostrop Footbridge', '2017', 'Leeds (GB-ENG)', 'United Kingdom', 'in use']
# ['3453', 'Knowlesville Road Bridge', '1910', 'Orleans County (NY)', 'USA', 'in use']
# ['3454', 'Kobe Bridge', '1970', 'Kobe', 'Japan', 'in use']
# ['3455', 'Kobe Portpia Bridge', '1979', 'Kobe', 'Japan', 'in use']
# ['3456', 'Koblenz Railroad Bridge', '1892', 'Koblenz (AG)', 'Switzerland', 'in use']
# ['3457', 'Koblenz-Felsenau Bridge', '1937', 'Koblenz (AG)', 'Switzerland', 'in use']
# ['3458', 'Koblenz-Felsenau Footbridge', '', 'Koblenz (AG)', 'Switzerland', 'in use']
# ['3459', 'Koblenz-Horcheim Bridge', '1961', 'Koblenz (RP)', 'Germany', 'in use']
# ['3460', 'Koch-Landau Skywalk', '', 'Cambridge (MA)', 'USA', 'in use']
# ['3461', 'Kochenhof Footbridge', '1990', 'Stuttgart (BW)', 'Germany', 'in use']
# ['3462', 'Köhlbrand Bridge', '1974', '- Hamburg (HH)', 'Germany', 'in use']
# ['3463', 'Kohlfurth Bridge', '1894', 'Wuppertal (NRW)', 'Germany', 'in use']
# ['3464', 'Kokonoe "Yume" Otsurihashi Bridge', '2006', 'Kokonoe', 'Japan', 'in use']
# ['3465', 'Koksilah River Pipeline bridge', '', 'Vancouver Island (BC)', 'Canada', 'in use']
# ['3466', 'Kokubu River Pipeline Bridge', '', 'Kochi', 'Japan', 'in use']
# ['3467', 'Kolbermoor Footbridge', '', 'Kolbermoor (BY)', 'Germany', 'in use']
# ['3468', 'Kolekole Park Bridge', '1950', 'Hawaii County (HI)', 'USA', 'in use']
# ['3469', 'Kolfe-Keranyo Pedestrian Bridge', '2004', 'Addis Ababa', 'Ethiopia', 'in use']
# ['3470', 'Kolín Footbridge', '2005', 'Kolín', 'Czechia', 'in use']
# ['3471', 'Koliste Footbridge', '1998', 'Brno', 'Czechia', 'in use']
# ['3472', 'Kolkerhof Bridge', '1996', 'Duisburg (NRW)', 'Germany', 'in use']
# ['3473', 'Köln-Mülheimer Brücke', '1929', 'Cologne (NRW)', 'Germany', 'destroyed']
# ['3474', 'Köln-Mülheimer Brücke', '1951', 'Cologne (NRW)', 'Germany', 'in use']
# ['3475', 'Kolomoen Bridge', '2011', 'Stange', 'Norway', 'in use']
# ['3476', 'Komsomolsk Railroad Bridge', '1931', 'Novosibirsk', 'Russia', 'in use']
# ['3477', 'Kömürhan Bridge', '2021', 'Elazig', 'Turkey', 'under construction']
# ['3478', 'Kone Bridge', '', 'Onomichi', 'Japan', 'in use']
# ['3479', "Kong Christian den X's Bro", '1930', 'Sønderborg', 'Denmark', 'in use']
# ['3480', 'Kongress-Steg', '2015', 'Saarbrücken (SL)', 'Germany', 'in use']
# ['3481', 'König-Karls-Brücke', '1893', 'Stuttgart (BW)', 'Germany', 'destroyed']
# ['3482', 'König-Karls-Brücke', '1976', 'Stuttgart (BW)', 'Germany', 'in use']
# ['3483', 'König-Ludwig-Trasse Footbridge', '2017', 'Recklinghausen (NRW)', 'Germany', 'in use']
# ['3484', 'Konigshavenbrug', '1927', 'Rotterdam', 'Netherlands', 'out of service']
# ['3485', 'Königsstuhl Observation Deck', '2023', 'Sassnitz (MV)', 'Germany', 'under construction']
# ['3486', 'Königsweg Bridge', '1998', 'Berlin (BE)', 'Germany', 'in use']
# ['3487', 'Koning Albert I-Laan Bicycle Overpass', '', 'Bruges', 'Belgium', 'in use']
# ['3488', 'Konkan Railway Bridge', '1995', 'Tiswadi', 'India', 'in use']
# ['3489', 'Könneritzbrücke', '1899', 'Leipzig (SN)', 'Germany', 'in use']
# ['3490', 'Könnern Railroad Bridge', '', 'Könnern (ST)', 'Germany', 'in use']
# ['3491', 'Konohana Bridge', '1990', 'Osaka', 'Japan', 'in use']
# ['3492', 'Konrad Adenauer Bridge', '1972', 'Bonn (NRW)', 'Germany', 'in use']
# ['3493', 'Konrad Adenauer Bridge', '1959', '- Ludwigshafen am Rhein (RP)', 'Germany', 'in use']
# ['3494', 'Konstanz Cycle Bridge', '1991', 'Konstanz (BW)', 'Germany', 'in use']
# ['3495', 'Kontshingila Footbridge', '2018', 'Eswatini', 'Eswatini', 'in use']
# ['3496', 'Koocanusa Bridge', '1970', 'Lincoln County (MT)', 'USA', 'in use']
# ['3497', 'Koopmann Strasse Bridge', '1955', 'Duisburg (NRW)', 'Germany', 'in use']
# ['3498', 'Kootenay Rail Bridge', '1902', 'Nelson (BC)', 'Canada', 'in use']
# ['3499', 'Kopu Bridge', '1928', 'Coromandel', 'New Zealand', 'in use']
# ['3500', 'Korkeasaarensilta', '1995', 'Oulu', 'Finland', 'in use']
# ['3501', 'Kornhaus Bridge', '1898', 'Berne (BE)', 'Switzerland', 'in use']
# ['3502', 'Kornhausbrücke', '', 'Hamburg (HH)', 'Germany', 'in use']
# ['3503', 'Korosten Footbridge', '', 'Korosten', 'Ukraine', 'in use']
# ['3504', 'Korrebrug', '1993', 'Groningen', 'Netherlands', 'in use']
# ['3505', 'Korya Footbridge', '2020', 'Kween', 'Uganda', 'in use']
# ['3506', 'Kosan Bridge', '1982', 'Ube', 'Japan', 'in use']
# ['3507', 'Kosciuszko Bridge', '2019', '- New York (NY)', 'USA', 'in use']
# ['3508', 'Kostheim Bridge', '1947', '- Wiesbaden (HE)', 'Germany', 'in use']
# ['3509', 'Kostrzyn Bridge', '', 'Kostrzyn nad Odra (LB)', 'Poland', 'in use']
# ['3510', 'Kostrzyn Railroad Bridge', '', 'Kostrzyn nad Odra (LB)', 'Poland', 'in use']
# ['3511', 'Köthen Bridge', '', 'Berlin (BE)', 'Germany', 'in use']
# ['3512', 'Kotlarski Bridge', '2001', 'Cracow (MA)', 'Poland', 'in use']
# ['3513', 'Kötschach-Mauthen Bridge', '', 'Kötschach-Mauthen (KTN)', 'Austria', 'in use']
# ['3514', 'Kotzebue Bridge', '1892', 'Odessa', 'Ukraine', 'in use']
# ['3515', 'Kōya Bridge', '1930', 'Nagoya', 'Japan', 'in use']
# ['3516', 'Køge Footbridge', '2008', 'Køge', 'Denmark', 'in use']
# ['3517', 'Køge North Station Footbridge', '2019', 'Køge', 'Denmark', 'under construction']
# ['3518', 'Krailling Bridge', '1997', 'Krailling (BY)', 'Germany', 'in use']
# ['3519', 'Kraków Pipeline Bridge (East)', '', 'Cracow (MA)', 'Poland', 'in use']
# ['3520', 'Kraków Pipeline Bridge (West)', '', 'Cracow (MA)', 'Poland', 'in use']
# ['3521', 'Krasnolushskyi Bridge', '1907', 'Moscow', 'Russia', 'demolished']
# ['3522', 'Krasnoluzhsky Rail Bridge', '2001', 'Moscow', 'Russia', 'in use']
# ['3523', 'Krasnoyarsk Railroad Bridge', '1896', 'Krasnoyarsk', 'Russia', 'in use']
# ['3524', 'Krasnoyarsk Railroad Bridge', '', 'Krasnoyarsk', 'Russia', 'in use']
# ['3525', 'Kreith Viaduct', '1904', 'Mutters (TIR)', 'Austria', 'in use']
# ['3526', 'Krems Danube Bridge', '1889', 'Krems an der Donau (NOE)', 'Austria', 'in use']
# ['3527', 'Kremsbrücke', '2006', 'Ansfelden (OOE)', 'Austria', 'in use']
# ['3528', 'Kreuzackerbrücke', '', 'Solothurn (SO)', 'Switzerland', 'in use']
# ['3529', 'Kreuztalviadukt', '1930', 'Oberharz am Brocken (ST)', 'Germany', 'in use']
# ['3530', 'Kreuzungsbauwerk der B6 über die A2', '1992', 'Hanover (NI)', 'Germany', 'in use']
# ['3531', 'Krickesteg', '1994', 'Castrop-Rauxel (NRW)', 'Germany', 'in use']
# ['3532', 'Křimice Railroad Bridge', '2006', 'Pilsen', 'Czechia', 'in use']
# ['3533', 'Kringlumýrar Footbridge', '1995', 'Reykjavik', 'Iceland', 'in use']
# ['3534', 'Krommewalbrug', '1992', 'Ghent', 'Belgium', 'in use']
# ['3535', 'Kronprins Frederiks Bro', '1935', 'Frederikssund', 'Denmark', 'in use']
# ['3536', 'Kronprinz-Rudolf-Brücke', '1876', 'Vienna', 'Austria', 'demolished']
# ['3537', 'Kronprinz-Wilhelm-Brücke', '1917', '- Neuwied (RP)', 'Germany', 'destroyed']
# ['3538', 'Kronprinzen Bridge', '1996', 'Berlin (BE)', 'Germany', 'in use']
# ['3539', 'Krotz Springs Bridge', '1934', 'Krotz Springs (LA)', 'USA', 'demolished']
# ['3540', 'Krotz Springs Pipeline Bridge', '', 'Krotz Springs (LA)', 'USA', 'out of service']
# ['3541', 'Krummbrücke Eislingen', '', 'Eislingen (BW)', 'Germany', 'in use']
# ['3542', 'Krupp Factory Railroad Bridge', '1874', 'Essen (NRW)', 'Germany', 'in use']
# ['3543', 'Krupski Młyn Suspension Bridge', '', 'Krupski Młyn (SL)', 'Poland', 'in use']
# ['3544', 'Krymsky Bridge', '1938', 'Moscow', 'Russia', 'in use']
# ['3545', 'Kryukov Bridge', '1949', 'Kremenchuk', 'Ukraine', 'in use']
# ['3546', 'Krzeszówka River Footbridge', '1830', 'Krzeszowice (MA)', 'Poland', 'in use']
# ['3547', 'Kuala Lumpur Monorail Arch Bridge', '2002', 'Kuala Lumpur', 'Malaysia', 'in use']
# ['3548', 'Kübelbach Viaduct', '1879', 'Dornstetten (BW)', 'Germany', 'in use']
# ['3549', 'Kucyaruseke Footbridge', '2018', 'Nyaruguru', 'Rwanda', 'in use']
# ['3550', 'Kuhdammbrücke', '2005', 'Wustermark (BB)', 'Germany', 'in use']
# ['3551', 'Kuiqi Railway Bridge', '2008', 'Fuzhou', 'China', 'in use']
# ['3552', 'Kukibuye Footbridge', '2016', 'Nyabihu', 'Rwanda', 'in use']
# ['3553', 'Kukizaki Bridge', '1980', 'Ibaraki', 'Japan', 'in use']
# ['3554', 'Kulla Footbridge', '2007', 'Ethiopia', 'Ethiopia', 'in use']
# ['3555', 'Kumusenyi Footbridge', '2017', 'Muhanga', 'Rwanda', 'in use']
# ['3556', 'Kungsängsledsbron', '', 'Uppsala', 'Sweden', 'in use']
# ['3557', 'Kungur Footbridge', '', 'Kungur', 'Russia', 'in use']
# ['3558', 'Kuopio Rail Bridge', '', 'Kuopio', 'Finland', 'in use']
# ['3559', 'Kupfergraben Railroad Bridge', '1934', 'Berlin (BE)', 'Germany', 'in use']
# ['3560', 'Kurilpa Bridge', '2009', 'Brisbane (QLD)', 'Australia', 'in use']
# ['3561', 'Kuringen Railroad Bridge', '', 'Kuringen', 'Belgium', 'in use']
# ['3562', 'Kuronoseto Bridge', '1974', 'Akune', 'Japan', 'in use']
# ['3563', 'Kurpfalzbrücke', '1950', 'Mannheim (BW)', 'Germany', 'in use']
# ['3564', 'Kurt Schumacher Bridge', '1974', 'Gelsenkirchen (NRW)', 'Germany', 'in use']
# ['3565', 'Kurt Schumacher Bridge', '1972', '- Ludwigshafen am Rhein (RP)', 'Germany', 'in use']
# ['3566', 'Kurt-Haertel-Passage Skybridge', '', 'Munich (BY)', 'Germany', 'in use']
# ['3567', 'Kurushima Kaikyo Bridge, First', '1999', '- Mushishima', 'Japan', 'in use']
# ['3568', 'Kurushima Kaikyo Bridge, Second', '1999', '- Umashima', 'Japan', 'in use']
# ['3569', 'Kurushima Kaikyo Bridge, Third', '1999', '- Umashima', 'Japan', 'in use']
# ['3570', 'Kushimoto Bridge', '1999', 'Wakayama', 'Japan', 'in use']
# ['3571', 'Kuskalana Bridge', '1910', 'Chitina (AK)', 'USA', 'in use']
# ['3572', 'Küstrin-Kietz Oder River Rail Bridge', '2020', '- Küstriner Vorland (BB)', 'Germany', 'project phase']
# ['3573', 'Küstrin-Kietz Oder River West Branch Rail Bridge', '2020', 'Küstriner Vorland (BB)', 'Germany', 'project phase']
# ['3574', 'Kutai Kertanegara Suspension Bridge', '2001', 'Tenggarong', 'Indonesia', 'collapsed']
# ['3575', 'Kuznechevsky Bridge', '1956', 'Arkhangelsk', 'Russia', 'in use']
# ['3576', 'Kwa Rukeratabaro Footbridge', '2022', 'Muhanga', 'Rwanda', 'in use']
# ...
# ['7743', 'William S. Ritchie Bridge', '1981', 'Ravenswood (WV)', 'USA', 'in use']
# ['7744', 'Williamsburg Bridge', '1903', 'New York (NY)', 'USA', 'in use']
# ['7745', 'Willich Footbridge', '2002', 'Willich (NRW)', 'Germany', 'in use']
# ['7746', 'Willis Avenue Bridge', '2010', 'New York (NY)', 'USA', 'in use']
# ['7747', 'Willis Avenue Bridge', '1901', 'New York (NY)', 'USA', 'demolished']
# ['7748', 'Wills Creek Bollman Bridge', '1871', 'Somerset County (PA)', 'USA', 'in use']
# ['7749', 'Wilmington Bridge', '', 'Kingston upon Hull (GB-ENG)', 'United Kingdom', 'in use']
# ['7750', 'Wilson Canyon Bridge', '1938', 'Coconino County (AZ)', 'USA', 'in use']
# ['7751', 'Wind Bridge', '2018', 'Uppsala', 'Sweden', 'in use']
# ['7752', 'Wind River Suspension Bridge', '1998', 'Carson (WA)', 'USA', 'in use']
# ['7753', 'Windsor Bridge', '1825', 'Windsor (GB-ENG)', 'United Kingdom', 'in use']
# ['7754', 'Windsor Railway Bridge', '1849', 'Windsor (GB-ENG)', 'United Kingdom', 'in use']
# ['7755', 'Winningen Viaduct', '1972', 'Winningen (RP)', 'Germany', 'in use']
# ['7756', 'Winona Bridge', '1924', 'Winona (AZ)', 'USA', 'in use']
# ['7757', 'Winona Main Channel Bridge', '1941', 'Winona (MN)', 'USA', 'in use']
# ['7758', 'Winona Railroad Bridge', '1891', 'Winona (MN)', 'USA', 'demolished']
# ['7759', 'Winooski River Footbridge', '', 'Bolton (VT)', 'USA', 'in use']
# ['7760', 'Winston Bridge', '1934', 'Douglas County (OR)', 'USA', 'in use']
# ['7761', 'Winston Street Overpass', '2009', 'Burnaby (BC)', 'Canada', 'in use']
# ['7762', 'Winterhuder Brücke', '1921', 'Hamburg (HH)', 'Germany', 'in use']
# ['7763', 'Wipfratalbrücke', '2002', 'Wipfratal (TH)', 'Germany', 'in use']
# ['7764', 'Wirye Bridge', '', 'Hanam', 'South Korea', 'in use']
# ['7765', 'Wishbone Bridge', '', 'Wolverhampton (GB-ENG)', 'United Kingdom', 'in use']
# ['7766', 'Wishing Star Lake Bridge (East)', '', 'Shanghai', 'China', 'in use']
# ['7767', 'Wishing Star Lake Bridge (West)', '', 'Shanghai', 'China', 'in use']
# ['7768', 'Wismar Footbridge', '', 'Wismar (MV)', 'Germany', 'in use']
# ['7769', 'Wissekerke Castle Footbridge', '1824', 'Kruibeke', 'Belgium', 'in use']
# ['7770', 'Witten Viaduct', '1916', 'Witten (NRW)', 'Germany', 'in use']
# ['7771', 'Witten-Bommern Bridge', '1882', 'Witten (NRW)', 'Germany', 'demolished']
# ['7772', 'Witten-Bommern Bridge', '1996', 'Witten (NRW)', 'Germany', 'in use']
# ['7773', 'Wittenberg Railroad Bridge', '2000', 'Wittenberg (ST)', 'Germany', 'in use']
# ['7774', 'Wittenberg Road Bridge', '2000', 'Wittenberg (ST)', 'Germany', 'in use']
# ['7775', 'Wittenberge Railroad Bridge', '1987', '- Wittenberge (BB)', 'Germany', 'in use']
# ['7776', 'Wittenberge Road Bridge', '1978', '- Wittenberge (BB)', 'Germany', 'in use']
# ['7777', 'Wittpenn Bridge', '2021', 'Jersey City (NJ)', 'USA', 'under construction']
# ['7778', 'Wittpenn Bridge', '1930', 'Jersey City (NJ)', 'USA', 'in use']
# ['7779', 'Witzenhausen Bridge', '', 'Witzenhausen (HE)', 'Germany', 'in use']
# ['7780', 'Wiwili Bridge', '1886', 'Freiburg im Breisgau (BW)', 'Germany', 'in use']
# ['7781', 'Wohlgelegen Bridge', '2003', 'Heilbronn (BW)', 'Germany', 'in use']
# ['7782', 'Wokop Bridge', '', 'Tel Aviv', 'Israel', 'in use']
# ['7783', 'Wolbecker Straßenbrücke', '2013', 'Münster (NRW)', 'Germany', 'in use']
# ['7784', 'Wolchulsan Suspension Bridge', '2006', 'South Jeolla', 'South Korea', 'in use']
# ['7785', 'Wolf Point Bridge', '1930', 'Wolf Point (MT)', 'USA', 'out of service']
# ['7786', 'Wolken Rail Bridge', '1847', 'Bützow (MV)', 'Germany', 'in use']
# ['7787', 'Wolkenhain', '2016', 'Berlin (BE)', 'Germany', 'in use']
# ['7788', 'Woluwelaan Railroad Bridge', '2012', 'Zaventem', 'Belgium', 'in use']
# ['7789', 'Wood Street Cycle Bridge', '2019', 'London (GB-ENG)', 'United Kingdom', 'in use']
# ['7790', 'Woolston Eyes Footbridge', '', 'Warrington (GB-ENG)', 'United Kingdom', 'in use']
# ['7791', 'Worcester railway bridge', '1904', 'Worcester (GB-ENG)', 'United Kingdom', 'in use']
# ['7792', 'World Trade Center Avenue Bridge', '', 'Boston (MA)', 'USA', 'in use']
# ['7793', 'World War I Memorial Bridge', '2013', 'Portsmouth (NH)', 'USA', 'in use']
# ['7794', 'Wörlitz Bridge', '1894', 'Dessau-Roßlau (ST)', 'Germany', 'in use']
# ['7795', 'Wormeldingen Bridge', '1890', 'Wormeldange', 'Luxembourg', 'destroyed']
# ['7796', 'Wormeldingen Bridge', '1964', 'Wormeldange', 'Luxembourg', 'in use']
# ['7797', 'Worms Railroad Bridge', '1900', 'Worms (RP)', 'Germany', 'in use']
# ['7798', 'Wroxham Footbridge', '2001', 'Wroxham (GB-ENG)', 'United Kingdom', 'in use']
# ['7799', 'Wublitz Footbridge', '1999', 'Werder (Havel) (BB)', 'Germany', 'in use']
# ['7800', 'Wuhan Yangtze River Bridge', '1957', 'Wuhan', 'China', 'in use']
# ['7801', 'Wuhlesteg', '2016', 'Berlin (BE)', 'Germany', 'in use']
# ['7802', 'Wuhu Yangtze River Bridge', '2000', 'Wuhu', 'China', 'in use']
# ['7803', 'Wunderbrücke (Technorama)', '2020', 'Winterthur (ZH)', 'Switzerland', 'in use']
# ['7804', 'Wupperbrücke Stadion', '', 'Wuppertal (NRW)', 'Germany', 'in use']
# ['7805', 'Wupperthal Footbridge', '', 'Wupperthal', 'South Africa', 'in use']
# ['7806', 'Wuri Bridge', '', 'Taichung', 'Taiwan', 'in use']
# ['7807', 'Würzburg Railroad Bridge', '', 'Würzburg (BY)', 'Germany', 'in use']
# ['7808', 'Wurzen-Bennewitz Bridge', '2006', 'Wurzen (SN)', 'Germany', 'in use']
# ['7809', 'Wustermark Bridge', '2005', 'Wustermark (BB)', 'Germany', 'in use']
# ['7810', 'Wustermark Rail Bridge (I)', '', 'Wustermark (BB)', 'Germany', 'in use']
# ['7811', 'Wustermark Rail Bridge (II)', '', 'Wustermark (BB)', 'Germany', 'in use']
# ['7812', 'Wusterwitz Bridge', '2009', 'Wusterwitz (BB)', 'Germany', 'in use']
# ['7813', 'Wutach Viaduct', '1890', 'Stühlingen (BW)', 'Germany', 'in use']
# ['7814', 'Wye River Bridge', '1966', 'Chepstow (GB-WLS)', 'United Kingdom', 'in use']
# ['7815', 'Wylam Railway Bridge', '1876', 'Wylam (GB-ENG)', 'United Kingdom', 'in use']
# ['7816', 'Wyland Bridge', '2002', 'Winterthur (ZH)', 'Switzerland', 'in use']
# ['7817', 'Wynch Bridge', '1830', 'Middleton (GB-ENG)', 'United Kingdom', 'in use']
# ['7818', 'Wynyard Crossing', '2011', 'Auckland', 'New Zealand', 'in use']
# ['7819', 'Wyoming Bridge', '1878', 'Dunbar (NE)', 'USA', 'demolished']
# ['7820', 'Wyszogród Bridge', '1999', 'Wyszogród (MZ)', 'Poland', 'in use']
# ['7821', 'Xechpup Footbridge', '2012', 'Guatemala', 'Guatemala', 'in use']
# ['7822', 'Xiangshun Road Bicycle Bridge', '', 'Taichung', 'Taiwan', 'in use']
# ['7823', 'Xiaoyoukeng Bridge', '', 'Taipei', 'Taiwan', 'in use']
# ['7824', 'Xidayinggang Twin Bridges', '2010', 'Shanghai', 'China', 'in use']
# ['7825', 'Xihoumen Bridge', '2009', '- Zhoushan', 'China', 'in use']
# ['7826', 'Xijiang River Bridge', '', 'Zhaoqing', 'China', 'in use']
# ['7827', 'Xiling Bridge', '1996', 'Yichang', 'China', 'in use']
# ['7828', 'Xinfada Bridge', '', 'Kaohsiung', 'Taiwan', 'in use']
# ['7829', 'Xingan Bridge', '', 'New Taipei City', 'Taiwan', 'in use']
# ['7830', 'XinWei Bridge', '', 'Kaohsiung', 'Taiwan', 'in use']
# ['7831', 'Xstrata Treetop Walkway', '2008', 'London (GB-ENG)', 'United Kingdom', 'in use']
# ['7832', 'Yabina y Colpa Bridge', '2008', 'Cusco', 'Peru', 'in use']
# ['7833', 'Yachi River Bridge', '2016', 'Guizhou', 'China', 'in use']
# ['7834', 'Yale Bridge', '1932', 'Yale (WA)', 'USA', 'in use']
# ['7835', 'Yamashiro Bridge', '1998', 'Kyoto', 'Japan', 'in use']
# ['7836', 'Yamatogawa Bridge', '1985', 'Osaka', 'Japan', 'in use']
# ['7837', 'Yanase Footbridge', '', 'Kami', 'Japan', 'in use']
# ['7838', 'Yancopin Bridge', '1903', 'Arkansas County (AR)', 'USA', 'out of service']
# ['7839', 'Yanggak Rail Bridge', '', 'Pyongyang', 'North Korea', 'in use']
# ['7840', 'Yangsigang Bridge', '2019', 'Wuhan', 'China', 'in use']
# ['7841', 'Yanji Yangtze River Bridge', '', 'Hubei', 'China', 'under construction']
# ['7842', 'Yankees–East 153rd Street Station Acces Bridge', '', 'New York (NY)', 'USA', 'in use']
# ['7843', 'Yankton Road Bridge', '', 'Sioux Falls (SD)', 'USA', 'in use']
# ['7844', 'Yaquina Bay Bridge', '1936', 'Newport (OR)', 'USA', 'in use']
# ['7845', 'Yardley-Wilburtha Bridge', '1903', 'Ewing (NJ)', 'USA', 'destroyed']
# ['7846', 'Yaremche Railway Bridge', '', 'Yaremche', 'Ukraine', 'demolished']
# ['7847', 'Yaroslavl Footbridge', '', 'Exeter (GB-ENG)', 'United Kingdom', 'in use']
# ['7848', 'Yaroslavl Pipeline Bridge', '', 'Yaroslavl', 'Russia', 'in use']
# ['7849', 'Yaroslavl Railroad Bridge', '1913', 'Yaroslavl', 'Russia', 'in use']
# ['7850', 'Yasaka Bridge', '', 'Iwakuni', 'Japan', 'in use']
# ['7851', 'Yauri Totora Footbridge', '2019', 'Tapacarí', 'Bolivia', 'in use']
# ['7852', 'Yavuz Sultan Selim Bridge', '2016', 'Istanbul', 'Turkey', 'in use']
# ['7853', 'Yayule #2 Footbridge', '2018', 'El Tuma-La Dalia', 'Nicaragua', 'in use']
# ['7854', 'Yazd Pedestrian Overpass', '', 'Yazd', 'Iran', 'in use']
# ['7855', 'Yazoo River Bridge', '1950', 'Redwood (MS)', 'USA', 'demolished']
# ['7856', 'Ybbs Footbridge', '2007', 'Amstetten (NOE)', 'Austria', 'in use']
# ['7857', 'Yehudit-Bizaron Bridge', '2019', 'Tel Aviv', 'Israel', 'in use']
# ['7858', 'Yellot Bridge', '', 'Baltimore County (MD)', 'USA', 'in use']
# ['7859', 'Yellow Bridge', '', 'Klungkung', 'Indonesia', 'collapsed']
# ['7860', 'Yellowstone River Bridge', '1930', 'Gardiner (MT)', 'USA', 'in use']
# ['7861', 'Yenne Suspension Bridge', '', 'Yenne (73)', 'France', 'in use']
# ['7862', 'Yeongdo Bridge', '2013', 'Busan', 'South Korea', 'in use']
# ['7863', 'Yeongheung Grand Bridge', '2001', 'Incheon', 'South Korea', 'in use']
# ['7864', 'Yeongjong Grand Bridge', '2000', 'Incheon', 'South Korea', 'in use']
# ['7865', 'Yeouido Saetgang Bridge', '2011', 'Seoul', 'South Korea', 'in use']
# ['7866', 'Yesanhe River Pipeline Bridge', '2009', 'Hubei', 'China', 'in use']
# ['7867', 'Ygnacio Valley Road Overcrossing', '', 'Walnut Creek (CA)', 'USA', 'in use']
# ['7868', 'Yi Qun Bridge', '', 'Kaohsiung', 'Taiwan', 'in use']
# ['7869', 'Yi Sun-Sin Bridge', '2012', 'Yeosu', 'South Korea', 'in use']
# ['7870', 'Yichang Xiling Bridge', '2001', 'Yichang', 'China', 'in use']
# ['7871', 'Yingshuihe Bridge', '1966', 'China', 'China', 'in use']
# ['7872', 'Yingwuzhou Yangtze River Bridge', '2014', 'Wuhan', 'China', 'in use']
# ['7873', 'Yodogawa Bridge', '1928', 'Kyoto', 'Japan', 'in use']
# ['7874', 'Yokohama Bay Bridge', '1989', 'Yokohama', 'Japan', 'in use']
# ['7875', 'York Millennium Bridge', '2001', 'York (GB-ENG)', 'United Kingdom', 'in use']
# ['7876', 'Yoshima Bridge', '1988', 'Sakaide', 'Japan', 'in use']
# ['7877', 'Young Bank Bridge', '', 'Belmopan', 'Belize', 'in use']
# ['7878', 'Ypsilon Footbridge', '2008', 'Drammen', 'Norway', 'in use']
# ['7879', 'Yufeng Bridge', '', 'Kunshan', 'China', 'in use']
# ['7880', 'Yūhigaoka Footbridge', '', 'Hiratsuka', 'Japan', 'in use']
# ['7881', 'Yujiang Bridge', '2014', 'Guangxi', 'China', 'in use']
# ['7882', 'Yuma Crossing Railroad Bridge', '1923', 'Yuma (AZ)', 'USA', 'in use']
# ['7883', 'Yumemai Bridge', '2001', 'Osaka', 'Japan', 'in use']
# ['7884', 'Yun Lung Arch Bridge', '1982', 'Nantou', 'Taiwan', 'in use']
# ['7885', 'Yunguita Suspension Bridge', '1926', 'Huila', 'Colombia', 'demolished']
# ['7886', 'Yunguyo Footbridge', '2016', 'Loayza', 'Bolivia', 'in use']
# ['7887', 'Yuri Bridge', '2013', 'Yurihonjō', 'Japan', 'in use']
# ['7888', 'Zabalgana Footbridge', '2016', 'Vitoria-Gasteiz', 'Spain', 'in use']
# ['7889', 'Zabia kladka', '1975', 'Wroclaw (DS)', 'Poland', 'in use']
# ['7890', 'Zablocki Drive Bridge', '1960', 'Milwaukee (WI)', 'USA', 'in use']
# ['7891', 'Zabłocie Rail Bridge', '2020', 'Cracow (MA)', 'Poland', 'in use']
# ['7892', 'Zabłocie Rail Bridge', '1988', 'Cracow (MA)', 'Poland', 'demolished']
# ['7893', 'Zaepfel Bridge', '2007', 'Strasbourg (67)', 'France', 'in use']
# ['7894', 'Zagorsko Footbridge', '', 'Momchilgrad', 'Bulgaria', 'in use']
# ['7895', 'Zaisyo Bridge', '', 'Kami', 'Japan', 'in use']
# ['7896', 'Zakroczym Bridge', '1990', 'Zakroczym (MZ)', 'Poland', 'in use']
# ['7897', 'Zala River Railroad Bridge', '', 'Zalaegerszeg', 'Hungary', 'in use']
# ['7898', 'Zamora Rail Bridge', '', 'Zamora', 'Spain', 'in use']
# ['7899', 'Zandhazen Bridge', '2016', 'Gooise Meren', 'Netherlands', 'in use']
# ['7900', 'Zaporizhia Arch Bridge', '1974', 'Zaporizhzhia', 'Ukraine', 'in use']
# ['7901', 'Zaragoza Ebro River Rail Bridge', '', 'Zaragoza', 'Spain', 'in use']
# ['7902', 'Zárate-Brazo Largo Bridge I', '1977', 'Zárate', 'Argentina', 'in use']
# ['7903', 'Zárate-Brazo Largo Bridge II', '1977', 'Zárate', 'Argentina', 'in use']
# ['7904', 'Žďákov Bridge', '1965', 'Orlík nad Vltavou', 'Czechia', 'in use']
# ['7905', 'Zeilsheim Overpass near Frankfurt', '1988', 'Frankfurt (HE)', 'Germany', 'in use']
# ['7906', 'Zeitzgrundbrücke', '', 'Stadtroda (TH)', 'Germany', 'demolished']
# ['7907', 'Zelzate Bascule Bridge', '', 'Zelzate', 'Belgium', 'in use']
# ['7908', 'Zenica Bosna River Bridge I', '1985', 'Zenica', 'Bosnia and Herzegovina', 'in use']
# ['7909', 'Zenica Bosna River Bridge II', '1985', 'Zenica', 'Bosnia and Herzegovina', 'in use']
# ['7910', 'Zenn Canal Bridge', '', 'Fürth (BY)', 'Germany', 'in use']
# ['7911', 'Zeppelin Bridge', '2003', 'Nordhausen (TH)', 'Germany', 'in use']
# ['7912', 'Zerpenschleuse Railroad Bridge', '1999', 'Wandlitz (BB)', 'Germany', 'in use']
# ['7913', 'Zeya River Rail Bridge', '', 'Blagoveshchensk', 'Russia', 'in use']
# ['7914', 'Zeya River Road Bridge', '', 'Blagoveshchensk', 'Russia', 'in use']
# ['7915', 'Žeželj Bridge', '2018', 'Novi Sad', 'Serbia', 'in use']
# ['7916', 'Zhanjiang Bay Bridge', '2007', 'Zhanjiang', 'China', 'in use']
# ['7917', 'Zhengzhou Yellow River Bridge', '2010', 'Zhengzhou', 'China', 'in use']
# ['7918', 'Zhivopisny Bridge', '2007', 'Moscow', 'Russia', 'in use']
# ['7919', 'Zhongshan Bridge', '1909', 'Lanzhou', 'China', 'in use']
# ['7920', 'Zhumeng Bridge', '', 'Taoyuan', 'Taiwan', 'in use']
# ['7921', 'Zhytomyr Park Footbridge', '', 'Zhytomyr', 'Ukraine', 'in use']
# ['7922', 'Ziegeleibrücke', '', 'Templin (BB)', 'Germany', 'in use']
# ['7923', 'Ziegelgrabenbrücke', '2007', 'Stralsund (MV)', 'Germany', 'in use']
# ['7924', 'Zieglers Ford Bridge', '1904', 'Decoria Township (MN)', 'USA', 'demolished']
# ['7925', 'Ziemes Valley Bridge', '1895', 'Remptendorf (TH)', 'Germany', 'out of service']
# ['7926', 'Zigor Kalea Bridge', '2004', 'Idiazabal', 'Spain', 'in use']
# ['7927', 'Zihlbrücke', '', '- La Tène (NE)', 'Switzerland', 'in use']
# ['7928', 'Zinggen Footbridge', '2019', 'Brixen (TT)', 'Italy', 'in use']
# ['7929', 'Znojmo Railroad Bridge', '1871', 'Znojmo', 'Czechia', 'in use']
# ['7930', 'Znojmo Railway Viaduct', '2009', 'Znojmo', 'Czechia', 'in use']
# ['7931', 'Zoarville Station Bridge', '1868', 'Zoarville (OH)', 'USA', 'in use']
# ['7932', 'Zofu Railroad Bridge', '1956', 'Haut-Katanga', 'Democratic Republic of the Congo', 'in use']
# ['7933', 'Zollamtsteg', '1900', 'Vienna', 'Austria', 'in use']
# ['7934', 'Zoobrücke', '1966', 'Cologne (NRW)', 'Germany', 'in use']
# ['7935', 'Zorrotza Cycleway Bridge', '', 'Bilbao', 'Spain', 'in use']
# ['7936', 'Zouthaven Bridge', '2005', 'Amsterdam', 'Netherlands', 'in use']
# ['7937', 'Zródlowa Street Footbridge', '2000', 'Kielce (SW)', 'Poland', 'in use']
# ['7938', 'Zschopautal Viaduct', '1906', 'Mittweida (SN)', 'Germany', 'in use']
# ['7939', 'Zubimusu Bridge', '', 'Villabona', 'Spain', 'in use']
# ['7940', 'Zuiderbrug', '1913', 'Meppel', 'Netherlands', 'in use']
# ['7941', 'Zupanja-Orasje Bridge', '1968', 'Zupanja', 'Croatia', 'in use']
# ['7942', 'Zwanenwaterbrug', '', 'Lelystad', 'Netherlands', 'in use']
# ['7943', 'Zwartewaterbrug', '1972', 'Zwartewaterland', 'Netherlands', 'in use']
# ['7944', 'Zweigert Bridge', '2000', 'Essen (NRW)', 'Germany', 'in use']
# ['7945', 'Zwierzyniecka Footbridge', '', 'Wroclaw (DS)', 'Poland', 'in use']
# ['7946', 'Zwierzyniecki Bridge', '1897', 'Wroclaw (DS)', 'Poland', 'in use']
# ['7947', 'Zwingenberg Bridge', '2011', 'Zwingenberg (BW)', 'Germany', 'in use']
# ['7948', 'Zwischenbrunner Strasse Bridge', '', 'Sankt Pölten (NOE)', 'Austria', 'in use']
# ['7949', 'Zwolle Railroad Bridge', '2011', 'Zwolle', 'Netherlands', 'in use']
# ['7950', 'Żywiec Bridge', '', 'Zywiec (SL)', 'Poland', 'in use']
# ['7951', 'Þjórsá Bridge', '1949', 'Southern Region', 'Iceland', 'in use']
